# %% [markdown]
# ## extracting ERP and PSD features without grand averaging

# %%
# %matplotlib inline
import numpy as np

from scipy.io import loadmat 
import mne, glob 
import pandas as pd
import mat73

# %%
# find the matfiles in the current directory 
matfiles = glob.glob('*.mat')

data = {}
matfiles
# Out:
# ['PreProcessed_AD001_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD002_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD003_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD004_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD006_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD008_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD010_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD011_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD012_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD013_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD014_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD015_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD016_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD017_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD018_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD020_Preprocessed_FirstClick.mat']

# %%
data_for_chan=mat73.loadmat(matfiles[0])
data_chan = pd.DataFrame.from_dict(data_for_chan)
chan=data_chan.iloc[4,0]
result_array = np.array([item for sublist in chan for item in sublist], dtype=str)
result_array
channels=result_array[0:102]
print('channels are')
print(channels)
print(channels.dtype)
# Out:
# channels are
# ['MEG0112+0113' 'MEG0122+0123' 'MEG0132+0133' 'MEG0142+0143'
#  'MEG0212+0213' 'MEG0222+0223' 'MEG0232+0233' 'MEG0242+0243'
#  'MEG0312+0313' 'MEG0322+0323' 'MEG0332+0333' 'MEG0342+0343'
#  'MEG0412+0413' 'MEG0422+0423' 'MEG0432+0433' 'MEG0442+0443'
#  'MEG0512+0513' 'MEG0522+0523' 'MEG0532+0533' 'MEG0542+0543'
#  'MEG0612+0613' 'MEG0622+0623' 'MEG0632+0633' 'MEG0642+0643'
#  'MEG0712+0713' 'MEG0722+0723' 'MEG0732+0733' 'MEG0742+0743'
#  'MEG0812+0813' 'MEG0822+0823' 'MEG0912+0913' 'MEG0922+0923'
#  'MEG0932+0933' 'MEG0942+0943' 'MEG1012+1013' 'MEG1022+1023'
#  'MEG1032+1033' 'MEG1042+1043' 'MEG1112+1113' 'MEG1122+1123'
#  'MEG1132+1133' 'MEG1142+1143' 'MEG1212+1213' 'MEG1222+1223'
#  'MEG1232+1233' 'MEG1242+1243' 'MEG1312+1313' 'MEG1322+1323'
#  'MEG1332+1333' 'MEG1342+1343' 'MEG1412+1413' 'MEG1422+1423'
#  'MEG1432+1433' 'MEG1442+1443' 'MEG1512+1513' 'MEG1522+1523'
#  'MEG1532+1533' 'MEG1542+1543' 'MEG1612+1613' 'MEG1622+1623'
#  'MEG1632+1633' 'MEG1642+1643' 'MEG1712+1713' 'MEG1722+1723'
#  'MEG1732+1733' 'MEG1742+1743' 'MEG1812+1813' 'MEG1822+1823'
#  'MEG1832+1833' 'MEG1842+1843' 'MEG1912+1913' 'MEG1922+1923'
#  'MEG1932+1933' 'MEG1942+1943' 'MEG2012+2013' 'MEG2022+2023'
#  'MEG2032+2033' 'MEG2042+2043' 'MEG2112+2113' 'MEG2122+2123'
#  'MEG2132+2133' 'MEG2142+2143' 'MEG2212+2213' 'MEG2222+2223'
#  'MEG2232+2233' 'MEG2242+2243' 'MEG2312+2313' 'MEG2322+2323'
#  'MEG2332+2333' 'MEG2342+2343' 'MEG2412+2413' 'MEG2422+2423'
#  'MEG2432+2433' 'MEG2442+2443' 'MEG2512+2513' 'MEG2522+2523'
#  'MEG2532+2533' 'MEG2542+2543' 'MEG2612+2613' 'MEG2622+2623'
#  'MEG2632+2633' 'MEG2642+2643']
# <U12

# %%
list_1 = channels.tolist()

# %%
location=data_chan.iloc[2,0]
pos=location['chanpos']
position=pos[0:102,:]

# %%
position
# Out:
# array([[-1.00075722e+01,  3.65128630e+00, -2.25105759e+00],
#        [-1.00621064e+01,  5.41282576e+00,  1.21426809e+00],
#        [-1.05140172e+01,  2.08403908e+00,  1.12193825e+00],
#        [-1.01240423e+01,  2.99298532e-01, -2.43275739e+00],
#        [-1.08367367e+01,  2.42531954e+00,  4.56424844e+00],
#        [-1.04351099e+01,  3.27754793e+00,  7.96055022e+00],
#        [-1.04496296e+01, -3.25349648e-01,  7.97673586e+00],
#        [-1.07277930e+01, -9.80692656e-01,  4.55195115e+00],
#        [-9.09741576e+00,  9.13935512e+00,  4.74954632e+00],
#        [-9.61617502e+00,  6.87580031e+00,  7.98214670e+00],
#        [-8.13470060e+00,  7.04733974e+00,  1.11388049e+01],
#        [-1.03150464e+01,  5.76595163e+00,  4.57486396e+00],
#        [-9.01232708e+00,  3.53965618e+00,  1.12300844e+01],
#        [-6.48532589e+00,  3.67729556e+00,  1.38783412e+01],
#        [-6.42388187e+00,  2.05244753e-01,  1.41232341e+01],
#        [-9.03684434e+00,  1.97289632e-02,  1.13746798e+01],
#        [-7.07210463e+00,  1.19415687e+01,  5.40785941e+00],
#        [-4.16394793e+00,  1.35577312e+01,  6.11421700e+00],
#        [-4.52085838e+00,  1.23830239e+01,  9.23438019e+00],
#        [-7.70068027e+00,  1.03274429e+01,  8.46208411e+00],
#        [-4.92502678e+00,  1.01580182e+01,  1.19057413e+01],
#        [-1.46904798e+00,  7.67545381e+00,  1.45639508e+01],
#        [-3.23796088e+00,  4.23655394e+00,  1.53834322e+01],
#        [-5.06940022e+00,  7.23435429e+00,  1.36802152e+01],
#        [-3.10327932e+00,  8.92683020e-01,  1.57962249e+01],
#        [ 5.82680683e-01,  1.10865396e+00,  1.62393270e+01],
#        [ 8.13844449e-01, -2.28044256e+00,  1.59580808e+01],
#        [-2.86801226e+00, -2.53504521e+00,  1.55062437e+01],
#        [-8.97337326e-01,  1.42329481e+01,  6.63004480e+00],
#        [-1.20382954e+00,  1.30013708e+01,  9.77732697e+00],
#        [ 2.42522017e+00,  1.39411912e+01,  6.89689182e+00],
#        [ 5.60446129e+00,  1.26692362e+01,  6.92189435e+00],
#        [ 5.65132128e+00,  1.10953685e+01,  1.00777292e+01],
#        [ 2.18521635e+00,  1.27638216e+01,  1.00509108e+01],
#        [-1.40866294e+00,  1.08201497e+01,  1.25320842e+01],
#        [ 2.18874927e+00,  1.05725641e+01,  1.27611083e+01],
#        [ 2.24341012e+00,  7.65030012e+00,  1.45698230e+01],
#        [ 4.17290741e-01,  4.46978855e+00,  1.58123782e+01],
#        [ 3.95943428e+00,  4.28552814e+00,  1.51443070e+01],
#        [ 7.05872116e+00,  4.47692730e+00,  1.31724878e+01],
#        [ 7.43318721e+00,  9.69849792e-01,  1.33551657e+01],
#        [ 4.22825949e+00,  8.55664076e-01,  1.54133618e+01],
#        [ 8.03480654e+00,  1.01170118e+01,  6.80013164e+00],
#        [ 9.62304532e+00,  6.93786213e+00,  6.98193618e+00],
#        [ 8.01879980e+00,  7.90240925e+00,  1.01025434e+01],
#        [ 5.79023380e+00,  7.85993961e+00,  1.28339054e+01],
#        [ 9.22519499e+00,  4.43214600e+00,  1.03242311e+01],
#        [ 1.05117478e+01,  3.66943307e+00,  7.14145619e+00],
#        [ 1.08043342e+01,  2.72882709e-01,  7.11004552e+00],
#        [ 9.63570016e+00,  8.44535943e-01,  1.04120074e+01],
#        [ 1.02207380e+01,  6.58272016e+00,  3.61291261e+00],
#        [ 1.11656301e+01,  4.93463700e+00,  3.34197089e-01],
#        [ 1.17059679e+01,  1.57083265e+00,  2.42070781e-01],
#        [ 1.10299848e+01,  3.32941198e+00,  3.75281003e+00],
#        [-1.03379552e+01, -1.26031199e+00,  1.02504831e+00],
#        [-9.45515192e+00, -4.50042297e+00,  1.22369739e+00],
#        [-8.29737655e+00, -6.16693577e+00, -2.04848627e+00],
#        [-9.63336332e+00, -3.04305208e+00, -2.28957226e+00],
#        [-9.87302244e+00, -4.22689740e+00,  4.56627296e+00],
#        [-9.64889687e+00, -3.81582542e+00,  7.96817424e+00],
#        [-7.77701727e+00, -6.91812853e+00,  8.28456143e+00],
#        [-8.20561265e+00, -7.15110077e+00,  4.81411139e+00],
#        [-6.23177001e+00, -8.78635903e+00, -1.72803548e+00],
#        [-7.73866574e+00, -7.41171186e+00,  1.47721966e+00],
#        [-5.33130411e+00, -9.73106087e+00,  1.85315701e+00],
#        [-3.44836882e+00, -1.06035082e+01, -1.35558034e+00],
#        [-8.37903915e+00, -3.45193303e+00,  1.11966596e+01],
#        [-5.99980473e+00, -3.15251752e+00,  1.38139579e+01],
#        [-2.49765759e+00, -5.61166368e+00,  1.42454489e+01],
#        [-5.87798355e+00, -6.71749070e+00,  1.16737912e+01],
#        [-4.98634692e+00, -9.09600517e+00,  8.69516325e+00],
#        [-2.71803395e+00, -1.07766792e+01,  5.62141675e+00],
#        [-2.25904459e+00, -1.10183748e+01,  2.25098417e+00],
#        [-5.79030770e+00, -9.45968285e+00,  5.20230857e+00],
#        [-2.12269224e+00, -8.25096067e+00,  1.19870334e+01],
#        [ 1.57484546e+00, -8.04589388e+00,  1.24216507e+01],
#        [ 1.85242985e+00, -9.81204911e+00,  9.53954517e+00],
#        [-1.51636818e+00, -1.00081744e+01,  9.13453794e+00],
#        [ 6.30978980e-01, -1.11114794e+01,  6.11525887e+00],
#        [ 1.05794939e+00, -1.13766531e+01,  2.69008724e+00],
#        [ 3.15549933e+00, -1.12628127e+01, -5.13056830e-01],
#        [-2.33762061e-01, -1.14600079e+01, -9.30737633e-01],
#        [ 4.28705681e+00, -2.54328303e+00,  1.50606668e+01],
#        [ 7.24288297e+00, -2.51087264e+00,  1.30949840e+01],
#        [ 5.10717288e+00, -6.08788506e+00,  1.29842688e+01],
#        [ 1.10951205e+00, -5.40196837e+00,  1.46691064e+01],
#        [ 5.21039970e+00, -8.50221008e+00,  9.92101121e+00],
#        [ 6.86064161e+00, -8.72234281e+00,  6.74297583e+00],
#        [ 4.31004745e+00, -1.06355261e+01,  3.05087387e+00],
#        [ 3.92053972e+00, -1.03996494e+01,  6.42917964e+00],
#        [ 9.27450528e+00, -2.69366574e+00,  1.02531409e+01],
#        [ 1.03410781e+01, -3.03872383e+00,  7.01649949e+00],
#        [ 9.00952918e+00, -6.13785774e+00,  6.89368071e+00],
#        [ 7.75150518e+00, -6.02371600e+00,  1.01517694e+01],
#        [ 7.21098318e+00, -9.00982836e+00,  3.38151029e+00],
#        [ 9.37684442e+00, -6.42429548e+00,  3.55553338e+00],
#        [ 8.82767393e+00, -7.92012471e+00,  9.29746511e-02],
#        [ 6.26232421e+00, -1.00385863e+01, -1.88315493e-01],
#        [ 1.12755016e+01, -1.05608559e-02,  3.66436490e+00],
#        [ 1.15925312e+01, -1.81707545e+00,  3.02652116e-01],
#        [ 1.06041664e+01, -5.06650322e+00,  2.54313689e-01],
#        [ 1.07586397e+01, -3.33236625e+00,  3.68456179e+00]])

# %%
# #left side channels
# ch_aud_loc=[]
# for i in range(len(position)):
#      if list_1[i] == 'MEG0142+0143' or list_1[i] == 'MEG1512+1513'or list_1[i] == 'MEG1542+1543' or list_1[i] =='MEG1812+1813' or list_1[i] == 'MEG1622+1623' or list_1[i] == 'MEG1522+1523' or list_1[i] == 'MEG1612+1613'or list_1[i] == 'MEG1632+1633'or list_1[i] == 'MEG0232+0233'or list_1[i] == 'MEG0242+0243':
#         ch_aud_loc.append(i)
# ch_aud_loc

# %%
# #right side channels
# ch_aud_loc=[]
# for i in range(len(position)):
#     if list_1[i] == 'MEG2412+2413' or list_1[i] == 'MEG2222+2223'or list_1[i] == 'MEG2422+2423' or list_1[i] =='MEG2442+2443' or list_1[i] == 'MEG1432+1433' or list_1[i] == 'MEG2612+2613' or list_1[i] == 'MEG2622+2623'or list_1[i] == 'MEG2642+2643'or list_1[i] == 'MEG1332+1333'or list_1[i] == 'MEG1342+1343':
#         ch_aud_loc.append(i)
# ch_aud_loc

# %%
# #rleft and ight side channels
# ch_aud_loc=[]
# for i in range(len(position)):
#     if list_1[i] == 'MEG2412+2413' or list_1[i] == 'MEG2222+2223'or list_1[i] == 'MEG2422+2423' or list_1[i] =='MEG2442+2443' or list_1[i] == 'MEG1432+1433' or list_1[i] == 'MEG2612+2613' or list_1[i] == 'MEG2622+2623'or list_1[i] == 'MEG2642+2643'or list_1[i] == 'MEG1332+1333'or list_1[i] == 'MEG1342+1343' or list_1[i] == 'MEG0142+0143' or list_1[i] == 'MEG1512+1513'or list_1[i] == 'MEG1542+1543' or list_1[i] =='MEG1812+1813' or list_1[i] == 'MEG1622+1623' or list_1[i] == 'MEG1522+1523' or list_1[i] == 'MEG1612+1613'or list_1[i] == 'MEG1632+1633'or list_1[i] == 'MEG0232+0233'or list_1[i] == 'MEG0242+0243':
#         ch_aud_loc.append(i)
# ch_aud_loc

# %%
ch_aud=list_1

# %%
len(ch_aud)
# Out:
# 102

# %%
# position2=position[ch_aud_loc]
# position2

# %%
num_trials=0
for subject in range(len(matfiles)):
    subject_data = []
    dat = mat73.loadmat(matfiles[subject])
    data = pd.DataFrame.from_dict(dat)
    new=data.iloc[7,0]
    print(len(new))
    num_trials+=len(new)
# Out:
# 31
# 61
# 21
# 32
# 35
# 28
# 35
# 28
# 44
# 40
# 34
# 26
# 26
# 26
# 33
# 25

# %%
num_trials
# Out:
# 525

# %%
import numpy as np

# Define the size of the empty array
array_size = (num_trials, 102, 151)

# Create an empty array of zeros with the specified size
empty_array = np.zeros(array_size)

# Display the shape of the empty array
print(empty_array.shape)
# Out:
# (525, 102, 151)

# %%
empty_array.shape
# Out:
# (525, 102, 151)

# %%
import numpy as np
import pandas as pd

# Initialize an empty list to store subject data
subject_data_list = []

# Number of subjects
#num_subjects = 5


# Size of each array
array_size = (102, 201)
num_trials=0
start=0

# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject in range(len(matfiles)):
    subject_data = []
    dat = mat73.loadmat(matfiles[subject])
    data = pd.DataFrame.from_dict(dat)
    new=data.iloc[7,0]
    
    num_trials+=len(new)

    print(start)
    end=num_trials
    print(end)
    for trial1 in range(0,len(new)):
        # Simulating data for demonstration purposes
        trial=new[trial1][0:102,200:351]
        subject_data.append(trial)
        sub_data=np.array(subject_data)
        print(sub_data.shape)
    
    empty_array[start:num_trials,:,:]=sub_data
    start=num_trials
    end=num_trials
    print(empty_array.shape)
# Out:
# 0
# 31
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# (27, 102, 151)
# (28, 102, 151)
# (29, 102, 151)
# (30, 102, 151)
# (31, 102, 151)
# (525, 102, 151)
# 31
# 92
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# (27, 102, 151)
# (28, 102, 151)
# (29, 102, 151)
# (30, 102, 151)
# (31, 102, 151)
# (32, 102, 151)
# (33, 102, 151)
# (34, 102, 151)
# (35, 102, 151)
# (36, 102, 151)
# (37, 102, 151)
# (38, 102, 151)
# (39, 102, 151)
# (40, 102, 151)
# (41, 102, 151)
# (42, 102, 151)
# (43, 102, 151)
# (44, 102, 151)
# (45, 102, 151)
# (46, 102, 151)
# (47, 102, 151)
# (48, 102, 151)
# (49, 102, 151)
# (50, 102, 151)
# (51, 102, 151)
# (52, 102, 151)
# (53, 102, 151)
# (54, 102, 151)
# (55, 102, 151)
# (56, 102, 151)
# (57, 102, 151)
# (58, 102, 151)
# (59, 102, 151)
# (60, 102, 151)
# (61, 102, 151)
# (525, 102, 151)
# 92
# 113
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (525, 102, 151)
# 113
# 145
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# (27, 102, 151)
# (28, 102, 151)
# (29, 102, 151)
# (30, 102, 151)
# (31, 102, 151)
# (32, 102, 151)
# (525, 102, 151)
# 145
# 180
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# (27, 102, 151)
# (28, 102, 151)
# (29, 102, 151)
# (30, 102, 151)
# (31, 102, 151)
# (32, 102, 151)
# (33, 102, 151)
# (34, 102, 151)
# (35, 102, 151)
# (525, 102, 151)
# 180
# 208
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# (27, 102, 151)
# (28, 102, 151)
# (525, 102, 151)
# 208
# 243
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# (27, 102, 151)
# (28, 102, 151)
# (29, 102, 151)
# (30, 102, 151)
# (31, 102, 151)
# (32, 102, 151)
# (33, 102, 151)
# (34, 102, 151)
# (35, 102, 151)
# (525, 102, 151)
# 243
# 271
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# (27, 102, 151)
# (28, 102, 151)
# (525, 102, 151)
# 271
# 315
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# (27, 102, 151)
# (28, 102, 151)
# (29, 102, 151)
# (30, 102, 151)
# (31, 102, 151)
# (32, 102, 151)
# (33, 102, 151)
# (34, 102, 151)
# (35, 102, 151)
# (36, 102, 151)
# (37, 102, 151)
# (38, 102, 151)
# (39, 102, 151)
# (40, 102, 151)
# (41, 102, 151)
# (42, 102, 151)
# (43, 102, 151)
# (44, 102, 151)
# (525, 102, 151)
# 315
# 355
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# (27, 102, 151)
# (28, 102, 151)
# (29, 102, 151)
# (30, 102, 151)
# (31, 102, 151)
# (32, 102, 151)
# (33, 102, 151)
# (34, 102, 151)
# (35, 102, 151)
# (36, 102, 151)
# (37, 102, 151)
# (38, 102, 151)
# (39, 102, 151)
# (40, 102, 151)
# (525, 102, 151)
# 355
# 389
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# (27, 102, 151)
# (28, 102, 151)
# (29, 102, 151)
# (30, 102, 151)
# (31, 102, 151)
# (32, 102, 151)
# (33, 102, 151)
# (34, 102, 151)
# (525, 102, 151)
# 389
# 415
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# (525, 102, 151)
# 415
# 441
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# (525, 102, 151)
# 441
# 467
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# (525, 102, 151)
# 467
# 500
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# (27, 102, 151)
# (28, 102, 151)
# (29, 102, 151)
# (30, 102, 151)
# (31, 102, 151)
# (32, 102, 151)
# (33, 102, 151)
# (525, 102, 151)
# 500
# 525
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (525, 102, 151)

# %%
aud_data=empty_array[:,:,:]
print(aud_data)
# Out:
# [[[2.52651669e-12 2.47600476e-12 2.39582113e-12 ... 4.87943089e-12
#    5.24331335e-12 5.53127524e-12]
#   [3.00274355e-12 3.06934650e-12 3.06917920e-12 ... 7.00144127e-12
#    7.21571077e-12 7.33876674e-12]
#   [4.60371772e-12 4.85297196e-12 5.14311980e-12 ... 5.15999249e-12
#    5.89760516e-12 6.59613941e-12]
#   ...
#   [2.51959351e-12 2.43530450e-12 2.28739941e-12 ... 2.10148503e-12
#    2.29641088e-12 2.42910050e-12]
#   [3.71650909e-13 7.57128257e-13 1.16042836e-12 ... 2.75861843e-12
#    2.94515765e-12 3.09937576e-12]
#   [3.23381437e-12 3.19679950e-12 3.10008145e-12 ... 1.51949197e-12
#    1.82265921e-12 2.09418933e-12]]
#
#  [[2.46599728e-12 2.40724851e-12 2.35484571e-12 ... 2.40537979e-12
#    2.82981085e-12 3.38114018e-12]
#   [4.26617941e-12 4.26770867e-12 4.28197451e-12 ... 2.95341723e-12
#    2.91405728e-12 2.90021981e-12]
#   [4.45670133e-12 4.78947119e-12 5.01931613e-12 ... 5.46739117e-13
#    3.82075581e-13 2.53107341e-13]
#   ...
#   [3.62459995e-12 4.16875426e-12 4.69889657e-12 ... 1.22666552e-12
#    1.58744673e-12 1.97482153e-12]
#   [3.56427500e-12 3.00664726e-12 2.55049221e-12 ... 1.48100710e-12
#    1.86761457e-12 2.22527379e-12]
#   [1.05172082e-11 1.01836008e-11 9.79076862e-12 ... 3.80316358e-12
#    3.52291199e-12 3.25319703e-12]]
#
#  [[2.53658011e-12 2.59917103e-12 2.68875890e-12 ... 3.37750897e-12
#    3.61178371e-12 3.80388794e-12]
#   [1.16964860e-12 1.08976424e-12 9.60778891e-13 ... 2.08653897e-12
#    2.10033025e-12 2.10340706e-12]
#   [2.58617100e-12 3.02681103e-12 3.49243561e-12 ... 1.75731821e-12
#    1.86361370e-12 1.98659282e-12]
#   ...
#   [3.84779830e-12 3.68989426e-12 3.57218602e-12 ... 3.44924964e-12
#    3.75878782e-12 4.02652652e-12]
#   [5.20813351e-12 5.80655096e-12 6.37446591e-12 ... 1.72699425e-12
#    1.09336155e-12 5.06854731e-13]
#   [9.64869196e-12 1.01996288e-11 1.07223659e-11 ... 5.28278418e-12
#    5.53211670e-12 5.75780437e-12]]
#
#  ...
#
#  [[4.47228042e-12 4.61833103e-12 4.74720588e-12 ... 2.60622603e-12
#    2.39267500e-12 2.31626998e-12]
#   [3.37893231e-12 3.10649278e-12 2.82958995e-12 ... 4.24365264e-12
#    3.97035627e-12 3.68351285e-12]
#   [4.35226282e-12 4.11195182e-12 3.79185053e-12 ... 3.68778274e-12
#    3.77677225e-12 3.82392704e-12]
#   ...
#   [5.11844575e-12 5.37604387e-12 5.55483006e-12 ... 9.40869981e-12
#    9.11001538e-12 8.68403349e-12]
#   [7.52448732e-12 8.04847964e-12 8.42766951e-12 ... 1.01848428e-11
#    9.76744526e-12 9.27365300e-12]
#   [1.02369286e-11 1.04932823e-11 1.07012757e-11 ... 9.22685765e-12
#    9.23943061e-12 9.19023013e-12]]
#
#  [[6.27998988e-12 6.24373514e-12 6.09928306e-12 ... 3.10454518e-12
#    2.91667460e-12 2.78107949e-12]
#   [2.57956155e-12 2.70008107e-12 2.75949017e-12 ... 2.00226808e-12
#    1.61457483e-12 1.17514735e-12]
#   [8.89461582e-12 9.13522418e-12 9.26679433e-12 ... 2.35503136e-12
#    2.55691886e-12 2.78716313e-12]
#   ...
#   [3.93586393e-12 3.61936883e-12 3.30212529e-12 ... 2.44074116e-12
#    1.90355873e-12 1.37649078e-12]
#   [2.11775848e-12 1.62952792e-12 1.22089436e-12 ... 2.25614133e-12
#    1.35138548e-12 4.88796468e-13]
#   [2.67040928e-12 2.46225151e-12 2.24743334e-12 ... 3.29541817e-12
#    3.15635021e-12 3.02895415e-12]]
#
#  [[2.62768772e-12 2.70666259e-12 2.76639241e-12 ... 5.65140871e-12
#    5.68946318e-12 5.70478646e-12]
#   [7.10364545e-12 7.10064288e-12 7.07644258e-12 ... 5.28600901e-12
#    5.73176173e-12 6.18094432e-12]
#   [3.20901760e-12 3.30751323e-12 3.34918025e-12 ... 9.46112585e-12
#    9.24638776e-12 9.01504209e-12]
#   ...
#   [2.95469394e-12 3.14089371e-12 3.33744630e-12 ... 5.52812853e-12
#    5.86487833e-12 6.21565875e-12]
#   [3.25378883e-12 3.46293984e-12 3.66172937e-12 ... 7.91371949e-13
#    1.98555475e-13 5.47788457e-13]
#   [6.33794683e-12 6.43108472e-12 6.55417434e-12 ... 5.60082960e-12
#    6.74695853e-12 7.85498573e-12]]]

# %%
# # Selecting rows based on indices
# aud_data = empty_array[:, ch_aud_loc, :]

# # Printing the dimensions of the final array
# print(aud_data.shape)

# %%
n_channels_aud = len(aud_data[1,:,1])
n_channels_aud
# Out:
# 102

# %%
# ch_aud=list_1
# print(len(ch_aud))

# %%
# #left side channels
#  #   tfa on selected auditory channels of the brain
# ch_aud=['MEG0142+0143', 'MEG1512+1513','MEG1542+1543','MEG1812+1813', 'MEG1622+1623' ,'MEG1522+1523','MEG1612+1613','MEG1632+1633','MEG0232+0233','MEG0242+0243']

# %%
# #right side channels
# #tfa on selected auditory channels of the brain
# ch_aud=['MEG2412+2413','MEG2222+2223','MEG2422+2423','MEG2442+2443','MEG1432+1433','MEG2612+2613','MEG2622+2623','MEG2642+2643','MEG1332+1333','MEG1342+1343']

# %%
# #right side channels
# #tfa on selected auditory channels of the brain
# ch_aud=['MEG2412+2413','MEG2222+2223','MEG2422+2423','MEG2442+2443','MEG1432+1433','MEG2612+2613','MEG2622+2623','MEG2642+2643','MEG1332+1333','MEG1342+1343','MEG0142+0143', 'MEG1512+1513','MEG1542+1543','MEG1812+1813', 'MEG1622+1623' ,'MEG1522+1523','MEG1612+1613','MEG1632+1633','MEG0232+0233','MEG0242+0243']

# %%
sfreq = 1000

# %%
#n_channels = len(trials_sub[1,:,1])

# Initialize an info structure
info = mne.create_info(
        ch_names = ch_aud,
        ch_types = ['grad']*n_channels_aud,
        sfreq    = sfreq 
        )

# %%
# for i in range(len(position2)):
#     info['chs'][i]['loc'][:3]=position2[i,:]

# %%
for i in range(len(position)):
    info['chs'][i]['loc'][:3]=position[i,:]

# %%
import numpy as np
import mne
import matplotlib
matplotlib.use('Qt5Agg')
# or 'Qt4Agg' depending on your system and Matplotlib version
import os
import matplotlib.pyplot as plt

directory='D:/internship_ulster_university/figures/erp_1st_click_healthy_all_channels/'



# Assume you have a list of trial counts for each subject
trial_counts = [31, 61, 21,32,35,28,35,28,44,40,34,26,26,26,33,25]
#trial_counts = [45,34,39,44,44]

# Create an empty list to store evoked objects for each subject
evoked_list = []

# Loop through subjects
for subject_idx, trials in enumerate(trial_counts):
    # Extract data for the current subject
    subject_data = aud_data[:trials, :, :]  # Adjusted time range
    print(subject_data.shape)
    
    # Compute the average across trials for the current subject
    average_data = np.mean(subject_data, axis=0)
    
    # Create Evoked object for the current subject with time information
    evoked = mne.EvokedArray(average_data, info)  # Adjusted time range
    evoked_list.append(evoked)

grand_average_healthy = mne.grand_average(evoked_list)

# Plot the grand average
fig=grand_average_healthy.plot()
# fig.axes[0].set_ylim(data_min, data_max)
# Set xlabel and ylabel
fig.axes[0].set_xlabel('Time (s)')
fig.axes[0].set_ylabel('Amplitude (pT)')

    
fig.suptitle(f'ERP - ALL Channels')

fig.show()
fig.patch.set_facecolor('white')
   
# Save the figure with the specified filename
filename = "all channels.png"
filepath = os.path.join(directory, filename)
fig.savefig(filepath)
plt.close(fig)  # Close the figure to release memory

ylim = fig.axes[0].get_ylim()

# Plot the ERP for each channel separately
for ch_idx in range(len(info['ch_names'])):
    fig=grand_average_healthy.plot(picks=ch_aud[ch_idx], show=False)
    
    
    # Set y-axis limits to match the first plot
    fig.axes[0].set_ylim(ylim)
    
    fig.axes[0].set_xlabel('Time (s)')
    fig.axes[0].set_ylabel('Amplitude (pT)')

    
        # Plot PSD for the current channel
    fig.suptitle(f'ERP - Channel {ch_aud[ch_idx]}')

    # Optional: Save the plot
    # fig.savefig(f'psd_channel_{ch_name}.png')

    # Show the plot
    fig.show()
    fig.patch.set_facecolor('white')
   
   # Save the figure with the specified filename
    filename = f"channel_{ch_aud[ch_idx]}.png"
    filepath = os.path.join(directory, filename)
    fig.savefig(filepath)
    plt.close(fig)  # Close the figure to release memory
# Out:
# (31, 102, 151)
# (61, 102, 151)
# (21, 102, 151)
# (32, 102, 151)
# (35, 102, 151)
# (28, 102, 151)
# (35, 102, 151)
# (28, 102, 151)
# (44, 102, 151)
# (40, 102, 151)
# (34, 102, 151)
# (26, 102, 151)
# (26, 102, 151)
# (26, 102, 151)
# (33, 102, 151)
# (25, 102, 151)
# Identifying common channels ...
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.

# %%
import os
import glob


# Construct the path to the target folder
folder_path2 = "D:\internship_ulster_university\preprocessed_filtered_eyes_closed_healthy"

# Move into the target folder
os.chdir(folder_path2)

# Select all files ending with ".mat"
mat_files_rs = glob.glob("*.mat")

# Print the list of selected files
print("Selected .mat files:")
for file in mat_files_rs:
    print(file)
# Out:
# Selected .mat files:
# PreProcessed_AD001_Preprocessed_EC.mat
# PreProcessed_AD002_Preprocessed_EC.mat
# PreProcessed_AD003_Preprocessed_EC.mat
# PreProcessed_AD004_Preprocessed_EC.mat
# PreProcessed_AD006_Preprocessed_EC.mat
# PreProcessed_AD008_Preprocessed_EC.mat
# PreProcessed_AD010_Preprocessed_EC.mat
# PreProcessed_AD011_Preprocessed_EC.mat
# PreProcessed_AD012_Preprocessed_EC.mat
# PreProcessed_AD013_Preprocessed_EC.mat
# PreProcessed_AD014_Preprocessed_EC.mat
# PreProcessed_AD015_Preprocessed_EC.mat
# PreProcessed_AD016_Preprocessed_EC.mat
# PreProcessed_AD017_Preprocessed_EC.mat
# PreProcessed_AD018_Preprocessed_EC.mat
# PreProcessed_AD020_Preprocessed_EC.mat

# %%
num_trials_rs_ec=0
for subject in range(len(mat_files_rs)):
    subject_data_rs_es = []
    dat_rs_ec = mat73.loadmat(mat_files_rs[subject])
    data_rs_ec = pd.DataFrame.from_dict(dat_rs_ec)
    new_rs_ec=data_rs_ec.iloc[6,0]
    print(len(new_rs_ec))
    num_trials_rs_ec+=len(new_rs_ec)
# Out:
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16

# %%
import numpy as np

# Define the size of the empty array
array_size_rs_ec = (num_trials_rs_ec, 102, 9901)

# Create an empty array of zeros with the specified size
empty_array_rs_ec = np.zeros(array_size_rs_ec)

# Display the shape of the empty array
print(empty_array_rs_ec.shape)
# Out:
# (256, 102, 9901)

# %%
# Number of subjects
num_subjects = 5
trial_counts=[]

# Size of each array
array_size = (102, 401)
num_trials=0
start=0
num_actual_trials=0

# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject in range(len(mat_files_rs)):
    
    dat = mat73.loadmat(mat_files_rs[subject])
    data = pd.DataFrame.from_dict(dat)
    new=data.iloc[6,0]
    
    num_trials+=len(new)

    print(start)
    end=num_trials-num_actual_trials
    print(end)
    trial_counts.append(num_actual_trials)
  
    subject_data = []
    for trial1 in range(0,len(new)):
        # Simulating data for demonstration purposes
        trial=new[trial1][0:102,:9901]
        
        num_actual_trials=num_actual_trials+1
        print("nu actual")
        print(num_actual_trials)
        subject_data.append(trial)
        #print(subject_data)
        sub_data=np.array(subject_data)
        print(sub_data.shape)
    
    empty_array_rs_ec[start:num_actual_trials,:,:]=sub_data
    start=num_actual_trials
    end=num_actual_trials
    print(empty_array_rs_ec.shape)
# Out:
# 0
# 16
# nu actual
# 1
# (1, 102, 9901)
# nu actual
# 2
# (2, 102, 9901)
# nu actual
# 3
# (3, 102, 9901)
# nu actual
# 4
# (4, 102, 9901)
# nu actual
# 5
# (5, 102, 9901)
# nu actual
# 6
# (6, 102, 9901)
# nu actual
# 7
# (7, 102, 9901)
# nu actual
# 8
# (8, 102, 9901)
# nu actual
# 9
# (9, 102, 9901)
# nu actual
# 10
# (10, 102, 9901)
# nu actual
# 11
# (11, 102, 9901)
# nu actual
# 12
# (12, 102, 9901)
# nu actual
# 13
# (13, 102, 9901)
# nu actual
# 14
# (14, 102, 9901)
# nu actual
# 15
# (15, 102, 9901)
# nu actual
# 16
# (16, 102, 9901)
# (256, 102, 9901)
# 16
# 16
# nu actual
# 17
# (1, 102, 9901)
# nu actual
# 18
# (2, 102, 9901)
# nu actual
# 19
# (3, 102, 9901)
# nu actual
# 20
# (4, 102, 9901)
# nu actual
# 21
# (5, 102, 9901)
# nu actual
# 22
# (6, 102, 9901)
# nu actual
# 23
# (7, 102, 9901)
# nu actual
# 24
# (8, 102, 9901)
# nu actual
# 25
# (9, 102, 9901)
# nu actual
# 26
# (10, 102, 9901)
# nu actual
# 27
# (11, 102, 9901)
# nu actual
# 28
# (12, 102, 9901)
# nu actual
# 29
# (13, 102, 9901)
# nu actual
# 30
# (14, 102, 9901)
# nu actual
# 31
# (15, 102, 9901)
# nu actual
# 32
# (16, 102, 9901)
# (256, 102, 9901)
# 32
# 16
# nu actual
# 33
# (1, 102, 9901)
# nu actual
# 34
# (2, 102, 9901)
# nu actual
# 35
# (3, 102, 9901)
# nu actual
# 36
# (4, 102, 9901)
# nu actual
# 37
# (5, 102, 9901)
# nu actual
# 38
# (6, 102, 9901)
# nu actual
# 39
# (7, 102, 9901)
# nu actual
# 40
# (8, 102, 9901)
# nu actual
# 41
# (9, 102, 9901)
# nu actual
# 42
# (10, 102, 9901)
# nu actual
# 43
# (11, 102, 9901)
# nu actual
# 44
# (12, 102, 9901)
# nu actual
# 45
# (13, 102, 9901)
# nu actual
# 46
# (14, 102, 9901)
# nu actual
# 47
# (15, 102, 9901)
# nu actual
# 48
# (16, 102, 9901)
# (256, 102, 9901)
# 48
# 16
# nu actual
# 49
# (1, 102, 9901)
# nu actual
# 50
# (2, 102, 9901)
# nu actual
# 51
# (3, 102, 9901)
# nu actual
# 52
# (4, 102, 9901)
# nu actual
# 53
# (5, 102, 9901)
# nu actual
# 54
# (6, 102, 9901)
# nu actual
# 55
# (7, 102, 9901)
# nu actual
# 56
# (8, 102, 9901)
# nu actual
# 57
# (9, 102, 9901)
# nu actual
# 58
# (10, 102, 9901)
# nu actual
# 59
# (11, 102, 9901)
# nu actual
# 60
# (12, 102, 9901)
# nu actual
# 61
# (13, 102, 9901)
# nu actual
# 62
# (14, 102, 9901)
# nu actual
# 63
# (15, 102, 9901)
# nu actual
# 64
# (16, 102, 9901)
# (256, 102, 9901)
# 64
# 16
# nu actual
# 65
# (1, 102, 9901)
# nu actual
# 66
# (2, 102, 9901)
# nu actual
# 67
# (3, 102, 9901)
# nu actual
# 68
# (4, 102, 9901)
# nu actual
# 69
# (5, 102, 9901)
# nu actual
# 70
# (6, 102, 9901)
# nu actual
# 71
# (7, 102, 9901)
# nu actual
# 72
# (8, 102, 9901)
# nu actual
# 73
# (9, 102, 9901)
# nu actual
# 74
# (10, 102, 9901)
# nu actual
# 75
# (11, 102, 9901)
# nu actual
# 76
# (12, 102, 9901)
# nu actual
# 77
# (13, 102, 9901)
# nu actual
# 78
# (14, 102, 9901)
# nu actual
# 79
# (15, 102, 9901)
# nu actual
# 80
# (16, 102, 9901)
# (256, 102, 9901)
# 80
# 16
# nu actual
# 81
# (1, 102, 9901)
# nu actual
# 82
# (2, 102, 9901)
# nu actual
# 83
# (3, 102, 9901)
# nu actual
# 84
# (4, 102, 9901)
# nu actual
# 85
# (5, 102, 9901)
# nu actual
# 86
# (6, 102, 9901)
# nu actual
# 87
# (7, 102, 9901)
# nu actual
# 88
# (8, 102, 9901)
# nu actual
# 89
# (9, 102, 9901)
# nu actual
# 90
# (10, 102, 9901)
# nu actual
# 91
# (11, 102, 9901)
# nu actual
# 92
# (12, 102, 9901)
# nu actual
# 93
# (13, 102, 9901)
# nu actual
# 94
# (14, 102, 9901)
# nu actual
# 95
# (15, 102, 9901)
# nu actual
# 96
# (16, 102, 9901)
# (256, 102, 9901)
# 96
# 16
# nu actual
# 97
# (1, 102, 9901)
# nu actual
# 98
# (2, 102, 9901)
# nu actual
# 99
# (3, 102, 9901)
# nu actual
# 100
# (4, 102, 9901)
# nu actual
# 101
# (5, 102, 9901)
# nu actual
# 102
# (6, 102, 9901)
# nu actual
# 103
# (7, 102, 9901)
# nu actual
# 104
# (8, 102, 9901)
# nu actual
# 105
# (9, 102, 9901)
# nu actual
# 106
# (10, 102, 9901)
# nu actual
# 107
# (11, 102, 9901)
# nu actual
# 108
# (12, 102, 9901)
# nu actual
# 109
# (13, 102, 9901)
# nu actual
# 110
# (14, 102, 9901)
# nu actual
# 111
# (15, 102, 9901)
# nu actual
# 112
# (16, 102, 9901)
# (256, 102, 9901)
# 112
# 16
# nu actual
# 113
# (1, 102, 9901)
# nu actual
# 114
# (2, 102, 9901)
# nu actual
# 115
# (3, 102, 9901)
# nu actual
# 116
# (4, 102, 9901)
# nu actual
# 117
# (5, 102, 9901)
# nu actual
# 118
# (6, 102, 9901)
# nu actual
# 119
# (7, 102, 9901)
# nu actual
# 120
# (8, 102, 9901)
# nu actual
# 121
# (9, 102, 9901)
# nu actual
# 122
# (10, 102, 9901)
# nu actual
# 123
# (11, 102, 9901)
# nu actual
# 124
# (12, 102, 9901)
# nu actual
# 125
# (13, 102, 9901)
# nu actual
# 126
# (14, 102, 9901)
# nu actual
# 127
# (15, 102, 9901)
# nu actual
# 128
# (16, 102, 9901)
# (256, 102, 9901)
# 128
# 16
# nu actual
# 129
# (1, 102, 9901)
# nu actual
# 130
# (2, 102, 9901)
# nu actual
# 131
# (3, 102, 9901)
# nu actual
# 132
# (4, 102, 9901)
# nu actual
# 133
# (5, 102, 9901)
# nu actual
# 134
# (6, 102, 9901)
# nu actual
# 135
# (7, 102, 9901)
# nu actual
# 136
# (8, 102, 9901)
# nu actual
# 137
# (9, 102, 9901)
# nu actual
# 138
# (10, 102, 9901)
# nu actual
# 139
# (11, 102, 9901)
# nu actual
# 140
# (12, 102, 9901)
# nu actual
# 141
# (13, 102, 9901)
# nu actual
# 142
# (14, 102, 9901)
# nu actual
# 143
# (15, 102, 9901)
# nu actual
# 144
# (16, 102, 9901)
# (256, 102, 9901)
# 144
# 16
# nu actual
# 145
# (1, 102, 9901)
# nu actual
# 146
# (2, 102, 9901)
# nu actual
# 147
# (3, 102, 9901)
# nu actual
# 148
# (4, 102, 9901)
# nu actual
# 149
# (5, 102, 9901)
# nu actual
# 150
# (6, 102, 9901)
# nu actual
# 151
# (7, 102, 9901)
# nu actual
# 152
# (8, 102, 9901)
# nu actual
# 153
# (9, 102, 9901)
# nu actual
# 154
# (10, 102, 9901)
# nu actual
# 155
# (11, 102, 9901)
# nu actual
# 156
# (12, 102, 9901)
# nu actual
# 157
# (13, 102, 9901)
# nu actual
# 158
# (14, 102, 9901)
# nu actual
# 159
# (15, 102, 9901)
# nu actual
# 160
# (16, 102, 9901)
# (256, 102, 9901)
# 160
# 16
# nu actual
# 161
# (1, 102, 9901)
# nu actual
# 162
# (2, 102, 9901)
# nu actual
# 163
# (3, 102, 9901)
# nu actual
# 164
# (4, 102, 9901)
# nu actual
# 165
# (5, 102, 9901)
# nu actual
# 166
# (6, 102, 9901)
# nu actual
# 167
# (7, 102, 9901)
# nu actual
# 168
# (8, 102, 9901)
# nu actual
# 169
# (9, 102, 9901)
# nu actual
# 170
# (10, 102, 9901)
# nu actual
# 171
# (11, 102, 9901)
# nu actual
# 172
# (12, 102, 9901)
# nu actual
# 173
# (13, 102, 9901)
# nu actual
# 174
# (14, 102, 9901)
# nu actual
# 175
# (15, 102, 9901)
# nu actual
# 176
# (16, 102, 9901)
# (256, 102, 9901)
# 176
# 16
# nu actual
# 177
# (1, 102, 9901)
# nu actual
# 178
# (2, 102, 9901)
# nu actual
# 179
# (3, 102, 9901)
# nu actual
# 180
# (4, 102, 9901)
# nu actual
# 181
# (5, 102, 9901)
# nu actual
# 182
# (6, 102, 9901)
# nu actual
# 183
# (7, 102, 9901)
# nu actual
# 184
# (8, 102, 9901)
# nu actual
# 185
# (9, 102, 9901)
# nu actual
# 186
# (10, 102, 9901)
# nu actual
# 187
# (11, 102, 9901)
# nu actual
# 188
# (12, 102, 9901)
# nu actual
# 189
# (13, 102, 9901)
# nu actual
# 190
# (14, 102, 9901)
# nu actual
# 191
# (15, 102, 9901)
# nu actual
# 192
# (16, 102, 9901)
# (256, 102, 9901)
# 192
# 16
# nu actual
# 193
# (1, 102, 9901)
# nu actual
# 194
# (2, 102, 9901)
# nu actual
# 195
# (3, 102, 9901)
# nu actual
# 196
# (4, 102, 9901)
# nu actual
# 197
# (5, 102, 9901)
# nu actual
# 198
# (6, 102, 9901)
# nu actual
# 199
# (7, 102, 9901)
# nu actual
# 200
# (8, 102, 9901)
# nu actual
# 201
# (9, 102, 9901)
# nu actual
# 202
# (10, 102, 9901)
# nu actual
# 203
# (11, 102, 9901)
# nu actual
# 204
# (12, 102, 9901)
# nu actual
# 205
# (13, 102, 9901)
# nu actual
# 206
# (14, 102, 9901)
# nu actual
# 207
# (15, 102, 9901)
# nu actual
# 208
# (16, 102, 9901)
# (256, 102, 9901)
# 208
# 16
# nu actual
# 209
# (1, 102, 9901)
# nu actual
# 210
# (2, 102, 9901)
# nu actual
# 211
# (3, 102, 9901)
# nu actual
# 212
# (4, 102, 9901)
# nu actual
# 213
# (5, 102, 9901)
# nu actual
# 214
# (6, 102, 9901)
# nu actual
# 215
# (7, 102, 9901)
# nu actual
# 216
# (8, 102, 9901)
# nu actual
# 217
# (9, 102, 9901)
# nu actual
# 218
# (10, 102, 9901)
# nu actual
# 219
# (11, 102, 9901)
# nu actual
# 220
# (12, 102, 9901)
# nu actual
# 221
# (13, 102, 9901)
# nu actual
# 222
# (14, 102, 9901)
# nu actual
# 223
# (15, 102, 9901)
# nu actual
# 224
# (16, 102, 9901)
# (256, 102, 9901)
# 224
# 16
# nu actual
# 225
# (1, 102, 9901)
# nu actual
# 226
# (2, 102, 9901)
# nu actual
# 227
# (3, 102, 9901)
# nu actual
# 228
# (4, 102, 9901)
# nu actual
# 229
# (5, 102, 9901)
# nu actual
# 230
# (6, 102, 9901)
# nu actual
# 231
# (7, 102, 9901)
# nu actual
# 232
# (8, 102, 9901)
# nu actual
# 233
# (9, 102, 9901)
# nu actual
# 234
# (10, 102, 9901)
# nu actual
# 235
# (11, 102, 9901)
# nu actual
# 236
# (12, 102, 9901)
# nu actual
# 237
# (13, 102, 9901)
# nu actual
# 238
# (14, 102, 9901)
# nu actual
# 239
# (15, 102, 9901)
# nu actual
# 240
# (16, 102, 9901)
# (256, 102, 9901)
# 240
# 16
# nu actual
# 241
# (1, 102, 9901)
# nu actual
# 242
# (2, 102, 9901)
# nu actual
# 243
# (3, 102, 9901)
# nu actual
# 244
# (4, 102, 9901)
# nu actual
# 245
# (5, 102, 9901)
# nu actual
# 246
# (6, 102, 9901)
# nu actual
# 247
# (7, 102, 9901)
# nu actual
# 248
# (8, 102, 9901)
# nu actual
# 249
# (9, 102, 9901)
# nu actual
# 250
# (10, 102, 9901)
# nu actual
# 251
# (11, 102, 9901)
# nu actual
# 252
# (12, 102, 9901)
# nu actual
# 253
# (13, 102, 9901)
# nu actual
# 254
# (14, 102, 9901)
# nu actual
# 255
# (15, 102, 9901)
# nu actual
# 256
# (16, 102, 9901)
# (256, 102, 9901)

# %%
# # Selecting rows based on indices
# aud_data_rsec = empty_array_rs_ec[:, ch_aud_loc, :]

# # Printing the dimensions of the final array
# print(aud_data_rsec.shape)

# %%
aud_data_rsec = empty_array_rs_ec[:,:,:]
print(aud_data_rsec.shape)
# Out:
# (256, 102, 9901)

# %%
tr_counts=[16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16]
#tr_counts=[16,16,16,16]
tr_counts
# Out:
# [16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16]

# %%
import numpy as np
import mne
import matplotlib
matplotlib.use('Qt5Agg')  # or 'Qt4Agg' depending on your system and Matplotlib version

directory='D:/internship_ulster_university/figures/erp_resting_state_eyes_closed_healthy_all_channels/'



# Create an empty list to store evoked objects for each subject
evoked_list_rs_ec = []

# Loop through subjects
for subject_idx, trials in enumerate(tr_counts):
    # Extract data for the current subject
    subject_data_rsec= aud_data_rsec[:trials, :, :]
    
    # Compute the average across trials for the current subject
    average_data_rsec = np.mean(subject_data_rsec, axis=0)
    
    
    # Create Evoked object for the current subject
    evoked_rsec = mne.EvokedArray(average_data_rsec, info)
    
    # Append the Evoked object to the list
    evoked_list_rs_ec.append(evoked_rsec)

# Compute the grand average across subjects
grand_average_rsec_healthy = mne.grand_average(evoked_list_rs_ec)


# Plot the grand average
fig=grand_average_rsec_healthy.plot()


fig.axes[0].set_xlabel('Time (s)')
fig.axes[0].set_ylabel('Amplitude (pT)')

 
fig.suptitle(f'ERP - ALL Channels')

fig.show()
fig.patch.set_facecolor('white')
   
# Save the figure with the specified filename
filename = "all channels resting state eyes closed.png"
filepath = os.path.join(directory, filename)
fig.savefig(filepath)
plt.close(fig)  # Close the figure to release memory

ylim = fig.axes[0].get_ylim()

# Plot the ERP for each channel separately
for ch_idx in range(len(info['ch_names'])):
    fig=grand_average_rsec_healthy.plot(picks=ch_aud[ch_idx], show=False)
    
    
    fig.axes[0].set_ylim(ylim)
    fig.axes[0].set_xlabel('Time (s)')
    fig.axes[0].set_ylabel('Amplitude (pT)')

        # Plot PSD for the current channel
    fig.suptitle(f'ERP - Channel {ch_aud[ch_idx]}')

    # Optional: Save the plot
    # fig.savefig(f'psd_channel_{ch_name}.png')

    # Show the plot
    fig.show()
    fig.patch.set_facecolor('white')
   
   # Save the figure with the specified filename
    filename = f"channel_{ch_aud[ch_idx]}.png"
    filepath = os.path.join(directory, filename)
    fig.savefig(filepath)
    plt.close(fig)  # Close the figure to release memory
# Out:
# Identifying common channels ...
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.

# %% [markdown]
# # Eyes closed data

# %%
plt.close()

# %%
ch_aud=list_1

# %%
len(ch_aud)
# Out:
# 102

# %%
import os
import glob


# Construct the path to the target folder
folder_path = "D:\internship_ulster_university\preprocessed_filtered_eyes_closed"

# Move into the target folder
os.chdir(folder_path)

# Select all files ending with ".mat"
matfiles_rsec = glob.glob("*.mat")

# Print the list of selected files
print("Selected .mat files:")
for file in matfiles_rsec:
    print(file)
# Out:
# Selected .mat files:
# PreProcessed_AD001_Preprocessed_EC.mat
# PreProcessed_AD002_Preprocessed_EC.mat
# PreProcessed_AD003_Preprocessed_EC.mat
# PreProcessed_AD004_Preprocessed_EC.mat
# PreProcessed_AD006_Preprocessed_EC.mat
# PreProcessed_AD008_Preprocessed_EC.mat
# PreProcessed_AD010_Preprocessed_EC.mat
# PreProcessed_AD011_Preprocessed_EC.mat
# PreProcessed_AD012_Preprocessed_EC.mat
# PreProcessed_AD013_Preprocessed_EC.mat
# PreProcessed_AD014_Preprocessed_EC.mat
# PreProcessed_AD015_Preprocessed_EC.mat
# PreProcessed_AD016_Preprocessed_EC.mat
# PreProcessed_AD017_Preprocessed_EC.mat
# PreProcessed_AD018_Preprocessed_EC.mat
# PreProcessed_AD020_Preprocessed_EC.mat
# PreProcessed_AD026_Preprocessed_EC.mat
# PreProcessed_AD027_Preprocessed_EC.mat
# PreProcessed_AD028_Preprocessed_EC.mat
# PreProcessed_AD030_Preprocessed_EC.mat

# %%
num_trials=0
trial_counts_rsec=[]
for subject in range(len(matfiles_rsec)):
    subject_data = []
    name=matfiles_rsec[subject]
    print(name)
    dat = mat73.loadmat(matfiles_rsec[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
#     print(new)
    trial_counts_rsec.append(len(new))
    print(len(new))
    num_trials+=len(new)
# Out:
# PreProcessed_AD001_Preprocessed_EC.mat
# 16
# PreProcessed_AD002_Preprocessed_EC.mat
# 16
# PreProcessed_AD003_Preprocessed_EC.mat
# 16
# PreProcessed_AD004_Preprocessed_EC.mat
# 16
# PreProcessed_AD006_Preprocessed_EC.mat
# 16
# PreProcessed_AD008_Preprocessed_EC.mat
# 16
# PreProcessed_AD010_Preprocessed_EC.mat
# 16
# PreProcessed_AD011_Preprocessed_EC.mat
# 16
# PreProcessed_AD012_Preprocessed_EC.mat
# 16
# PreProcessed_AD013_Preprocessed_EC.mat
# 16
# PreProcessed_AD014_Preprocessed_EC.mat
# 16
# PreProcessed_AD015_Preprocessed_EC.mat
# 16
# PreProcessed_AD016_Preprocessed_EC.mat
# 16
# PreProcessed_AD017_Preprocessed_EC.mat
# 16
# PreProcessed_AD018_Preprocessed_EC.mat
# 16
# PreProcessed_AD020_Preprocessed_EC.mat
# 16
# PreProcessed_AD026_Preprocessed_EC.mat
# 16
# PreProcessed_AD027_Preprocessed_EC.mat
# 16
# PreProcessed_AD028_Preprocessed_EC.mat
# 16
# PreProcessed_AD030_Preprocessed_EC.mat
# 16

# %%
trial_counts_rsec
# Out:
# [16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16]

# %%
list_1
# Out:
# ['MEG0112+0113',
#  'MEG0122+0123',
#  'MEG0132+0133',
#  'MEG0142+0143',
#  'MEG0212+0213',
#  'MEG0222+0223',
#  'MEG0232+0233',
#  'MEG0242+0243',
#  'MEG0312+0313',
#  'MEG0322+0323',
#  'MEG0332+0333',
#  'MEG0342+0343',
#  'MEG0412+0413',
#  'MEG0422+0423',
#  'MEG0432+0433',
#  'MEG0442+0443',
#  'MEG0512+0513',
#  'MEG0522+0523',
#  'MEG0532+0533',
#  'MEG0542+0543',
#  'MEG0612+0613',
#  'MEG0622+0623',
#  'MEG0632+0633',
#  'MEG0642+0643',
#  'MEG0712+0713',
#  'MEG0722+0723',
#  'MEG0732+0733',
#  'MEG0742+0743',
#  'MEG0812+0813',
#  'MEG0822+0823',
#  'MEG0912+0913',
#  'MEG0922+0923',
#  'MEG0932+0933',
#  'MEG0942+0943',
#  'MEG1012+1013',
#  'MEG1022+1023',
#  'MEG1032+1033',
#  'MEG1042+1043',
#  'MEG1112+1113',
#  'MEG1122+1123',
#  'MEG1132+1133',
#  'MEG1142+1143',
#  'MEG1212+1213',
#  'MEG1222+1223',
#  'MEG1232+1233',
#  'MEG1242+1243',
#  'MEG1312+1313',
#  'MEG1322+1323',
#  'MEG1332+1333',
#  'MEG1342+1343',
#  'MEG1412+1413',
#  'MEG1422+1423',
#  'MEG1432+1433',
#  'MEG1442+1443',
#  'MEG1512+1513',
#  'MEG1522+1523',
#  'MEG1532+1533',
#  'MEG1542+1543',
#  'MEG1612+1613',
#  'MEG1622+1623',
#  'MEG1632+1633',
#  'MEG1642+1643',
#  'MEG1712+1713',
#  'MEG1722+1723',
#  'MEG1732+1733',
#  'MEG1742+1743',
#  'MEG1812+1813',
#  'MEG1822+1823',
#  'MEG1832+1833',
#  'MEG1842+1843',
#  'MEG1912+1913',
#  'MEG1922+1923',
#  'MEG1932+1933',
#  'MEG1942+1943',
#  'MEG2012+2013',
#  'MEG2022+2023',
#  'MEG2032+2033',
#  'MEG2042+2043',
#  'MEG2112+2113',
#  'MEG2122+2123',
#  'MEG2132+2133',
#  'MEG2142+2143',
#  'MEG2212+2213',
#  'MEG2222+2223',
#  'MEG2232+2233',
#  'MEG2242+2243',
#  'MEG2312+2313',
#  'MEG2322+2323',
#  'MEG2332+2333',
#  'MEG2342+2343',
#  'MEG2412+2413',
#  'MEG2422+2423',
#  'MEG2432+2433',
#  'MEG2442+2443',
#  'MEG2512+2513',
#  'MEG2522+2523',
#  'MEG2532+2533',
#  'MEG2542+2543',
#  'MEG2612+2613',
#  'MEG2622+2623',
#  'MEG2632+2633',
#  'MEG2642+2643']

# %%
len(list_1)
# Out:
# 102

# %%
#n_channels = len(trials_sub[1,:,1])

# Initialize an info structure
info = mne.create_info(
        ch_names = list_1,
        ch_types = ['grad']*len(list_1),
        sfreq    = sfreq 
        )

# %%
# ch_aud_loc

# %%
# for i in range(len(position)):
#     info['chs'][i]['loc'][:3]=position[i,:]

# %%
import numpy as np
import pandas as pd

# Initialize an empty list to store subject data
subject_data_list = []

# Number of subjects
#num_subjects = 5


# Size of each array
array_size = (102, 201)
num_trials=0
start=0
raw_list_mean_rsec = []
# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject, trials in enumerate(trial_counts_rsec):
    subject_data = []
    print('subject idx is')
    print(subject)
    
    name=matfiles_rsec[subject]
    print(name)
    dat = mat73.loadmat(matfiles_rsec[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
    
    num_trials+=len(new)

    print(start)
    end=num_trials
    print(end)
    trial_data=[]
    

    for trial in range(trials):
        #print(new[0].shape[1])
        if new[0].shape[1] == 10001:
            trial_data.append(new[trial][:102,:9901])
            times = grand_average_rsec_healthy.times
            
        else:
            trial_data.append(new[trial][:102,200:351])
            times = grand_average_healthy.times
            
    # Compute the average across trials for the current subject
    average_data_healthy = np.mean(trial_data, axis=0)
    print(average_data_healthy.shape)
   # Create RawArray object for the current trial
    raw = mne.io.RawArray(average_data_healthy, info)

    # Append the Raw object to the list
    raw_list_mean_rsec.append(raw)
    print(len(raw_list_mean_rsec))
# #Concatenate Raw objects if needed
# raw_combined_mean_mci_ts = mne.concatenate_raws(raw_list_mean_mci_ts)

# print(len(raw_combined_mean_mci_ts))
# Out:
# subject idx is
# 0
# PreProcessed_AD001_Preprocessed_EC.mat
# 0
# 16
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 1
# subject idx is
# 1
# PreProcessed_AD002_Preprocessed_EC.mat
# 0
# 32
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 2
# subject idx is
# 2
# PreProcessed_AD003_Preprocessed_EC.mat
# 0
# 48
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 3
# subject idx is
# 3
# PreProcessed_AD004_Preprocessed_EC.mat
# 0
# 64
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 4
# subject idx is
# 4
# PreProcessed_AD006_Preprocessed_EC.mat
# 0
# 80
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 5
# subject idx is
# 5
# PreProcessed_AD008_Preprocessed_EC.mat
# 0
# 96
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 6
# subject idx is
# 6
# PreProcessed_AD010_Preprocessed_EC.mat
# 0
# 112
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 7
# subject idx is
# 7
# PreProcessed_AD011_Preprocessed_EC.mat
# 0
# 128
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 8
# subject idx is
# 8
# PreProcessed_AD012_Preprocessed_EC.mat
# 0
# 144
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 9
# subject idx is
# 9
# PreProcessed_AD013_Preprocessed_EC.mat
# 0
# 160
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 10
# subject idx is
# 10
# PreProcessed_AD014_Preprocessed_EC.mat
# 0
# 176
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 11
# subject idx is
# 11
# PreProcessed_AD015_Preprocessed_EC.mat
# 0
# 192
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 12
# subject idx is
# 12
# PreProcessed_AD016_Preprocessed_EC.mat
# 0
# 208
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 13
# subject idx is
# 13
# PreProcessed_AD017_Preprocessed_EC.mat
# 0
# 224
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 14
# subject idx is
# 14
# PreProcessed_AD018_Preprocessed_EC.mat
# 0
# 240
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 15
# subject idx is
# 15
# PreProcessed_AD020_Preprocessed_EC.mat
# 0
# 256
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 16
# subject idx is
# 16
# PreProcessed_AD026_Preprocessed_EC.mat
# 0
# 272
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 17
# subject idx is
# 17
# PreProcessed_AD027_Preprocessed_EC.mat
# 0
# 288
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 18
# subject idx is
# 18
# PreProcessed_AD028_Preprocessed_EC.mat
# 0
# 304
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 19
# subject idx is
# 19
# PreProcessed_AD030_Preprocessed_EC.mat
# 0
# 320
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 20

# %%
raw_list_mean_rsec
# Out:
# [<RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>]

# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import kurtosis

features_psd_rsec = []
for raw in raw_list_mean_rsec:
    # Compute PSD
    psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
    #psd_spectrum_healthy = raw.compute_psd(method='multitaper', fmin=0, fmax=40, tmin=None, tmax=None)
    print(psd_spectrum_healthy.shape)
    
    
    features=[]
    for idx, ch_name in enumerate(list_1):
        psd_data = psd_spectrum_healthy[idx]  # PSD data for the current channel
        print('current channel is')
        print(ch_name)

    # Statistical Features
        mean_power = np.mean(psd_data)
        variance_power = np.var(psd_data)
    
        skewness_power = stats.skew(psd_data)
        kurtosis_power = stats.kurtosis(psd_data)
        freqs = psd_spectrum_healthy.freqs  # Frequency values
        max_power_freq = freqs[np.argmax(psd_data)]
        max_power = np.max(psd_data)
        band_power_alpha = np.sum(psd_data[:,(freqs >= 8) & (freqs <= 13)])  # Alpha band
        band_power_beta = np.sum(psd_data[:,(freqs >= 13) & (freqs <= 30)])  # Beta band
        
                    # Compute entropy for alpha band
        alpha_prob = psd_data[:,(freqs >= alpha_band[0]) & (freqs <= alpha_band[1])] / np.sum(psd_data)
        spectral_entropy_alpha = -np.sum(alpha_prob * np.log2(alpha_prob + 1e-12))  # Add a small value to avoid log(0)

        # Compute entropy for beta band
        beta_prob = psd_data[:,(freqs >= beta_band[0]) & (freqs <= beta_band[1])] / np.sum(psd_data)
        spectral_entropy_beta = -np.sum(beta_prob * np.log2(beta_prob + 1e-12))  # Add a small value to avoid log(0)

        
 
        # Append features for the current channel
        channel_features = [mean_power, variance_power, skewness_power, kurtosis_power,
                            max_power_freq, max_power, band_power_alpha, band_power_beta,
                            spectral_entropy_alpha, spectral_entropy_beta]
        
       
        features.append(channel_features)

# Convert features to numpy array
    
    features_psd_rsec.append(features)
    
features_psd_rsec = np.array(features_psd_rsec)
# Out:
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_12048\3347335835.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# C:\Users\stuti\AppData\Local\Temp\ipykernel_12048\3347335835.py:32: RuntimeWarning: invalid value encountered in true_divide
#   alpha_prob = psd_data[:,(freqs >= alpha_band[0]) & (freqs <= alpha_band[1])] / np.sum(psd_data)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_12048\3347335835.py:36: RuntimeWarning: invalid value encountered in true_divide
#   beta_prob = psd_data[:,(freqs >= beta_band[0]) & (freqs <= beta_band[1])] / np.sum(psd_data)
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# C:\Users\stuti\AppData\Local\Temp\ipykernel_12048\3347335835.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# C:\Users\stuti\AppData\Local\Temp\ipykernel_12048\3347335835.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# ...
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# Effective window size : 0.110 (s)
# (102, 4)
# current channel is
# MEG0112+0113
# current channel is
# MEG0122+0123
# current channel is
# MEG0132+0133
# current channel is
# MEG0142+0143
# current channel is
# MEG0212+0213
# current channel is
# MEG0222+0223
# current channel is
# MEG0232+0233
# current channel is
# MEG0242+0243
# current channel is
# MEG0312+0313
# current channel is
# MEG0322+0323
# current channel is
# MEG0332+0333
# current channel is
# MEG0342+0343
# current channel is
# MEG0412+0413
# current channel is
# MEG0422+0423
# current channel is
# MEG0432+0433
# current channel is
# MEG0442+0443
# current channel is
# MEG0512+0513
# current channel is
# MEG0522+0523
# current channel is
# MEG0532+0533
# current channel is
# MEG0542+0543
# current channel is
# MEG0612+0613
# current channel is
# MEG0622+0623
# current channel is
# MEG0632+0633
# current channel is
# MEG0642+0643
# current channel is
# MEG0712+0713
# current channel is
# MEG0722+0723
# current channel is
# MEG0732+0733
# current channel is
# MEG0742+0743
# current channel is
# MEG0812+0813
# current channel is
# MEG0822+0823
# current channel is
# MEG0912+0913
# current channel is
# MEG0922+0923
# current channel is
# MEG0932+0933
# current channel is
# MEG0942+0943
# current channel is
# MEG1012+1013
# current channel is
# MEG1022+1023
# current channel is
# MEG1032+1033
# current channel is
# MEG1042+1043
# current channel is
# MEG1112+1113
# current channel is
# MEG1122+1123
# current channel is
# MEG1132+1133
# current channel is
# MEG1142+1143
# current channel is
# MEG1212+1213
# current channel is
# MEG1222+1223
# current channel is
# MEG1232+1233
# current channel is
# MEG1242+1243
# current channel is
# MEG1312+1313
# current channel is
# MEG1322+1323
# current channel is
# MEG1332+1333
# current channel is
# MEG1342+1343
# current channel is
# MEG1412+1413
# current channel is
# MEG1422+1423
# current channel is
# MEG1432+1433
# current channel is
# MEG1442+1443
# current channel is
# MEG1512+1513
# current channel is
# MEG1522+1523
# current channel is
# MEG1532+1533
# current channel is
# MEG1542+1543
# current channel is
# MEG1612+1613
# current channel is
# MEG1622+1623
# current channel is
# MEG1632+1633
# current channel is
# MEG1642+1643
# current channel is
# MEG1712+1713
# current channel is
# MEG1722+1723
# current channel is
# MEG1732+1733
# current channel is
# MEG1742+1743
# current channel is
# MEG1812+1813
# current channel is
# MEG1822+1823
# current channel is
# MEG1832+1833
# current channel is
# MEG1842+1843
# current channel is
# MEG1912+1913
# current channel is
# MEG1922+1923
# current channel is
# MEG1932+1933
# current channel is
# MEG1942+1943
# current channel is
# MEG2012+2013
# current channel is
# MEG2022+2023
# current channel is
# MEG2032+2033
# current channel is
# MEG2042+2043
# current channel is
# MEG2112+2113
# current channel is
# MEG2122+2123
# current channel is
# MEG2132+2133
# current channel is
# MEG2142+2143
# current channel is
# MEG2212+2213
# current channel is
# MEG2222+2223
# current channel is
# MEG2232+2233
# current channel is
# MEG2242+2243
# current channel is
# MEG2312+2313
# current channel is
# MEG2322+2323
# current channel is
# MEG2332+2333
# current channel is
# MEG2342+2343
# current channel is
# MEG2412+2413
# current channel is
# MEG2422+2423
# current channel is
# MEG2432+2433
# current channel is
# MEG2442+2443
# current channel is
# MEG2512+2513
# current channel is
# MEG2522+2523
# current channel is
# MEG2532+2533
# current channel is
# MEG2542+2543
# current channel is
# MEG2612+2613
# current channel is
# MEG2622+2623
# current channel is
# MEG2632+2633
# current channel is
# MEG2642+2643
# C:\Users\stuti\AppData\Local\Temp\ipykernel_12048\3347335835.py:53: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   features_psd_rsec = np.array(features_psd_rsec)

# %%
features_psd_rsec.shape
# Out:
# (20, 102, 10)

# %%
# Exclude the 2nd and 3rd columns in the third dimension
new_features_psd_rsec = np.delete(features_psd_rsec, [2, 3], axis=2)

# %%
new_features_psd_rsec.shape
# Out:
# (20, 102, 8)

# %%
import numpy as np
import pandas as pd
    
# Import necessary libraries
from scipy.stats import skew, kurtosis
from scipy.signal import find_peaks
from numpy import diff

# Initialize an empty list to store subject data
subject_data_list = []

# Number of subjects
#num_subjects = 5
# Create an empty list to store evoked objects for each subject
evoked_list = []
features_erp_rsec = []

# Size of each array
array_size = (102, 201)
num_trials=0
start=0
raw_list = []
# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject, trials in enumerate(trial_counts_rsec):
    subject_data = []
    print('subject idx is')
    print(subject)
    
    name=matfiles_rsec[subject]
    print(name)
    dat = mat73.loadmat(matfiles_rsec[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        print('in if')
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
    
    num_trials+=len(new)

    print(start)
    end=num_trials
    print(end) 
    print(new[0].shape)
    trial_data=[]
# Loop through subjects
    for trial in range(trials):
        #print(new[0].shape[1])
        if new[0].shape[1] == 10001:
            trial_data.append(new[trial][:102,:9901])
            times = grand_average_rsec_healthy.times
            
        else:
            trial_data.append(new[trial][:102,200:351])
            times = grand_average_healthy.times
            
    # Compute the average across trials for the current subject
    average_data_healthy = np.mean(trial_data, axis=0)
    print(average_data_healthy.shape)
    
# Create empty lists to store features
    peak_amplitudes = []
    latencies = []
    auc_values = []
    slopes = []
    features_erp_1st_click_healthy=[]
    features=[]
    from scipy.integrate import simps
    

    # Initialize empty lists to store features
    peak_to_peak_amplitudes = []
    mean_absolute_amplitudes = []
    rms_amplitudes = []
    std_devs = []
    skewness_values = []
    kurtosis_values = []
    zero_crossing_rates = []
    aar_values=[]
    zork_values=[]


# Iterate through channels
    for ch_idx in range(len(info['ch_names'])):
        # Extract ERP data for the current channel
        channel_data = average_data_healthy[ch_idx,:]
        
    
    # Compute peak amplitude and latency
        peak_amplitude = np.max(channel_data)
         # Compute peak-to-peak amplitude
        peak_to_peak_amplitude = np.max(channel_data) - np.min(channel_data)
        peak_to_peak_amplitudes.append(peak_to_peak_amplitude)
        # Compute mean absolute amplitude
        mean_absolute_amplitude = np.mean(np.abs(channel_data))
        mean_absolute_amplitudes.append(mean_absolute_amplitude)
            # Compute RMS amplitude
        rms_amplitude = np.sqrt(np.mean(channel_data**2))
        rms_amplitudes.append(rms_amplitude)

        # Compute standard deviation
        std_dev = np.std(channel_data)
        std_devs.append(std_dev)

        # Compute skewness
        skewness = skew(channel_data)
        skewness_values.append(skewness)

        # Compute kurtosis
        kurtosis_val = kurtosis(channel_data)
        kurtosis_values.append(kurtosis_val)

        # Compute zero crossing rate
        zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
        zero_crossing_rates.append(zero_crossings)

        latency = times[np.argmax(channel_data)]
    
    # Calculate area under the curve (AUC)
        auc_value = simps(channel_data, times)
    
    # Calculate slope (e.g., by fitting a linear regression model)
    # You can use numpy's polyfit function for this purpose
        slope_coefficients = np.polyfit(times, channel_data, 1)
        slope = slope_coefficients[0]
        
        
        zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
        zero_crossing_rates.append(zero_crossings)

        # Compute AAR
        aar = peak_to_peak_amplitude / mean_absolute_amplitude
        aar_values.append(aar)

        # Compute ZORK
        zork = zero_crossings / kurtosis_val
        zork_values.append(zork)
        
        peak_to_peak_amplitudes1=np.array(peak_to_peak_amplitudes)
        channel_features = [peak_amplitude,latency,auc_value,slope,
                            peak_to_peak_amplitude, 
                                 mean_absolute_amplitude, 
                                 rms_amplitude, 
                                 std_dev, 
                                 skewness, 
                                 kurtosis_val, 
                                 zero_crossings,aar,zork]

        features.append(channel_features)

    features_erp_rsec.append(features)
    
features_erp_rsec = np.array(features_erp_rsec,dtype=object)
# Out:
# subject idx is
# 0
# PreProcessed_AD001_Preprocessed_EC.mat
# in if
# 0
# 16
# (204, 10001)
# (102, 9901)
# subject idx is
# 1
# PreProcessed_AD002_Preprocessed_EC.mat
# in if
# 0
# 32
# (204, 10001)
# (102, 9901)
# subject idx is
# 2
# PreProcessed_AD003_Preprocessed_EC.mat
# in if
# 0
# 48
# (204, 10001)
# (102, 9901)
# subject idx is
# 3
# PreProcessed_AD004_Preprocessed_EC.mat
# in if
# 0
# 64
# (204, 10001)
# (102, 9901)
# subject idx is
# 4
# PreProcessed_AD006_Preprocessed_EC.mat
# in if
# 0
# 80
# (204, 10001)
# (102, 9901)
# subject idx is
# 5
# PreProcessed_AD008_Preprocessed_EC.mat
# in if
# 0
# 96
# (204, 10001)
# (102, 9901)
# subject idx is
# 6
# PreProcessed_AD010_Preprocessed_EC.mat
# in if
# 0
# 112
# (204, 10001)
# (102, 9901)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_12048\2945046109.py:133: RuntimeWarning: invalid value encountered in double_scalars
#   aar = peak_to_peak_amplitude / mean_absolute_amplitude
# subject idx is
# 7
# PreProcessed_AD011_Preprocessed_EC.mat
# in if
# 0
# 128
# (204, 10001)
# (102, 9901)
# subject idx is
# 8
# PreProcessed_AD012_Preprocessed_EC.mat
# in if
# 0
# 144
# (204, 10001)
# (102, 9901)
# subject idx is
# 9
# PreProcessed_AD013_Preprocessed_EC.mat
# in if
# 0
# 160
# (204, 10001)
# (102, 9901)
# subject idx is
# 10
# PreProcessed_AD014_Preprocessed_EC.mat
# in if
# 0
# 176
# (204, 10001)
# (102, 9901)
# subject idx is
# 11
# PreProcessed_AD015_Preprocessed_EC.mat
# in if
# 0
# 192
# (204, 10001)
# (102, 9901)
# subject idx is
# 12
# PreProcessed_AD016_Preprocessed_EC.mat
# in if
# 0
# 208
# (204, 10001)
# (102, 9901)
# subject idx is
# 13
# PreProcessed_AD017_Preprocessed_EC.mat
# in if
# 0
# 224
# (204, 10001)
# (102, 9901)
# subject idx is
# 14
# PreProcessed_AD018_Preprocessed_EC.mat
# in if
# 0
# 240
# (204, 10001)
# (102, 9901)
# subject idx is
# 15
# PreProcessed_AD020_Preprocessed_EC.mat
# in if
# 0
# 256
# (204, 10001)
# (102, 9901)
# subject idx is
# 16
# PreProcessed_AD026_Preprocessed_EC.mat
# in if
# 0
# 272
# (204, 10001)
# (102, 9901)
# subject idx is
# 17
# PreProcessed_AD027_Preprocessed_EC.mat
# in if
# 0
# 288
# (204, 10001)
# (102, 9901)
# subject idx is
# 18
# PreProcessed_AD028_Preprocessed_EC.mat
# in if
# 0
# 304
# (204, 10001)
# (102, 9901)
# subject idx is
# 19
# PreProcessed_AD030_Preprocessed_EC.mat
# in if
# 0
# 320
# (204, 10001)
# (102, 9901)

# %%
features_erp_rsec.shape
# Out:
# (20, 102, 13)

# %%
usable_features_psd_rsec=new_features_psd_rsec[:,:,4:8]
print(usable_features_psd_rsec.shape)
# Out:
# (20, 102, 4)

# %%
usable_features_psd_rsec[:10].shape
# Out:
# (10, 102, 4)

# %%
plt.close()

# %%
# ch_aud

# %%
usable_features_psd_rsec.shape
# Out:
# (20, 102, 4)

# %%
# ch_aud

# %%
# # evaluate_performance(train_healthy_selected_features_rsec, X_test, y_test)
 
# from sklearn.metrics import classification_report, accuracy_score
# def evaluate_performance(X_train, X_test, y_test):
#     # Step 2: Train Isolation Forest Model
#     isolation_forest = IsolationForest(contamination=0.5,random_state=42)  # Contamination can be adjusted based on the anomaly rate
#     isolation_forest.fit(X_train)


#     # Step 3: K-fold Cross Validation
#     kf = KFold(n_splits=3, shuffle=True,random_state=42)  # Define k-fold cross-validation with 5 folds
#     fold_accuracies = []
#     for fold, (train_index, test_index) in enumerate(kf.split(X_test)):
#         X_train_fold, X_test_fold = X_test[train_index], X_test[test_index]
#         y_train_fold, y_test_fold = y_test[train_index], y_test[test_index]
#         print(y_test_fold)

#         # Predict anomalies
#         predictions_fold = isolation_forest.predict(X_test_fold)
#         print(predictions_fold)

#         # Convert predictions to match labels (0 for healthy, 1 for anomaly)
#         y_pred_fold = np.zeros_like(y_test_fold)
#         y_pred_fold[predictions_fold == 1] = 0
#         y_pred_fold[predictions_fold == -1] = 1

#         # Print classification report for the fold
#         print(f"Classification Report - Fold {fold + 1}:")
#         #print(classification_report(y_test_fold, y_pred_fold, target_names=['Normal', 'Anomaly'],zero_division=0))
#         print(classification_report(y_test_fold,predictions_fold, target_names=['Normal', 'Anomaly'],zero_division=0))
        
        
#                # Calculate accuracy for this fold
#         fold_accuracy = accuracy_score(y_test_fold, predictions_fold)
#         fold_accuracies.append(fold_accuracy)


#     # Evaluate the model on the entire test set
#     predictions = isolation_forest.predict(X_test)

#     # Convert predictions to match labels (0 for healthy, 1 for anomaly)
#     y_pred = np.zeros_like(y_test)
#     y_pred[predictions == 1] = 0
#     y_pred[predictions == -1] = 1
    
#     # Calculate accuracy for the entire test set
#     test_set_accuracy = accuracy_score(y_test, predictions)


#     # Print final classification report
#     print("Final Classification Report:")
#     print(classification_report(y_test, predictions, zero_division=0))
    
    
#     return test_set_accuracy, fold_accuracies

    
   
 

# # # Usage
# # test_set_accuracy, fold_accuracies = evaluate_performance(train_healthy_selected_features_rsec, X_test, y_test)
# # print("Test Set Accuracy:", test_set_accuracy)
# # print("Fold Accuracies:", fold_accuracies)

# %%
# import pickle
# with open('features_psd_rsec.pkl', 'wb') as file: 
#     pickle.dump(usable_features_psd_rsec, file)

# %%
# import pickle
# with open('features_erp_rsec.pkl', 'wb') as file: 
#     pickle.dump(features_erp_rsec, file)

# %%
import pickle
with open('features_psd_rsec.pkl','rb') as file:
    usable_features_psd_rsec=pickle.load(file)

# %%
import pickle
with open('features_erp_rsec.pkl','rb') as file:
    features_erp_rsec=pickle.load(file)

# %%
usable_features_psd_rsec.shape
# Out:
# (20, 102, 4)

# %%
features_erp_rsec.shape
# Out:
# (20, 102, 13)

# %% [markdown]
# # Eyes open data

# %%
import os
import glob


# Construct the path to the target folder
folder_path = "D:\internship_ulster_university\preprocessed_filtered_eyes_open"

# Move into the target folder
os.chdir(folder_path)

# Select all files ending with ".mat"
matfiles_rseo = glob.glob("*.mat")

# Print the list of selected files
print("Selected .mat files:")
for file in matfiles_rseo:
    print(file)
# Out:
# Selected .mat files:
# PreProcessed_AD001_Preprocessed_EO.mat
# PreProcessed_AD002_Preprocessed_EO.mat
# PreProcessed_AD003_Preprocessed_EO.mat
# PreProcessed_AD004_Preprocessed_EO.mat
# PreProcessed_AD006_Preprocessed_EO.mat
# PreProcessed_AD008_Preprocessed_EO.mat
# PreProcessed_AD010_Preprocessed_EO.mat
# PreProcessed_AD011_Preprocessed_EO.mat
# PreProcessed_AD012_Preprocessed_EO.mat
# PreProcessed_AD013_Preprocessed_EO.mat
# PreProcessed_AD014_Preprocessed_EO.mat
# PreProcessed_AD015_Preprocessed_EO.mat
# PreProcessed_AD016_Preprocessed_EO.mat
# PreProcessed_AD017_Preprocessed_EO.mat
# PreProcessed_AD018_Preprocessed_EO.mat
# PreProcessed_AD020_Preprocessed_EO.mat
# PreProcessed_AD026_Preprocessed_EO.mat
# PreProcessed_AD027_Preprocessed_EO.mat
# PreProcessed_AD028_Preprocessed_EO.mat
# PreProcessed_AD030_Preprocessed_EO.mat
# PreProcessed_AD031_Preprocessed_EO.mat

# %%
num_trials=0
trial_counts_rseo=[]
for subject in range(len(matfiles_rseo)):
    subject_data = []
    name=matfiles_rseo[subject]
    print(name)
    dat = mat73.loadmat(matfiles_rseo[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
#     print(new)
    trial_counts_rseo.append(len(new))
    print(len(new))
    num_trials+=len(new)
# Out:
# PreProcessed_AD001_Preprocessed_EO.mat
# 16
# PreProcessed_AD002_Preprocessed_EO.mat
# 16
# PreProcessed_AD003_Preprocessed_EO.mat
# 16
# PreProcessed_AD004_Preprocessed_EO.mat
# 16
# PreProcessed_AD006_Preprocessed_EO.mat
# 16
# PreProcessed_AD008_Preprocessed_EO.mat
# 16
# PreProcessed_AD010_Preprocessed_EO.mat
# 16
# PreProcessed_AD011_Preprocessed_EO.mat
# 16
# PreProcessed_AD012_Preprocessed_EO.mat
# 16
# PreProcessed_AD013_Preprocessed_EO.mat
# 16
# PreProcessed_AD014_Preprocessed_EO.mat
# 16
# PreProcessed_AD015_Preprocessed_EO.mat
# 16
# PreProcessed_AD016_Preprocessed_EO.mat
# 16
# PreProcessed_AD017_Preprocessed_EO.mat
# 16
# PreProcessed_AD018_Preprocessed_EO.mat
# 16
# PreProcessed_AD020_Preprocessed_EO.mat
# 16
# PreProcessed_AD026_Preprocessed_EO.mat
# 15
# PreProcessed_AD027_Preprocessed_EO.mat
# 16
# PreProcessed_AD028_Preprocessed_EO.mat
# 16
# PreProcessed_AD030_Preprocessed_EO.mat
# 16
# PreProcessed_AD031_Preprocessed_EO.mat
# 16

# %%
trial_counts_rseo
# Out:
# [16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  15,
#  16,
#  16,
#  16,
#  16]

# %%
import numpy as np
import pandas as pd

# Initialize an empty list to store subject data
subject_data_list = []

# Number of subjects
#num_subjects = 5


# Size of each array
array_size = (102, 201)
num_trials=0
start=0
raw_list_mean_rseo = []
    

# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject, trials in enumerate(trial_counts_rseo):
    subject_data = []
    print('subject idx is')
    print(subject)
    
    name=matfiles_rseo[subject]
    print(name)
    dat = mat73.loadmat(matfiles_rseo[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
    
    num_trials+=len(new)

    print(start)
    end=num_trials
    print(end)
    trial_data=[]

            
# # print(len(raw_combined_mean_mci_ts))
    for trial in range(trials):
        #print(new[0].shape[1])
        if new[0].shape[1] == 10001:
            trial_data.append(new[trial][:102,:9901])
            times = grand_average_rsec_healthy.times
            
        else:
            trial_data.append(new[trial][:102,200:351])
            times = grand_average_healthy.times
        trial=trial_data[0]
        raw = mne.io.RawArray(trial, info)
        raw_list_mean_rseo.append(raw)
    print(len(raw_list_mean_rseo))
# Out:
# subject idx is
# 0
# PreProcessed_AD001_Preprocessed_EO.mat
# 0
# 16
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 16
# subject idx is
# 1
# PreProcessed_AD002_Preprocessed_EO.mat
# 0
# 32
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 32
# subject idx is
# 2
# PreProcessed_AD003_Preprocessed_EO.mat
# 0
# 48
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 48
# subject idx is
# 3
# PreProcessed_AD004_Preprocessed_EO.mat
# 0
# 64
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 64
# subject idx is
# 4
# PreProcessed_AD006_Preprocessed_EO.mat
# 0
# 80
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 80
# subject idx is
# 5
# PreProcessed_AD008_Preprocessed_EO.mat
# 0
# 96
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 96
# subject idx is
# 6
# PreProcessed_AD010_Preprocessed_EO.mat
# 0
# 112
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 112
# subject idx is
# 7
# PreProcessed_AD011_Preprocessed_EO.mat
# 0
# 128
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 128
# subject idx is
# 8
# PreProcessed_AD012_Preprocessed_EO.mat
# 0
# 144
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 144
# subject idx is
# 9
# PreProcessed_AD013_Preprocessed_EO.mat
# 0
# 160
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 160
# subject idx is
# 10
# PreProcessed_AD014_Preprocessed_EO.mat
# 0
# 176
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 176
# subject idx is
# 11
# PreProcessed_AD015_Preprocessed_EO.mat
# 0
# 192
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 192
# subject idx is
# 12
# PreProcessed_AD016_Preprocessed_EO.mat
# 0
# 208
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 208
# subject idx is
# 13
# PreProcessed_AD017_Preprocessed_EO.mat
# 0
# 224
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 224
# subject idx is
# 14
# PreProcessed_AD018_Preprocessed_EO.mat
# 0
# 240
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 240
# subject idx is
# 15
# PreProcessed_AD020_Preprocessed_EO.mat
# 0
# 256
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 256
# subject idx is
# 16
# PreProcessed_AD026_Preprocessed_EO.mat
# 0
# 271
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 271
# subject idx is
# 17
# PreProcessed_AD027_Preprocessed_EO.mat
# 0
# 287
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 287
# subject idx is
# 18
# PreProcessed_AD028_Preprocessed_EO.mat
# 0
# 303
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 303
# subject idx is
# 19
# PreProcessed_AD030_Preprocessed_EO.mat
# 0
# 319
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 319
# subject idx is
# 20
# PreProcessed_AD031_Preprocessed_EO.mat
# 0
# 335
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 335

# %%
raw_list_mean_rseo
# Out:
# [<RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>]

# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import kurtosis
alpha_band=(8,13)
beta_band=(13,30)
features_psd_rseo = []
for raw in raw_list_mean_rseo:
    # Compute PSD
    psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
    #psd_spectrum_healthy = raw.compute_psd(method='multitaper', fmin=0, fmax=40, tmin=None, tmax=None)
    print(psd_spectrum_healthy.shape)
    
    
    features=[]
    for idx, ch_name in enumerate(list_1):
        psd_data = psd_spectrum_healthy[idx]  # PSD data for the current channel
        
        

    # Statistical Features
        mean_power = np.mean(psd_data)
        variance_power = np.var(psd_data)
    
        skewness_power = stats.skew(psd_data)
        kurtosis_power = stats.kurtosis(psd_data)
        freqs = psd_spectrum_healthy.freqs  # Frequency values
        max_power_freq = freqs[np.argmax(psd_data)]
        max_power = np.max(psd_data)
        band_power_alpha = np.sum(psd_data[:,(freqs >= 8) & (freqs <= 13)])  # Alpha band
        band_power_beta = np.sum(psd_data[:,(freqs >= 13) & (freqs <= 30)])  # Beta band
        
                    # Compute entropy for alpha band
        alpha_prob = psd_data[:,(freqs >= alpha_band[0]) & (freqs <= alpha_band[1])] / np.sum(psd_data)
        spectral_entropy_alpha = -np.sum(alpha_prob * np.log2(alpha_prob + 1e-12))  # Add a small value to avoid log(0)

        # Compute entropy for beta band
        beta_prob = psd_data[:,(freqs >= beta_band[0]) & (freqs <= beta_band[1])] / np.sum(psd_data)
        spectral_entropy_beta = -np.sum(beta_prob * np.log2(beta_prob + 1e-12))  # Add a small value to avoid log(0)

        
 
        # Append features for the current channel
        channel_features = [mean_power, variance_power, skewness_power, kurtosis_power,
                            max_power_freq, max_power, band_power_alpha, band_power_beta,
                            spectral_entropy_alpha, spectral_entropy_beta]
        
       
        features.append(channel_features)

# Convert features to numpy array
    
    features_psd_rseo.append(features)
    
features_psd_rseo = np.array(features_psd_rseo)
# Out:
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:33: RuntimeWarning: invalid value encountered in true_divide
#   alpha_prob = psd_data[:,(freqs >= alpha_band[0]) & (freqs <= alpha_band[1])] / np.sum(psd_data)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:37: RuntimeWarning: invalid value encountered in true_divide
#   beta_prob = psd_data[:,(freqs >= beta_band[0]) & (freqs <= beta_band[1])] / np.sum(psd_data)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3700920911.py:54: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   features_psd_rseo = np.array(features_psd_rseo)

# %%
features_psd_rseo
# Out:
# array([[[1.2276929087765274e-25, 3.998988659264755e-51,
#          array([nan, nan, nan, nan]), ..., 2.3130365421082524e-25,
#          0.5212658277168896, 0.9696345451375732],
#         [1.300991034604867e-25, 2.990595473218604e-51,
#          array([nan, nan, nan, nan]), ..., 2.5552444787380087e-25,
#          0.5294233532717435, 0.9797109892542122],
#         [1.3102693044174005e-25, 5.0216227427464215e-51,
#          array([nan, nan, nan, nan]), ..., 2.5679607917467266e-25,
#          0.5248530797442795, 0.9463264537379514],
#         ...,
#         [6.652454190924905e-26, 1.074032270988968e-51,
#          array([nan, nan, nan, nan]), ..., 1.2717382347575834e-25,
#          0.5244376137837149, 0.9694418967468352],
#         [5.9727437599771e-26, 6.390097480428914e-52,
#          array([nan, nan, nan, nan]), ..., 1.2769025707808533e-25,
#          0.5307311278410398, 1.001022599473779],
#         [1.119869190820366e-25, 1.6963812375755624e-51,
#          array([nan, nan, nan, nan]), ..., 2.3838770641921116e-25,
#          0.5305021374083777, 1.0096885428717728]],
#
#        [[1.2276929087765274e-25, 3.998988659264755e-51,
#          array([nan, nan, nan, nan]), ..., 2.3130365421082524e-25,
#          0.5212658277168896, 0.9696345451375732],
#         [1.300991034604867e-25, 2.990595473218604e-51,
#          array([nan, nan, nan, nan]), ..., 2.5552444787380087e-25,
#          0.5294233532717435, 0.9797109892542122],
#         [1.3102693044174005e-25, 5.0216227427464215e-51,
#          array([nan, nan, nan, nan]), ..., 2.5679607917467266e-25,
#          0.5248530797442795, 0.9463264537379514],
#         ...,
#         [6.652454190924905e-26, 1.074032270988968e-51,
#          array([nan, nan, nan, nan]), ..., 1.2717382347575834e-25,
#          0.5244376137837149, 0.9694418967468352],
#         [5.9727437599771e-26, 6.390097480428914e-52,
#          array([nan, nan, nan, nan]), ..., 1.2769025707808533e-25,
#          0.5307311278410398, 1.001022599473779],
#         [1.119869190820366e-25, 1.6963812375755624e-51,
#          array([nan, nan, nan, nan]), ..., 2.3838770641921116e-25,
#          0.5305021374083777, 1.0096885428717728]],
#
#        [[1.2276929087765274e-25, 3.998988659264755e-51,
#          array([nan, nan, nan, nan]), ..., 2.3130365421082524e-25,
#          0.5212658277168896, 0.9696345451375732],
#         [1.300991034604867e-25, 2.990595473218604e-51,
#          array([nan, nan, nan, nan]), ..., 2.5552444787380087e-25,
#          0.5294233532717435, 0.9797109892542122],
#         [1.3102693044174005e-25, 5.0216227427464215e-51,
#          array([nan, nan, nan, nan]), ..., 2.5679607917467266e-25,
#          0.5248530797442795, 0.9463264537379514],
#         ...,
#         [6.652454190924905e-26, 1.074032270988968e-51,
#          array([nan, nan, nan, nan]), ..., 1.2717382347575834e-25,
#          0.5244376137837149, 0.9694418967468352],
#         [5.9727437599771e-26, 6.390097480428914e-52,
#          array([nan, nan, nan, nan]), ..., 1.2769025707808533e-25,
#          0.5307311278410398, 1.001022599473779],
#         [1.119869190820366e-25, 1.6963812375755624e-51,
#          array([nan, nan, nan, nan]), ..., 2.3838770641921116e-25,
#          0.5305021374083777, 1.0096885428717728]],
#
#        ...,
#
#        [[1.8880935220351703e-25, 1.4315256396321054e-50,
#          array([nan, nan, nan, nan]), ..., 3.2683174253820773e-25,
#          0.5044023934563856, 0.9185153598169336],
#         [1.4142794334782001e-24, 2.2400568361779445e-48,
#          array([nan, nan, nan, nan]), ..., 1.6465193028317896e-24,
#          0.3724238263658415, 0.725988860140693],
#         [6.015861110912123e-25, 2.779990133588335e-49,
#          array([nan, nan, nan, nan]), ..., 8.402997279642028e-25,
#          0.4377139438557262, 0.8299738971001771],
#         ...,
#         [4.871497205367268e-25, 1.995610709159312e-49,
#          array([nan, nan, nan, nan]), ..., 6.966239196845542e-25,
#          0.4331175901248443, 0.801627667795048],
#         [2.3539104366665904e-25, 3.9629572991738953e-50,
#          array([nan, nan, nan, nan]), ..., 3.534129050564298e-25,
#          0.45353340894222693, 0.8408133837434247],
#         [2.391650693102695e-25, 3.1528339950394487e-50,
#          array([nan, nan, nan, nan]), ..., 4.0470422402977936e-25,
#          0.48837631454117425, 0.8748447320512183]],
#
#        [[1.8880935220351703e-25, 1.4315256396321054e-50,
#          array([nan, nan, nan, nan]), ..., 3.2683174253820773e-25,
#          0.5044023934563856, 0.9185153598169336],
#         [1.4142794334782001e-24, 2.2400568361779445e-48,
#          array([nan, nan, nan, nan]), ..., 1.6465193028317896e-24,
#          0.3724238263658415, 0.725988860140693],
#         [6.015861110912123e-25, 2.779990133588335e-49,
#          array([nan, nan, nan, nan]), ..., 8.402997279642028e-25,
#          0.4377139438557262, 0.8299738971001771],
#         ...,
#         [4.871497205367268e-25, 1.995610709159312e-49,
#          array([nan, nan, nan, nan]), ..., 6.966239196845542e-25,
#          0.4331175901248443, 0.801627667795048],
#         [2.3539104366665904e-25, 3.9629572991738953e-50,
#          array([nan, nan, nan, nan]), ..., 3.534129050564298e-25,
#          0.45353340894222693, 0.8408133837434247],
#         [2.391650693102695e-25, 3.1528339950394487e-50,
#          array([nan, nan, nan, nan]), ..., 4.0470422402977936e-25,
#          0.48837631454117425, 0.8748447320512183]],
#
#        [[1.8880935220351703e-25, 1.4315256396321054e-50,
#          array([nan, nan, nan, nan]), ..., 3.2683174253820773e-25,
#          0.5044023934563856, 0.9185153598169336],
#         [1.4142794334782001e-24, 2.2400568361779445e-48,
#          array([nan, nan, nan, nan]), ..., 1.6465193028317896e-24,
#          0.3724238263658415, 0.725988860140693],
#         [6.015861110912123e-25, 2.779990133588335e-49,
#          array([nan, nan, nan, nan]), ..., 8.402997279642028e-25,
#          0.4377139438557262, 0.8299738971001771],
#         ...,
#         [4.871497205367268e-25, 1.995610709159312e-49,
#          array([nan, nan, nan, nan]), ..., 6.966239196845542e-25,
#          0.4331175901248443, 0.801627667795048],
#         [2.3539104366665904e-25, 3.9629572991738953e-50,
#          array([nan, nan, nan, nan]), ..., 3.534129050564298e-25,
#          0.45353340894222693, 0.8408133837434247],
#         [2.391650693102695e-25, 3.1528339950394487e-50,
#          array([nan, nan, nan, nan]), ..., 4.0470422402977936e-25,
#          0.48837631454117425, 0.8748447320512183]]], dtype=object)

# %%
features_psd_rseo.shape
# Out:
# (335, 102, 10)

# %%
# Exclude the 2nd and 3rd columns in the third dimension
new_features_psd_rseo = np.delete(features_psd_rseo, [2, 3], axis=2)

# %%
new_features_psd_rseo.shape
# Out:
# (335, 102, 8)

# %%
import numpy as np
import pandas as pd
    
# Import necessary libraries
from scipy.stats import skew, kurtosis
from scipy.signal import find_peaks
from numpy import diff
# Initialize an empty list to store subject data
subject_data_list = []
evoked_list = []
features_erp_rseo = []

# Size of each array
array_size = (102, 201)
num_trials=0
start=0
raw_list = []
# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject, trials in enumerate(trial_counts_rseo):
    subject_data = []
    print('subject idx is')
    print(subject)
    
    name=matfiles_rseo[subject]
    print(name)
    dat = mat73.loadmat(matfiles_rseo[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        print('in if')
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
    
    num_trials+=len(new)

    print(start)
    end=num_trials
    print(end) 
    print(new[0].shape)
    trial_data=[]
    # Create empty lists to store features
    peak_amplitudes = []
    latencies = []
    auc_values = []
    slopes = []
    features_erp_1st_click_healthy=[]
    features=[]
    from scipy.integrate import simps
    

    # Initialize empty lists to store features
    peak_to_peak_amplitudes = []
    mean_absolute_amplitudes = []
    rms_amplitudes = []
    std_devs = []
    skewness_values = []
    kurtosis_values = []
    zero_crossing_rates = []
    aar_values=[]
    zork_values=[]
# Loop through subjects
    for trial in range(trials):
        #print(new[0].shape[1])
        if new[0].shape[1] == 10001:
            trial_data.append(new[trial][:102,:9901])
            times = grand_average_rsec_healthy.times
            
        else:
            trial_data.append(new[trial][:102,200:351])
            times = grand_average_healthy.times
        trial=trial_data[0]
        features=[]
# Iterate through channels
        for ch_idx in range(len(info['ch_names'])):
            # Extract ERP data for the current channel
            channel_data = trial[ch_idx,:]


        # Compute peak amplitude and latency
            peak_amplitude = np.max(channel_data)
             # Compute peak-to-peak amplitude
            peak_to_peak_amplitude = np.max(channel_data) - np.min(channel_data)
            peak_to_peak_amplitudes.append(peak_to_peak_amplitude)
            # Compute mean absolute amplitude
            mean_absolute_amplitude = np.mean(np.abs(channel_data))
            mean_absolute_amplitudes.append(mean_absolute_amplitude)
                # Compute RMS amplitude
            rms_amplitude = np.sqrt(np.mean(channel_data**2))
            rms_amplitudes.append(rms_amplitude)

            # Compute standard deviation
            std_dev = np.std(channel_data)
            std_devs.append(std_dev)

            # Compute skewness
            skewness = skew(channel_data)
            skewness_values.append(skewness)

            # Compute kurtosis
            kurtosis_val = kurtosis(channel_data)
            kurtosis_values.append(kurtosis_val)

            # Compute zero crossing rate
            zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
            zero_crossing_rates.append(zero_crossings)

            latency = times[np.argmax(channel_data)]

        # Calculate area under the curve (AUC)
            auc_value = simps(channel_data, times)

        # Calculate slope (e.g., by fitting a linear regression model)
        # You can use numpy's polyfit function for this purpose
            slope_coefficients = np.polyfit(times, channel_data, 1)
            slope = slope_coefficients[0]


            zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
            zero_crossing_rates.append(zero_crossings)

            # Compute AAR
            aar = peak_to_peak_amplitude / mean_absolute_amplitude
            aar_values.append(aar)

            # Compute ZORK
            zork = zero_crossings / kurtosis_val
            zork_values.append(zork)

            peak_to_peak_amplitudes1=np.array(peak_to_peak_amplitudes)
            channel_features = [peak_amplitude,latency,auc_value,slope,
                                peak_to_peak_amplitude, 
                                     mean_absolute_amplitude, 
                                     rms_amplitude, 
                                     std_dev, 
                                     skewness, 
                                     kurtosis_val, 
                                     zero_crossings,aar,zork]

            features.append(channel_features)

        features_erp_rseo.append(features)
    
features_erp_rseo = np.array(features_erp_rseo,dtype=object)
# Out:
# subject idx is
# 0
# PreProcessed_AD001_Preprocessed_EO.mat
# in if
# 0
# 16
# (204, 10001)
# subject idx is
# 1
# PreProcessed_AD002_Preprocessed_EO.mat
# in if
# 0
# 32
# (204, 10001)
# subject idx is
# 2
# PreProcessed_AD003_Preprocessed_EO.mat
# in if
# 0
# 48
# (204, 10001)
# subject idx is
# 3
# PreProcessed_AD004_Preprocessed_EO.mat
# in if
# 0
# 64
# (204, 10001)
# subject idx is
# 4
# PreProcessed_AD006_Preprocessed_EO.mat
# in if
# 0
# 80
# (204, 10001)
# subject idx is
# 5
# PreProcessed_AD008_Preprocessed_EO.mat
# in if
# 0
# 96
# (204, 10001)
# subject idx is
# 6
# PreProcessed_AD010_Preprocessed_EO.mat
# in if
# 0
# 112
# (204, 10001)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2207974811.py:123: RuntimeWarning: invalid value encountered in double_scalars
#   aar = peak_to_peak_amplitude / mean_absolute_amplitude
# subject idx is
# 7
# PreProcessed_AD011_Preprocessed_EO.mat
# in if
# 0
# 128
# (204, 10001)
# subject idx is
# 8
# PreProcessed_AD012_Preprocessed_EO.mat
# in if
# 0
# 144
# (204, 10001)
# subject idx is
# 9
# PreProcessed_AD013_Preprocessed_EO.mat
# in if
# 0
# 160
# (204, 10001)
# subject idx is
# 10
# PreProcessed_AD014_Preprocessed_EO.mat
# in if
# 0
# 176
# (204, 10001)
# subject idx is
# 11
# PreProcessed_AD015_Preprocessed_EO.mat
# in if
# 0
# 192
# (204, 10001)
# subject idx is
# 12
# PreProcessed_AD016_Preprocessed_EO.mat
# in if
# 0
# 208
# (204, 10001)
# subject idx is
# 13
# PreProcessed_AD017_Preprocessed_EO.mat
# in if
# 0
# 224
# (204, 10001)
# subject idx is
# 14
# PreProcessed_AD018_Preprocessed_EO.mat
# in if
# 0
# 240
# (204, 10001)
# subject idx is
# 15
# PreProcessed_AD020_Preprocessed_EO.mat
# in if
# 0
# 256
# (204, 10001)
# subject idx is
# 16
# PreProcessed_AD026_Preprocessed_EO.mat
# in if
# 0
# 271
# (204, 10001)
# subject idx is
# 17
# PreProcessed_AD027_Preprocessed_EO.mat
# in if
# 0
# 287
# (204, 10001)
# subject idx is
# 18
# PreProcessed_AD028_Preprocessed_EO.mat
# in if
# 0
# 303
# (204, 10001)
# subject idx is
# 19
# PreProcessed_AD030_Preprocessed_EO.mat
# in if
# 0
# 319
# (204, 10001)
# subject idx is
# 20
# PreProcessed_AD031_Preprocessed_EO.mat
# in if
# 0
# 335
# (204, 10001)

# %%
features_erp_rseo.shape
# Out:
# (335, 102, 13)

# %%
# plt.close()

# %%
usable_features_psd_rseo=new_features_psd_rseo[:,:,4:8]
print(usable_features_psd_rseo.shape)
# Out:
# (335, 102, 4)

# %%
import numpy as np

reshaped_psd = []
reshaped_erp = []

# Start index for slicing
start_idx = 0

# Iterate over each subject and their respective trial count
for trials in trial_counts_rseo:
    # Calculate the end index for slicing
    end_idx = start_idx + trials
    
    # Slice the data for the current subject
    subject_psd = usable_features_psd_rseo[start_idx:end_idx, :, :]
    subject_erp = features_erp_rseo[start_idx:end_idx, :, :]
    
    # Append the reshaped data to the list
    reshaped_psd.append(subject_psd)
    reshaped_erp.append(subject_erp)
    
    # Update the start index for the next iteration
    start_idx = end_idx

# Convert the lists to numpy arrays with the desired shape
reshaped_psd = np.array(reshaped_psd)  # Shape will be (21, trials_per_subject, 102, 4)
reshaped_erp = np.array(reshaped_erp)  # Shape will be (21, trials_per_subject, 102, 13)
# Out:
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2799428737.py:26: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   reshaped_psd = np.array(reshaped_psd)  # Shape will be (21, trials_per_subject, 102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2799428737.py:27: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   reshaped_erp = np.array(reshaped_erp)  # Shape will be (21, trials_per_subject, 102, 13)

# %%
reshaped_erp[16].shape
# Out:
# (15, 102, 13)

# %%
import numpy as np
from scipy.io import savemat

psd_file_path = 'D:/internship_ulster_university/features without grand averaging/rseo_psd_without_grand_average.mat'
erp_file_path = 'D:/internship_ulster_university/features without grand averaging/rseo_erp_without_grand_average.mat'

# Create a dictionary to hold the variables to be saved
psd_dict = {'reshaped_psd': reshaped_psd}
erp_dict = {'reshaped_erp': reshaped_erp}

# Save the reshaped arrays to .mat files
savemat(psd_file_path, psd_dict)
savemat(erp_file_path, erp_dict)

print(f"Files saved successfully to {psd_file_path} and {erp_file_path}")
# Out:
# Files saved successfully to D:/internship_ulster_university/features without grand averaging/rseo_psd_without_grand_average.mat and D:/internship_ulster_university/features without grand averaging/rseo_erp_without_grand_average.mat

# %% [markdown]
# # 1st click data

# %%
import os
import glob


# Construct the path to the target folder
folder_path = "D:\internship_ulster_university\preprocessed_filtered_1st_click"

# Move into the target folder
os.chdir(folder_path)

# Select all files ending with ".mat"
matfiles_1st_click = glob.glob("*.mat")

# Print the list of selected files
print("Selected .mat files:")
for file in matfiles_1st_click:
    print(file)
# Out:
# Selected .mat files:
# PreProcessed_AD001_Preprocessed_FirstClick.mat
# PreProcessed_AD002_Preprocessed_FirstClick.mat
# PreProcessed_AD003_Preprocessed_FirstClick.mat
# PreProcessed_AD004_Preprocessed_FirstClick.mat
# PreProcessed_AD006_Preprocessed_FirstClick.mat
# PreProcessed_AD008_Preprocessed_FirstClick.mat
# PreProcessed_AD010_Preprocessed_FirstClick.mat
# PreProcessed_AD011_Preprocessed_FirstClick.mat
# PreProcessed_AD012_Preprocessed_FirstClick.mat
# PreProcessed_AD013_Preprocessed_FirstClick.mat
# PreProcessed_AD014_Preprocessed_FirstClick.mat
# PreProcessed_AD015_Preprocessed_FirstClick.mat
# PreProcessed_AD016_Preprocessed_FirstClick.mat
# PreProcessed_AD017_Preprocessed_FirstClick.mat
# PreProcessed_AD018_Preprocessed_FirstClick.mat
# PreProcessed_AD020_Preprocessed_FirstClick.mat
# PreProcessed_AD026_Preprocessed_FirstClick.mat
# PreProcessed_AD027_Preprocessed_FirstClick.mat
# PreProcessed_AD028_Preprocessed_FirstClick.mat
# PreProcessed_AD030_Preprocessed_FirstClick.mat
# PreProcessed_AD031_Preprocessed_FirstClick.mat

# %%
num_trials=0
trial_counts_1st_click=[]
for subject in range(len(matfiles_1st_click)):
    subject_data = []
    name=matfiles_1st_click[subject]
    print(name)
    dat = mat73.loadmat(matfiles_1st_click[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
#     print(new)
    trial_counts_1st_click.append(len(new))
    print(len(new))
    num_trials+=len(new)
# Out:
# PreProcessed_AD001_Preprocessed_FirstClick.mat
# 31
# PreProcessed_AD002_Preprocessed_FirstClick.mat
# 61
# PreProcessed_AD003_Preprocessed_FirstClick.mat
# 21
# PreProcessed_AD004_Preprocessed_FirstClick.mat
# 32
# PreProcessed_AD006_Preprocessed_FirstClick.mat
# 35
# PreProcessed_AD008_Preprocessed_FirstClick.mat
# 28
# PreProcessed_AD010_Preprocessed_FirstClick.mat
# 35
# PreProcessed_AD011_Preprocessed_FirstClick.mat
# 28
# PreProcessed_AD012_Preprocessed_FirstClick.mat
# 44
# PreProcessed_AD013_Preprocessed_FirstClick.mat
# 40
# PreProcessed_AD014_Preprocessed_FirstClick.mat
# 34
# PreProcessed_AD015_Preprocessed_FirstClick.mat
# 26
# PreProcessed_AD016_Preprocessed_FirstClick.mat
# 26
# PreProcessed_AD017_Preprocessed_FirstClick.mat
# 26
# PreProcessed_AD018_Preprocessed_FirstClick.mat
# 33
# PreProcessed_AD020_Preprocessed_FirstClick.mat
# 25
# PreProcessed_AD026_Preprocessed_FirstClick.mat
# 45
# PreProcessed_AD027_Preprocessed_FirstClick.mat
# 34
# PreProcessed_AD028_Preprocessed_FirstClick.mat
# 39
# PreProcessed_AD030_Preprocessed_FirstClick.mat
# 44
# PreProcessed_AD031_Preprocessed_FirstClick.mat
# 44

# %%
trial_counts_1st_click
# Out:
# [31,
#  61,
#  21,
#  32,
#  35,
#  28,
#  35,
#  28,
#  44,
#  40,
#  34,
#  26,
#  26,
#  26,
#  33,
#  25,
#  45,
#  34,
#  39,
#  44,
#  44]

# %%
sum(trial_counts_1st_click)
# Out:
# 731

# %%
import numpy as np
import pandas as pd

# Initialize an empty list to store subject data
subject_data_list = []

# Number of subjects
#num_subjects = 5


# Size of each array
array_size = (102, 201)
num_trials=0
start=0
raw_list_mean_1st_click = []
# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject, trials in enumerate(trial_counts_1st_click):
    subject_data = []
    print('subject idx is')
    print(subject)
    
    name=matfiles_1st_click[subject]
    print(name)
    dat = mat73.loadmat(matfiles_1st_click[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
    
    num_trials+=len(new)

    print(start)
    end=num_trials
    print(end)
    trial_data=[]
    

    for trial in range(trials):
        #print(new[0].shape[1])
        if new[0].shape[1] == 10001:
            trial_data.append(new[trial][:102,:9901])
            times = grand_average_rsec_healthy.times
            
        else:
            trial_data.append(new[trial][:102,200:351])
            times = grand_average_healthy.times
        trial=trial_data[0]
        raw = mne.io.RawArray(trial, info)
        raw_list_mean_1st_click.append(raw)
    print(len(raw_list_mean_1st_click))
# Out:
# subject idx is
# 0
# PreProcessed_AD001_Preprocessed_FirstClick.mat
# 0
# 31
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 31
# subject idx is
# 1
# PreProcessed_AD002_Preprocessed_FirstClick.mat
# 0
# 92
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 92
# subject idx is
# 2
# PreProcessed_AD003_Preprocessed_FirstClick.mat
# 0
# 113
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 113
# subject idx is
# 3
# PreProcessed_AD004_Preprocessed_FirstClick.mat
# 0
# 145
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 145
# subject idx is
# 4
# PreProcessed_AD006_Preprocessed_FirstClick.mat
# 0
# 180
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 180
# subject idx is
# 5
# PreProcessed_AD008_Preprocessed_FirstClick.mat
# 0
# 208
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 208
# subject idx is
# 6
# PreProcessed_AD010_Preprocessed_FirstClick.mat
# 0
# 243
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 243
# subject idx is
# 7
# PreProcessed_AD011_Preprocessed_FirstClick.mat
# 0
# 271
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 271
# subject idx is
# 8
# PreProcessed_AD012_Preprocessed_FirstClick.mat
# 0
# 315
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 315
# subject idx is
# 9
# PreProcessed_AD013_Preprocessed_FirstClick.mat
# 0
# 355
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 355
# subject idx is
# 10
# PreProcessed_AD014_Preprocessed_FirstClick.mat
# 0
# 389
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
# ...
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 643
# subject idx is
# 19
# PreProcessed_AD030_Preprocessed_FirstClick.mat
# 0
# 687
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 687
# subject idx is
# 20
# PreProcessed_AD031_Preprocessed_FirstClick.mat
# 0
# 731
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 731

# %%
raw_list_mean_1st_click
# Out:
# [<RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>]

# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import kurtosis

# Define frequency bands
alpha_band = (8, 13)  # Alpha band frequencies
beta_band = (13, 30)  # Beta band frequencies

features_psd_1st_click = []
for raw in raw_list_mean_1st_click:
    # Compute PSD
 #   psd_spectrum_healthy = raw.compute_psd(method='multitaper', fmin=4, fmax=40, tmin=None, tmax=None )
    psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
    print(psd_spectrum_healthy.shape)
    print(psd_spectrum_healthy.freqs)
    
    features=[]
    for idx, ch_name in enumerate(list_1):
        psd_data = psd_spectrum_healthy[idx]  # PSD data for the current channel
        

    # Statistical Features
        mean_power = np.mean(psd_data)
        variance_power = np.var(psd_data)
    
        skewness_power = stats.skew(psd_data)
        kurtosis_power = stats.kurtosis(psd_data)
        freqs = psd_spectrum_healthy.freqs  # Frequency values
        max_power_freq = freqs[np.argmax(psd_data)]
        max_power = np.max(psd_data)
        band_power_alpha = np.sum(psd_data[:,(freqs >= 8) & (freqs <= 13)])  # Alpha band
        band_power_beta = np.sum(psd_data[:,(freqs >= 13) & (freqs <= 30)])  # Beta band
        
                    # Compute entropy for alpha band
        alpha_prob = psd_data[:,(freqs >= alpha_band[0]) & (freqs <= alpha_band[1])] / np.sum(psd_data)
        spectral_entropy_alpha = -np.sum(alpha_prob * np.log2(alpha_prob + 1e-12))  # Add a small value to avoid log(0)

        # Compute entropy for beta band
        beta_prob = psd_data[:,(freqs >= beta_band[0]) & (freqs <= beta_band[1])] / np.sum(psd_data)
        spectral_entropy_beta = -np.sum(beta_prob * np.log2(beta_prob + 1e-12))  # Add a small value to avoid log(0)

        
 
        # Append features for the current channel
        channel_features = [mean_power, variance_power, skewness_power, kurtosis_power,
                            max_power_freq, max_power, band_power_alpha, band_power_beta,
                            spectral_entropy_alpha, spectral_entropy_beta]
        
       
        features.append(channel_features)

# Convert features to numpy array
    
    features_psd_1st_click.append(features)
    
features_psd_1st_click = np.array(features_psd_1st_click)
# Out:
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:35: RuntimeWarning: invalid value encountered in true_divide
#   alpha_prob = psd_data[:,(freqs >= alpha_band[0]) & (freqs <= alpha_band[1])] / np.sum(psd_data)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:39: RuntimeWarning: invalid value encountered in true_divide
#   beta_prob = psd_data[:,(freqs >= beta_band[0]) & (freqs <= beta_band[1])] / np.sum(psd_data)
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:13: UserWarning: Zero value in spectrum for channel MEG2542+2543
# ...
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\251301982.py:56: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   features_psd_1st_click = np.array(features_psd_1st_click)

# %%
features_psd_1st_click.shape
# Out:
# (731, 102, 10)

# %%
# Exclude the 2nd and 3rd columns in the third dimension
new_features_psd_1st_click = np.delete(features_psd_1st_click, [2, 3], axis=2)

# %%
new_features_psd_1st_click.shape
# Out:
# (731, 102, 8)

# %%
import numpy as np
import pandas as pd
    
# Import necessary libraries
from scipy.stats import skew, kurtosis
from scipy.signal import find_peaks
from numpy import diff

# Initialize an empty list to store subject data
subject_data_list = []

# Number of subjects
#num_subjects = 5
# Create an empty list to store evoked objects for each subject
evoked_list = []
features_erp_1st_click = []

# Size of each array
array_size = (102, 201)
num_trials=0
start=0
raw_list = []
# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject, trials in enumerate(trial_counts_1st_click):
    subject_data = []
    print('subject idx is')
    print(subject)
    
    name=matfiles_1st_click[subject]
    print(name)
    dat = mat73.loadmat(matfiles_1st_click[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        print('in if')
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
    
    num_trials+=len(new)

    print(start)
    end=num_trials
    print(end) 
    print(new[0].shape)
    trial_data=[]
    # Create empty lists to store features
    peak_amplitudes = []
    latencies = []
    auc_values = []
    slopes = []
    features_erp_1st_click_healthy=[]
    features=[]
    from scipy.integrate import simps
    

    # Initialize empty lists to store features
    peak_to_peak_amplitudes = []
    mean_absolute_amplitudes = []
    rms_amplitudes = []
    std_devs = []
    skewness_values = []
    kurtosis_values = []
    zero_crossing_rates = []
    aar_values=[]
    zork_values=[]
# Loop through subjects
    for trial in range(trials):
        #print(new[0].shape[1])
        if new[0].shape[1] == 10001:
            trial_data.append(new[trial][:102,:9901])
            times = grand_average_rsec_healthy.times
            
        else:
            trial_data.append(new[trial][:102,200:351])
            times = grand_average_healthy.times
        trial=trial_data[0]
        features=[]
        for ch_idx in range(len(info['ch_names'])):
            # Extract ERP data for the current channel
            channel_data = trial[ch_idx,:]
        # Compute peak amplitude and latency
            peak_amplitude = np.max(channel_data)
             # Compute peak-to-peak amplitude
            peak_to_peak_amplitude = np.max(channel_data) - np.min(channel_data)
            peak_to_peak_amplitudes.append(peak_to_peak_amplitude)
            # Compute mean absolute amplitude
            mean_absolute_amplitude = np.mean(np.abs(channel_data))
            mean_absolute_amplitudes.append(mean_absolute_amplitude)
                # Compute RMS amplitude
            rms_amplitude = np.sqrt(np.mean(channel_data**2))
            rms_amplitudes.append(rms_amplitude)

            # Compute standard deviation
            std_dev = np.std(channel_data)
            std_devs.append(std_dev)

            # Compute skewness
            skewness = skew(channel_data)
            skewness_values.append(skewness)

            # Compute kurtosis
            kurtosis_val = kurtosis(channel_data)
            kurtosis_values.append(kurtosis_val)

            # Compute zero crossing rate
            zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
            zero_crossing_rates.append(zero_crossings)

            latency = times[np.argmax(channel_data)]

        # Calculate area under the curve (AUC)
            auc_value = simps(channel_data, times)

        # Calculate slope (e.g., by fitting a linear regression model)
        # You can use numpy's polyfit function for this purpose
            slope_coefficients = np.polyfit(times, channel_data, 1)
            slope = slope_coefficients[0]


            zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
            zero_crossing_rates.append(zero_crossings)

            # Compute AAR
            aar = peak_to_peak_amplitude / mean_absolute_amplitude
            aar_values.append(aar)

            # Compute ZORK
            zork = zero_crossings / kurtosis_val
            zork_values.append(zork)

            peak_to_peak_amplitudes1=np.array(peak_to_peak_amplitudes)
            channel_features = [peak_amplitude,latency,auc_value,slope,
                                peak_to_peak_amplitude, 
                                     mean_absolute_amplitude, 
                                     rms_amplitude, 
                                     std_dev, 
                                     skewness, 
                                     kurtosis_val, 
                                     zero_crossings,aar,zork]

            features.append(channel_features)

        features_erp_1st_click.append(features)   
    
features_erp_1st_click= np.array(features_erp_1st_click,dtype=object)
# Out:
# subject idx is
# 0
# PreProcessed_AD001_Preprocessed_FirstClick.mat
# 0
# 31
# (204, 401)
# subject idx is
# 1
# PreProcessed_AD002_Preprocessed_FirstClick.mat
# 0
# 92
# (204, 401)
# subject idx is
# 2
# PreProcessed_AD003_Preprocessed_FirstClick.mat
# 0
# 113
# (204, 401)
# subject idx is
# 3
# PreProcessed_AD004_Preprocessed_FirstClick.mat
# 0
# 145
# (204, 401)
# subject idx is
# 4
# PreProcessed_AD006_Preprocessed_FirstClick.mat
# 0
# 180
# (204, 401)
# subject idx is
# 5
# PreProcessed_AD008_Preprocessed_FirstClick.mat
# 0
# 208
# (204, 401)
# subject idx is
# 6
# PreProcessed_AD010_Preprocessed_FirstClick.mat
# 0
# 243
# (204, 401)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\3371479376.py:125: RuntimeWarning: invalid value encountered in double_scalars
#   aar = peak_to_peak_amplitude / mean_absolute_amplitude
# subject idx is
# 7
# PreProcessed_AD011_Preprocessed_FirstClick.mat
# 0
# 271
# (204, 401)
# subject idx is
# 8
# PreProcessed_AD012_Preprocessed_FirstClick.mat
# 0
# 315
# (204, 401)
# subject idx is
# 9
# PreProcessed_AD013_Preprocessed_FirstClick.mat
# 0
# 355
# (204, 401)
# subject idx is
# 10
# PreProcessed_AD014_Preprocessed_FirstClick.mat
# 0
# 389
# (204, 401)
# subject idx is
# 11
# PreProcessed_AD015_Preprocessed_FirstClick.mat
# 0
# 415
# (204, 401)
# subject idx is
# 12
# PreProcessed_AD016_Preprocessed_FirstClick.mat
# 0
# 441
# (204, 401)
# subject idx is
# 13
# PreProcessed_AD017_Preprocessed_FirstClick.mat
# 0
# 467
# (204, 401)
# subject idx is
# 14
# PreProcessed_AD018_Preprocessed_FirstClick.mat
# 0
# 500
# (204, 401)
# subject idx is
# 15
# PreProcessed_AD020_Preprocessed_FirstClick.mat
# 0
# 525
# (204, 401)
# subject idx is
# 16
# PreProcessed_AD026_Preprocessed_FirstClick.mat
# 0
# 570
# (204, 401)
# subject idx is
# 17
# PreProcessed_AD027_Preprocessed_FirstClick.mat
# 0
# 604
# (204, 401)
# subject idx is
# 18
# PreProcessed_AD028_Preprocessed_FirstClick.mat
# 0
# 643
# (204, 401)
# subject idx is
# 19
# PreProcessed_AD030_Preprocessed_FirstClick.mat
# 0
# 687
# (204, 401)
# subject idx is
# 20
# PreProcessed_AD031_Preprocessed_FirstClick.mat
# 0
# 731
# (204, 401)

# %%
features_erp_1st_click.shape
# Out:
# (731, 102, 13)

# %%
usable_features_psd_1st_click=new_features_psd_1st_click[:,:,4:8]
print(usable_features_psd_1st_click.shape)
# Out:
# (731, 102, 4)

# %%
import numpy as np

reshaped_psd_1st_click = []
reshaped_erp_1st_click = []

# Start index for slicing
start_idx = 0

# Iterate over each subject and their respective trial count
for trials in trial_counts_1st_click:
    # Calculate the end index for slicing
    end_idx = start_idx + trials
    
    # Slice the data for the current subject
    subject_psd = usable_features_psd_1st_click[start_idx:end_idx, :, :]
    subject_erp = features_erp_1st_click[start_idx:end_idx, :, :]
    
    # Append the reshaped data to the list
    reshaped_psd_1st_click.append(subject_psd)
    reshaped_erp_1st_click.append(subject_erp)
    
    # Update the start index for the next iteration
    start_idx = end_idx

# Convert the lists to numpy arrays with the desired shape
reshaped_psd_1st_click = np.array(reshaped_psd_1st_click)  # Shape will be (21, trials_per_subject, 102, 4)
reshaped_erp_1st_click = np.array(reshaped_erp_1st_click)  # Shape will be (21, trials_per_subject, 102, 13)
# Out:
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\591420145.py:26: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   reshaped_psd_1st_click = np.array(reshaped_psd_1st_click)  # Shape will be (21, trials_per_subject, 102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\591420145.py:27: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   reshaped_erp_1st_click = np.array(reshaped_erp_1st_click)  # Shape will be (21, trials_per_subject, 102, 13)

# %%
reshaped_erp_1st_click[2].shape
# Out:
# (21, 102, 13)

# %%
import numpy as np
from scipy.io import savemat

psd_file_path = 'D:/internship_ulster_university/features without grand averaging/1st_click_psd_without_grand_average.mat'
erp_file_path = 'D:/internship_ulster_university/features without grand averaging/1st_click_erp_without_grand_average.mat'

# Create a dictionary to hold the variables to be saved
psd_dict = {'reshaped_psd': reshaped_psd_1st_click}
erp_dict = {'reshaped_erp': reshaped_erp_1st_click}

# Save the reshaped arrays to .mat files
savemat(psd_file_path, psd_dict)
savemat(erp_file_path, erp_dict)

print(f"Files saved successfully to {psd_file_path} and {erp_file_path}")
# Out:
# Files saved successfully to D:/internship_ulster_university/features without grand averaging/1st_click_psd_without_grand_average.mat and D:/internship_ulster_university/features without grand averaging/1st_click_erp_without_grand_average.mat

# %% [markdown]
# # 2nd click data

# %%
import os
import glob


# Construct the path to the target folder
folder_path = "D:\internship_ulster_university\preprocessed_filtered_2nd_click"

# Move into the target folder
os.chdir(folder_path)

# Select all files ending with ".mat"
matfiles_2nd_click = glob.glob("*.mat")

# Print the list of selected files
print("Selected .mat files:")
for file in matfiles_2nd_click:
    print(file)
# Out:
# Selected .mat files:
# PreProcessed_AD001_Preprocessed_SecondClick.mat
# PreProcessed_AD002_Preprocessed_SecondClick.mat
# PreProcessed_AD003_Preprocessed_SecondClick.mat
# PreProcessed_AD004_Preprocessed_SecondClick.mat
# PreProcessed_AD006_Preprocessed_SecondClick.mat
# PreProcessed_AD008_Preprocessed_SecondClick.mat
# PreProcessed_AD010_Preprocessed_SecondClick.mat
# PreProcessed_AD011_Preprocessed_SecondClick.mat
# PreProcessed_AD012_Preprocessed_SecondClick.mat
# PreProcessed_AD013_Preprocessed_SecondClick.mat
# PreProcessed_AD014_Preprocessed_SecondClick.mat
# PreProcessed_AD015_Preprocessed_SecondClick.mat
# PreProcessed_AD016_Preprocessed_SecondClick.mat
# PreProcessed_AD017_Preprocessed_SecondClick.mat
# PreProcessed_AD018_Preprocessed_SecondClick.mat
# PreProcessed_AD020_Preprocessed_SecondClick.mat
# PreProcessed_AD026_Preprocessed_SecondClick.mat
# PreProcessed_AD027_Preprocessed_SecondClick.mat
# PreProcessed_AD028_Preprocessed_SecondClick.mat
# PreProcessed_AD030_Preprocessed_SecondClick.mat
# PreProcessed_AD031_Preprocessed_SecondClick.mat

# %%
num_trials=0
trial_counts_2nd_click=[]
for subject in range(len(matfiles_2nd_click)):
    subject_data = []
    name=matfiles_2nd_click[subject]
    print(name)
    dat = mat73.loadmat(matfiles_2nd_click[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
#     print(new)
    trial_counts_2nd_click.append(len(new))
    print(len(new))
    num_trials+=len(new)
# Out:
# PreProcessed_AD001_Preprocessed_SecondClick.mat
# 34
# PreProcessed_AD002_Preprocessed_SecondClick.mat
# 59
# PreProcessed_AD003_Preprocessed_SecondClick.mat
# 26
# PreProcessed_AD004_Preprocessed_SecondClick.mat
# 34
# PreProcessed_AD006_Preprocessed_SecondClick.mat
# 35
# PreProcessed_AD008_Preprocessed_SecondClick.mat
# 31
# PreProcessed_AD010_Preprocessed_SecondClick.mat
# 30
# PreProcessed_AD011_Preprocessed_SecondClick.mat
# 21
# PreProcessed_AD012_Preprocessed_SecondClick.mat
# 40
# PreProcessed_AD013_Preprocessed_SecondClick.mat
# 40
# PreProcessed_AD014_Preprocessed_SecondClick.mat
# 34
# PreProcessed_AD015_Preprocessed_SecondClick.mat
# 30
# PreProcessed_AD016_Preprocessed_SecondClick.mat
# 31
# PreProcessed_AD017_Preprocessed_SecondClick.mat
# 28
# PreProcessed_AD018_Preprocessed_SecondClick.mat
# 36
# PreProcessed_AD020_Preprocessed_SecondClick.mat
# 39
# PreProcessed_AD026_Preprocessed_SecondClick.mat
# 40
# PreProcessed_AD027_Preprocessed_SecondClick.mat
# 33
# PreProcessed_AD028_Preprocessed_SecondClick.mat
# 32
# PreProcessed_AD030_Preprocessed_SecondClick.mat
# 43
# PreProcessed_AD031_Preprocessed_SecondClick.mat
# 46

# %%
trial_counts_2nd_click
# Out:
# [34,
#  59,
#  26,
#  34,
#  35,
#  31,
#  30,
#  21,
#  40,
#  40,
#  34,
#  30,
#  31,
#  28,
#  36,
#  39,
#  40,
#  33,
#  32,
#  43,
#  46]

# %%
import numpy as np
import pandas as pd

# Initialize an empty list to store subject data
subject_data_list = []

# Number of subjects
#num_subjects = 5


# Size of each array
array_size = (102, 201)
num_trials=0
start=0
raw_list_mean_2nd_click = []
# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject, trials in enumerate(trial_counts_2nd_click):
    subject_data = []
    print('subject idx is')
    print(subject)
    
    name=matfiles_2nd_click[subject]
    print(name)
    dat = mat73.loadmat(matfiles_2nd_click[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
    
    num_trials+=len(new)

    print(start)
    end=num_trials
    print(end)
    trial_data=[]
    

    for trial in range(trials):
        #print(new[0].shape[1])
        if new[0].shape[1] == 10001:
            trial_data.append(new[trial][:102,:9901])
            times = grand_average_rsec_healthy.times
            
        else:
            trial_data.append(new[trial][:102,200:351])
            times = grand_average_healthy.times
            
        trial=trial_data[0]
        raw = mne.io.RawArray(trial, info)
        raw_list_mean_2nd_click.append(raw)
    print(len(raw_list_mean_2nd_click))
# #Concatenate Raw objects if needed
# raw_combined_mean_mci_ts = mne.concatenate_raws(raw_list_mean_mci_ts)

# print(len(raw_combined_mean_mci_ts))
# Out:
# subject idx is
# 0
# PreProcessed_AD001_Preprocessed_SecondClick.mat
# 0
# 34
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 34
# subject idx is
# 1
# PreProcessed_AD002_Preprocessed_SecondClick.mat
# 0
# 93
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 93
# subject idx is
# 2
# PreProcessed_AD003_Preprocessed_SecondClick.mat
# 0
# 119
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 119
# subject idx is
# 3
# PreProcessed_AD004_Preprocessed_SecondClick.mat
# 0
# 153
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 153
# subject idx is
# 4
# PreProcessed_AD006_Preprocessed_SecondClick.mat
# 0
# 188
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 188
# subject idx is
# 5
# PreProcessed_AD008_Preprocessed_SecondClick.mat
# 0
# 219
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 219
# subject idx is
# 6
# PreProcessed_AD010_Preprocessed_SecondClick.mat
# 0
# 249
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 249
# subject idx is
# 7
# PreProcessed_AD011_Preprocessed_SecondClick.mat
# 0
# 270
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 270
# subject idx is
# 8
# PreProcessed_AD012_Preprocessed_SecondClick.mat
# 0
# 310
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 310
# subject idx is
# 9
# PreProcessed_AD013_Preprocessed_SecondClick.mat
# 0
# 350
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 350
# subject idx is
# 10
# PreProcessed_AD014_Preprocessed_SecondClick.mat
# 0
# 384
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# ...
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 621
# subject idx is
# 18
# PreProcessed_AD028_Preprocessed_SecondClick.mat
# 0
# 653
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 653
# subject idx is
# 19
# PreProcessed_AD030_Preprocessed_SecondClick.mat
# 0
# 696
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 696
# subject idx is
# 20
# PreProcessed_AD031_Preprocessed_SecondClick.mat
# 0
# 742
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# Creating RawArray with float64 data, n_channels=102, n_times=151
#     Range : 0 ... 150 =      0.000 ...     0.150 secs
# Ready.
# 742

# %%
raw_list_mean_2nd_click
# Out:
# [<RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>,
#  <RawArray | 102 x 151 (0.1 s), ~221 kB, data loaded>]

# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import kurtosis

features_psd_2nd_click = []
for raw in raw_list_mean_2nd_click:
    # Compute PSD
    psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
    #psd_spectrum_healthy = raw.compute_psd(method='multitaper', fmin=0, fmax=40, tmin=None, tmax=None)
    print(psd_spectrum_healthy.shape)
    
    
    features=[]
    for idx, ch_name in enumerate(list_1):
        psd_data = psd_spectrum_healthy[idx]  # PSD data for the current channel

    # Statistical Features
        mean_power = np.mean(psd_data)
        variance_power = np.var(psd_data)
    
        skewness_power = stats.skew(psd_data)
        kurtosis_power = stats.kurtosis(psd_data)
        freqs = psd_spectrum_healthy.freqs  # Frequency values
        max_power_freq = freqs[np.argmax(psd_data)]
        max_power = np.max(psd_data)
        band_power_alpha = np.sum(psd_data[:,(freqs >= 8) & (freqs <= 13)])  # Alpha band
        band_power_beta = np.sum(psd_data[:,(freqs >= 13) & (freqs <= 30)])  # Beta band
        
                    # Compute entropy for alpha band
        alpha_prob = psd_data[:,(freqs >= alpha_band[0]) & (freqs <= alpha_band[1])] / np.sum(psd_data)
        spectral_entropy_alpha = -np.sum(alpha_prob * np.log2(alpha_prob + 1e-12))  # Add a small value to avoid log(0)

        # Compute entropy for beta band
        beta_prob = psd_data[:,(freqs >= beta_band[0]) & (freqs <= beta_band[1])] / np.sum(psd_data)
        spectral_entropy_beta = -np.sum(beta_prob * np.log2(beta_prob + 1e-12))  # Add a small value to avoid log(0)

        
 
        # Append features for the current channel
        channel_features = [mean_power, variance_power, skewness_power, kurtosis_power,
                            max_power_freq, max_power, band_power_alpha, band_power_beta,
                            spectral_entropy_alpha, spectral_entropy_beta]
        
       
        features.append(channel_features)

# Convert features to numpy array
    
    features_psd_2nd_click.append(features)
    
features_psd_2nd_click = np.array(features_psd_2nd_click)
# Out:
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:30: RuntimeWarning: invalid value encountered in true_divide
#   alpha_prob = psd_data[:,(freqs >= alpha_band[0]) & (freqs <= alpha_band[1])] / np.sum(psd_data)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:34: RuntimeWarning: invalid value encountered in true_divide
#   beta_prob = psd_data[:,(freqs >= beta_band[0]) & (freqs <= beta_band[1])] / np.sum(psd_data)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:8: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2441752013.py:51: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   features_psd_2nd_click = np.array(features_psd_2nd_click)

# %%
features_psd_2nd_click.shape
# Out:
# (742, 102, 10)

# %%
# Exclude the 2nd and 3rd columns in the third dimension
new_features_psd_2nd_click = np.delete(features_psd_2nd_click, [2, 3], axis=2)

# %%
new_features_psd_2nd_click.shape
# Out:
# (742, 102, 8)

# %%
import numpy as np
import pandas as pd
    
# Import necessary libraries
from scipy.stats import skew, kurtosis
from scipy.signal import find_peaks
from numpy import diff

# Initialize an empty list to store subject data
subject_data_list = []

# Number of subjects
#num_subjects = 5
# Create an empty list to store evoked objects for each subject
evoked_list = []
features_erp_2nd_click = []

# Size of each array
array_size = (102, 201)
num_trials=0
start=0
raw_list = []
# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject, trials in enumerate(trial_counts_2nd_click):
    subject_data = []
    print('subject idx is')
    print(subject)
    
    name=matfiles_2nd_click[subject]
    print(name)
    dat = mat73.loadmat(matfiles_2nd_click[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        print('in if')
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
    
    num_trials+=len(new)

    print(start)
    end=num_trials
    print(end) 
    print(new[0].shape)
    trial_data=[]
    peak_amplitudes = []
    latencies = []
    auc_values = []
    slopes = []
    features_erp_1st_click_healthy=[]
    features=[]
    from scipy.integrate import simps
    

    # Initialize empty lists to store features
    peak_to_peak_amplitudes = []
    mean_absolute_amplitudes = []
    rms_amplitudes = []
    std_devs = []
    skewness_values = []
    kurtosis_values = []
    zero_crossing_rates = []
    aar_values=[]
    zork_values=[]

# Loop through subjects
    for trial in range(trials):
        #print(new[0].shape[1])
        if new[0].shape[1] == 10001:
            trial_data.append(new[trial][:102,:9901])
            times = grand_average_rsec_healthy.times
            
        else:
            trial_data.append(new[trial][:102,200:351])
            times = grand_average_healthy.times
        trial=trial_data[0]
        features=[]

# Iterate through channels
        for ch_idx in range(len(info['ch_names'])):
            # Extract ERP data for the current channel
            channel_data = trial[ch_idx,:]


        # Compute peak amplitude and latency
            peak_amplitude = np.max(channel_data)
             # Compute peak-to-peak amplitude
            peak_to_peak_amplitude = np.max(channel_data) - np.min(channel_data)
            peak_to_peak_amplitudes.append(peak_to_peak_amplitude)
            # Compute mean absolute amplitude
            mean_absolute_amplitude = np.mean(np.abs(channel_data))
            mean_absolute_amplitudes.append(mean_absolute_amplitude)
                # Compute RMS amplitude
            rms_amplitude = np.sqrt(np.mean(channel_data**2))
            rms_amplitudes.append(rms_amplitude)

            # Compute standard deviation
            std_dev = np.std(channel_data)
            std_devs.append(std_dev)

            # Compute skewness
            skewness = skew(channel_data)
            skewness_values.append(skewness)

            # Compute kurtosis
            kurtosis_val = kurtosis(channel_data)
            kurtosis_values.append(kurtosis_val)

            # Compute zero crossing rate
            zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
            zero_crossing_rates.append(zero_crossings)

            latency = times[np.argmax(channel_data)]

        # Calculate area under the curve (AUC)
            auc_value = simps(channel_data, times)

        # Calculate slope (e.g., by fitting a linear regression model)
        # You can use numpy's polyfit function for this purpose
            slope_coefficients = np.polyfit(times, channel_data, 1)
            slope = slope_coefficients[0]


            zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
            zero_crossing_rates.append(zero_crossings)

            # Compute AAR
            aar = peak_to_peak_amplitude / mean_absolute_amplitude
            aar_values.append(aar)

            # Compute ZORK
            zork = zero_crossings / kurtosis_val
            zork_values.append(zork)

            peak_to_peak_amplitudes1=np.array(peak_to_peak_amplitudes)
            channel_features = [peak_amplitude,latency,auc_value,slope,
                                peak_to_peak_amplitude, 
                                     mean_absolute_amplitude, 
                                     rms_amplitude, 
                                     std_dev, 
                                     skewness, 
                                     kurtosis_val, 
                                     zero_crossings,aar,zork]

            features.append(channel_features)

        features_erp_2nd_click.append(features)
    
features_erp_2nd_click= np.array(features_erp_2nd_click,dtype=object)
# Out:
# subject idx is
# 0
# PreProcessed_AD001_Preprocessed_SecondClick.mat
# 0
# 34
# (204, 401)
# subject idx is
# 1
# PreProcessed_AD002_Preprocessed_SecondClick.mat
# 0
# 93
# (204, 401)
# subject idx is
# 2
# PreProcessed_AD003_Preprocessed_SecondClick.mat
# 0
# 119
# (204, 401)
# subject idx is
# 3
# PreProcessed_AD004_Preprocessed_SecondClick.mat
# 0
# 153
# (204, 401)
# subject idx is
# 4
# PreProcessed_AD006_Preprocessed_SecondClick.mat
# 0
# 188
# (204, 401)
# subject idx is
# 5
# PreProcessed_AD008_Preprocessed_SecondClick.mat
# 0
# 219
# (204, 401)
# subject idx is
# 6
# PreProcessed_AD010_Preprocessed_SecondClick.mat
# 0
# 249
# (204, 401)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\2403161103.py:129: RuntimeWarning: invalid value encountered in double_scalars
#   aar = peak_to_peak_amplitude / mean_absolute_amplitude
# subject idx is
# 7
# PreProcessed_AD011_Preprocessed_SecondClick.mat
# 0
# 270
# (204, 401)
# subject idx is
# 8
# PreProcessed_AD012_Preprocessed_SecondClick.mat
# 0
# 310
# (204, 401)
# subject idx is
# 9
# PreProcessed_AD013_Preprocessed_SecondClick.mat
# 0
# 350
# (204, 401)
# subject idx is
# 10
# PreProcessed_AD014_Preprocessed_SecondClick.mat
# 0
# 384
# (204, 401)
# subject idx is
# 11
# PreProcessed_AD015_Preprocessed_SecondClick.mat
# 0
# 414
# (204, 401)
# subject idx is
# 12
# PreProcessed_AD016_Preprocessed_SecondClick.mat
# 0
# 445
# (204, 401)
# subject idx is
# 13
# PreProcessed_AD017_Preprocessed_SecondClick.mat
# 0
# 473
# (204, 401)
# subject idx is
# 14
# PreProcessed_AD018_Preprocessed_SecondClick.mat
# 0
# 509
# (204, 401)
# subject idx is
# 15
# PreProcessed_AD020_Preprocessed_SecondClick.mat
# 0
# 548
# (204, 401)
# subject idx is
# 16
# PreProcessed_AD026_Preprocessed_SecondClick.mat
# 0
# 588
# (204, 401)
# subject idx is
# 17
# PreProcessed_AD027_Preprocessed_SecondClick.mat
# 0
# 621
# (204, 401)
# subject idx is
# 18
# PreProcessed_AD028_Preprocessed_SecondClick.mat
# 0
# 653
# (204, 401)
# subject idx is
# 19
# PreProcessed_AD030_Preprocessed_SecondClick.mat
# 0
# 696
# (204, 401)
# subject idx is
# 20
# PreProcessed_AD031_Preprocessed_SecondClick.mat
# 0
# 742
# (204, 401)

# %%
features_erp_2nd_click.shape
# Out:
# (742, 102, 13)

# %%
usable_features_psd_2nd_click=new_features_psd_2nd_click[:,:,4:8]
print(usable_features_psd_2nd_click.shape)
# Out:
# (742, 102, 4)

# %%
import numpy as np

reshaped_psd_2nd_click = []
reshaped_erp_2nd_click = []

# Start index for slicing
start_idx = 0

# Iterate over each subject and their respective trial count
for trials in trial_counts_2nd_click:
    # Calculate the end index for slicing
    end_idx = start_idx + trials
    
    # Slice the data for the current subject
    subject_psd = usable_features_psd_2nd_click[start_idx:end_idx, :, :]
    subject_erp = features_erp_2nd_click[start_idx:end_idx, :, :]
    
    # Append the reshaped data to the list
    reshaped_psd_2nd_click.append(subject_psd)
    reshaped_erp_2nd_click.append(subject_erp)
    
    # Update the start index for the next iteration
    start_idx = end_idx

# Convert the lists to numpy arrays with the desired shape
reshaped_psd_2nd_click = np.array(reshaped_psd_2nd_click)  # Shape will be (21, trials_per_subject, 102, 4)
reshaped_erp_2nd_click = np.array(reshaped_erp_2nd_click)  # Shape will be (21, trials_per_subject, 102, 13)
# Out:
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\1726156992.py:26: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   reshaped_psd_2nd_click = np.array(reshaped_psd_2nd_click)  # Shape will be (21, trials_per_subject, 102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3188\1726156992.py:27: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   reshaped_erp_2nd_click = np.array(reshaped_erp_2nd_click)  # Shape will be (21, trials_per_subject, 102, 13)

# %%
reshaped_psd_2nd_click[2].shape
# Out:
# (26, 102, 4)

# %%
import numpy as np
from scipy.io import savemat

psd_file_path = 'D:/internship_ulster_university/features without grand averaging/2nd_click_psd_without_grand_average.mat'
erp_file_path = 'D:/internship_ulster_university/features without grand averaging/2nd_click_erp_without_grand_average.mat'

# Create a dictionary to hold the variables to be saved
psd_dict = {'reshaped_psd': reshaped_psd_2nd_click}
erp_dict = {'reshaped_erp': reshaped_erp_2nd_click}

# Save the reshaped arrays to .mat files
savemat(psd_file_path, psd_dict)
savemat(erp_file_path, erp_dict)

print(f"Files saved successfully to {psd_file_path} and {erp_file_path}")
# Out:
# Files saved successfully to D:/internship_ulster_university/features without grand averaging/2nd_click_psd_without_grand_average.mat and D:/internship_ulster_university/features without grand averaging/2nd_click_erp_without_grand_average.mat

# %% [markdown]
# # movie state

# %%
import os
import glob


# Construct the path to the target folder
folder_path = "D:\internship_ulster_university\combined_grad_movie_state"

# Move into the target folder
os.chdir(folder_path)

# Select all files ending with ".mat"
matfiles_ms = glob.glob("*.mat")

# Print the list of selected files
print("Selected .mat files:")
for file in matfiles_ms:
    print(file)
# Out:
# Selected .mat files:
# Combined_grad_AD001_MoviesWatching.mat
# Combined_grad_AD002_MoviesWatching.mat
# Combined_grad_AD003_MoviesWatching.mat
# Combined_grad_AD004_MoviesWatching.mat
# Combined_grad_AD006_MoviesWatching.mat
# Combined_grad_AD008_MoviesWatching.mat
# Combined_grad_AD010_MoviesWatching.mat
# Combined_grad_AD011_MoviesWatching.mat
# Combined_grad_AD012_MoviesWatching.mat
# Combined_grad_AD013_MoviesWatching.mat
# Combined_grad_AD014_MoviesWatching.mat
# Combined_grad_AD015_MoviesWatching.mat
# Combined_grad_AD016_MoviesWatching.mat
# Combined_grad_AD017_MoviesWatching.mat
# Combined_grad_AD018_MoviesWatching.mat
# Combined_grad_AD020_MoviesWatching.mat
# Combined_grad_AD026_MoviesWatching.mat
# Combined_grad_AD027_MoviesWatching.mat
# Combined_grad_AD028_MoviesWatching.mat
# Combined_grad_AD030_MoviesWatching.mat
# Combined_grad_AD031_MoviesWatching.mat

# %%
trial_counts_movie_state=[]
num_trials=0
for subject in range(len(matfiles_ms)):
    name=matfiles_ms[subject]
    print(name)
    dat = mat73.loadmat(matfiles_ms[subject])
    for key, value in dat.items():
        print(key)
    data=dat['MEG']
    for key, value in data.items():
        print(key)
    new=data['trial']
    print('new shape')
    print(len(new))
    data2=np.asarray(new)
    print(data2.shape[0])
    trial_counts_movie_state.append(data2.shape[0])
    num_trials+=data2.shape[0]
# Out:
# Combined_grad_AD001_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 52
# 52
# Combined_grad_AD002_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 51
# 51
# Combined_grad_AD003_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 52
# 52
# Combined_grad_AD004_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49
# Combined_grad_AD006_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 48
# 48
# Combined_grad_AD008_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49
# Combined_grad_AD010_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 50
# 50
# Combined_grad_AD011_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 50
# 50
# Combined_grad_AD012_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49
# Combined_grad_AD013_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49
# Combined_grad_AD014_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 50
# 50
# Combined_grad_AD015_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 50
# 50
# Combined_grad_AD016_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49
# Combined_grad_AD017_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49
# Combined_grad_AD018_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49
# Combined_grad_AD020_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49
# Combined_grad_AD026_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 50
# 50
# Combined_grad_AD027_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49
# Combined_grad_AD028_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49
# Combined_grad_AD030_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49
# Combined_grad_AD031_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49

# %%
trial_counts_movie_state
# Out:
# [52,
#  51,
#  52,
#  49,
#  48,
#  49,
#  50,
#  50,
#  49,
#  49,
#  50,
#  50,
#  49,
#  49,
#  49,
#  49,
#  50,
#  49,
#  49,
#  49,
#  49]

# %%
import numpy as np
import pandas as pd

trial_data=[]
num_trials_movie_state_healthy=0
start=0
raw_list_mean_ms = []
for subject, trials in enumerate(trial_counts_movie_state):
    print('subject idx is')
    print(subject)
    print("trials is")
    print(trials)
    name=matfiles_ms[subject]
    print(name)
    dat = mat73.loadmat(matfiles_ms[subject])
    data=dat['MEG']
    new=data['trial']
    data2=np.asarray(new)
    print(data2.shape)
    for trial in range(trials):
        data_trial=data2[trial,:102,:]
        print("shape of 1 trial data")
        print(data_trial.shape)
        raw = mne.io.RawArray(data_trial, info)
        raw_list_mean_ms.append(raw)
    print(len(raw_list_mean_ms))
# Out:
# subject idx is
# 0
# trials is
# 52
# Combined_grad_AD001_MoviesWatching.mat
# (52, 204, 10000)
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 52
# subject idx is
# 1
# trials is
# 51
# Combined_grad_AD002_MoviesWatching.mat
# (51, 204, 10000)
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 103
# subject idx is
# 2
# trials is
# 52
# Combined_grad_AD003_MoviesWatching.mat
# (52, 204, 10000)
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 155
# subject idx is
# 3
# trials is
# 49
# Combined_grad_AD004_MoviesWatching.mat
# (49, 204, 10000)
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 204
# subject idx is
# 4
# trials is
# 48
# Combined_grad_AD006_MoviesWatching.mat
# (48, 204, 10000)
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 252
# subject idx is
# 5
# trials is
# 49
# Combined_grad_AD008_MoviesWatching.mat
# (49, 204, 10000)
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# ...
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 992
# subject idx is
# 20
# trials is
# 49
# Combined_grad_AD031_MoviesWatching.mat
# (49, 204, 10000)
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# shape of 1 trial data
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 1041

# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import kurtosis
alpha_band=(8,13)
beta_band=(13,30)
features_psd_ms = []
for raw in raw_list_mean_ms:
    # Compute PSD
    psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
    #psd_spectrum_healthy = raw.compute_psd(method='multitaper', fmin=0, fmax=40, tmin=None, tmax=None)
    print(psd_spectrum_healthy.shape)
    
    
    features=[]
    for idx, ch_name in enumerate(list_1):
        psd_data = psd_spectrum_healthy[idx]  # PSD data for the current channel

    # Statistical Features
        mean_power = np.mean(psd_data)
        variance_power = np.var(psd_data)
    
        skewness_power = stats.skew(psd_data)
        kurtosis_power = stats.kurtosis(psd_data)
        freqs = psd_spectrum_healthy.freqs  # Frequency values
        max_power_freq = freqs[np.argmax(psd_data)]
        max_power = np.max(psd_data)
        band_power_alpha = np.sum(psd_data[:,(freqs >= 8) & (freqs <= 13)])  # Alpha band
        band_power_beta = np.sum(psd_data[:,(freqs >= 13) & (freqs <= 30)])  # Beta band
        
                    # Compute entropy for alpha band
        alpha_prob = psd_data[:,(freqs >= alpha_band[0]) & (freqs <= alpha_band[1])] / np.sum(psd_data)
        spectral_entropy_alpha = -np.sum(alpha_prob * np.log2(alpha_prob + 1e-12))  # Add a small value to avoid log(0)

        # Compute entropy for beta band
        beta_prob = psd_data[:,(freqs >= beta_band[0]) & (freqs <= beta_band[1])] / np.sum(psd_data)
        spectral_entropy_beta = -np.sum(beta_prob * np.log2(beta_prob + 1e-12))  # Add a small value to avoid log(0)

        
 
        # Append features for the current channel
        channel_features = [mean_power, variance_power, skewness_power, kurtosis_power,
                            max_power_freq, max_power, band_power_alpha, band_power_beta,
                            spectral_entropy_alpha, spectral_entropy_beta]
        
       
        features.append(channel_features)

# Convert features to numpy array
    
    features_psd_ms.append(features)
    
features_psd_ms = np.array(features_psd_ms)
# Out:
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:31: RuntimeWarning: invalid value encountered in true_divide
#   alpha_prob = psd_data[:,(freqs >= alpha_band[0]) & (freqs <= alpha_band[1])] / np.sum(psd_data)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:35: RuntimeWarning: invalid value encountered in true_divide
#   beta_prob = psd_data[:,(freqs >= beta_band[0]) & (freqs <= beta_band[1])] / np.sum(psd_data)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# ...
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# Effective window size : 0.110 (s)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:9: UserWarning: Zero value in spectrum for channel MEG2542+2543
#   psd_spectrum_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# Effective window size : 0.110 (s)
# (102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\1330227569.py:52: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   features_psd_ms = np.array(features_psd_ms)

# %%
features_psd_ms.shape
# Out:
# (1041, 102, 10)

# %%
# Exclude the 2nd and 3rd columns in the third dimension
new_features_psd_ms = np.delete(features_psd_ms, [2, 3], axis=2)

# %%
grand_average_healthy.times
# Out:
# array([0.   , 0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008,
#        0.009, 0.01 , 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017,
#        0.018, 0.019, 0.02 , 0.021, 0.022, 0.023, 0.024, 0.025, 0.026,
#        0.027, 0.028, 0.029, 0.03 , 0.031, 0.032, 0.033, 0.034, 0.035,
#        0.036, 0.037, 0.038, 0.039, 0.04 , 0.041, 0.042, 0.043, 0.044,
#        0.045, 0.046, 0.047, 0.048, 0.049, 0.05 , 0.051, 0.052, 0.053,
#        0.054, 0.055, 0.056, 0.057, 0.058, 0.059, 0.06 , 0.061, 0.062,
#        0.063, 0.064, 0.065, 0.066, 0.067, 0.068, 0.069, 0.07 , 0.071,
#        0.072, 0.073, 0.074, 0.075, 0.076, 0.077, 0.078, 0.079, 0.08 ,
#        0.081, 0.082, 0.083, 0.084, 0.085, 0.086, 0.087, 0.088, 0.089,
#        0.09 , 0.091, 0.092, 0.093, 0.094, 0.095, 0.096, 0.097, 0.098,
#        0.099, 0.1  , 0.101, 0.102, 0.103, 0.104, 0.105, 0.106, 0.107,
#        0.108, 0.109, 0.11 , 0.111, 0.112, 0.113, 0.114, 0.115, 0.116,
#        0.117, 0.118, 0.119, 0.12 , 0.121, 0.122, 0.123, 0.124, 0.125,
#        0.126, 0.127, 0.128, 0.129, 0.13 , 0.131, 0.132, 0.133, 0.134,
#        0.135, 0.136, 0.137, 0.138, 0.139, 0.14 , 0.141, 0.142, 0.143,
#        0.144, 0.145, 0.146, 0.147, 0.148, 0.149, 0.15 ])

# %%
import numpy as np

# Create an array from 0 to 10000 ms with a step of 1 ms
times = np.arange(0, 10000, 1) / 1000  # Divide by 1000 to convert ms to seconds

# %%
import numpy as np
import pandas as pd
    
# Import necessary libraries
from scipy.stats import skew, kurtosis
from scipy.signal import find_peaks
from numpy import diff

# Initialize an empty list to store subject data
subject_data_list = []

# Number of subjects
#num_subjects = 5
# Create an empty list to store evoked objects for each subject
evoked_list = []
features_erp_ms = []

# Size of each array
array_size = (102, 201)
num_trials=0
start=0
raw_list = []

# Replace this part with your actual data retrieval process in the nested loops
for subject, trials in enumerate(trial_counts_movie_state):
    print('subject idx is')
    print(subject)
    print("trials is")
    print(trials)
    name=matfiles_ms[subject]
    print(name)
    dat = mat73.loadmat(matfiles_ms[subject])
    data=dat['MEG']
    new=data['trial']
    data2=np.asarray(new)
    print(data2.shape) 
    
    
    trial_data=[]
    peak_amplitudes = []
    latencies = []
    auc_values = []
    slopes = []
    features_erp_1st_click_healthy=[]
    features=[]
    from scipy.integrate import simps
    

    # Initialize empty lists to store features
    peak_to_peak_amplitudes = []
    mean_absolute_amplitudes = []
    rms_amplitudes = []
    std_devs = []
    skewness_values = []
    kurtosis_values = []
    zero_crossing_rates = []
    aar_values=[]
    zork_values=[]

# Loop through subjects
    for trial in range(trials):
        data_trial=data2[trial,:102,:]
        print("shape of 1 trial data")
        print(data_trial.shape)
        features=[]

# Iterate through channels
        for ch_idx in range(len(info['ch_names'])):
            # Extract ERP data for the current channel
            channel_data = data_trial[ch_idx,:]
            print(channel_data.shape)


        # Compute peak amplitude and latency
            peak_amplitude = np.max(channel_data)
             # Compute peak-to-peak amplitude
            peak_to_peak_amplitude = np.max(channel_data) - np.min(channel_data)
            peak_to_peak_amplitudes.append(peak_to_peak_amplitude)
            # Compute mean absolute amplitude
            mean_absolute_amplitude = np.mean(np.abs(channel_data))
            mean_absolute_amplitudes.append(mean_absolute_amplitude)
                # Compute RMS amplitude
            rms_amplitude = np.sqrt(np.mean(channel_data**2))
            rms_amplitudes.append(rms_amplitude)

            # Compute standard deviation
            std_dev = np.std(channel_data)
            std_devs.append(std_dev)

            # Compute skewness
            skewness = skew(channel_data)
            skewness_values.append(skewness)

            # Compute kurtosis
            kurtosis_val = kurtosis(channel_data)
            kurtosis_values.append(kurtosis_val)

            # Compute zero crossing rate
            zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
            zero_crossing_rates.append(zero_crossings)

            latency = times[np.argmax(channel_data)]

        # Calculate area under the curve (AUC)
            auc_value = simps(channel_data, times)

        # Calculate slope (e.g., by fitting a linear regression model)
        # You can use numpy's polyfit function for this purpose
            slope_coefficients = np.polyfit(times, channel_data, 1)
            slope = slope_coefficients[0]


            zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
            zero_crossing_rates.append(zero_crossings)

            # Compute AAR
            aar = peak_to_peak_amplitude / mean_absolute_amplitude
            aar_values.append(aar)

            # Compute ZORK
            zork = zero_crossings / kurtosis_val
            zork_values.append(zork)

            peak_to_peak_amplitudes1=np.array(peak_to_peak_amplitudes)
            channel_features = [peak_amplitude,latency,auc_value,slope,
                                peak_to_peak_amplitude, 
                                     mean_absolute_amplitude, 
                                     rms_amplitude, 
                                     std_dev, 
                                     skewness, 
                                     kurtosis_val, 
                                     zero_crossings,aar,zork]

            features.append(channel_features)

        features_erp_ms.append(features)
    
features_erp_ms= np.array(features_erp_ms,dtype=object)
# Out:
# subject idx is
# 0
# trials is
# 52
# Combined_grad_AD001_MoviesWatching.mat
# (52, 204, 10000)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# ...
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# shape of 1 trial data
# (102, 10000)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)
# (10000,)

# %%
len(times)
# Out:
# 10000

# %%
features_erp_ms.shape
# Out:
# (1041, 102, 13)

# %%
sum(trial_counts_movie_state)
# Out:
# 1041

# %%
usable_features_psd_ms=new_features_psd_ms[:,:,4:8]
print(usable_features_psd_ms.shape)
# Out:
# (1041, 102, 4)

# %%
import numpy as np

reshaped_psd_ms = []
reshaped_erp_ms = []

# Start index for slicing
start_idx = 0

# Iterate over each subject and their respective trial count
for trials in trial_counts_movie_state:
    # Calculate the end index for slicing
    end_idx = start_idx + trials
    
    # Slice the data for the current subject
    subject_psd = usable_features_psd_ms[start_idx:end_idx, :, :]
    subject_erp = features_erp_ms[start_idx:end_idx, :, :]
    
    # Append the reshaped data to the list
    reshaped_psd_ms.append(subject_psd)
    reshaped_erp_ms.append(subject_erp)
    
    # Update the start index for the next iteration
    start_idx = end_idx

# Convert the lists to numpy arrays with the desired shape
reshaped_psd_ms = np.array(reshaped_psd_ms)  # Shape will be (21, trials_per_subject, 102, 4)
reshaped_erp_ms = np.array(reshaped_erp_ms)  # Shape will be (21, trials_per_subject, 102, 13)
# Out:
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\281010639.py:26: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   reshaped_psd_ms = np.array(reshaped_psd_ms)  # Shape will be (21, trials_per_subject, 102, 4)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_3976\281010639.py:27: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   reshaped_erp_ms = np.array(reshaped_erp_ms)  # Shape will be (21, trials_per_subject, 102, 13)

# %%
import numpy as np
from scipy.io import savemat

psd_file_path = 'D:/internship_ulster_university/features without grand averaging/ms_psd_without_grand_average.mat'
erp_file_path = 'D:/internship_ulster_university/features without grand averaging/ms_erp_without_grand_average.mat'

# Create a dictionary to hold the variables to be saved
psd_dict = {'reshaped_psd': reshaped_psd_ms}
erp_dict = {'reshaped_erp': reshaped_erp_ms}

# Save the reshaped arrays to .mat files
savemat(psd_file_path, psd_dict)
savemat(erp_file_path, erp_dict)

print(f"Files saved successfully to {psd_file_path} and {erp_file_path}")
# Out:
# Files saved successfully to D:/internship_ulster_university/features without grand averaging/ms_psd_without_grand_average.mat and D:/internship_ulster_university/features without grand averaging/ms_erp_without_grand_average.mat
