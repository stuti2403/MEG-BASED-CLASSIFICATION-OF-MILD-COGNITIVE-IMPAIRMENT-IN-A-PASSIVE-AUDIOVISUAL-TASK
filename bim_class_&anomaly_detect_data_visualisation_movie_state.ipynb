# %% [markdown]
# # initial ERP analysis
# (1st click and eyes closed data for healthy subjects, just for analyses purposes)
#
# for classification and anomaly detection, skip to section "feature extraction: healthy subjects resting state"

# %%
# %matplotlib inline
import numpy as np

from scipy.io import loadmat 
import mne, glob 
import pandas as pd
import mat73

# %%
# find the matfiles in the current directory 
matfiles = glob.glob('*.mat')

data = {}
matfiles
# Out:
# ['PreProcessed_AD001_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD002_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD003_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD004_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD006_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD008_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD010_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD011_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD012_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD013_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD014_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD015_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD016_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD017_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD018_Preprocessed_FirstClick.mat',
#  'PreProcessed_AD020_Preprocessed_FirstClick.mat']

# %%
data_for_chan=mat73.loadmat(matfiles[0])
data_chan = pd.DataFrame.from_dict(data_for_chan)
chan=data_chan.iloc[4,0]
result_array = np.array([item for sublist in chan for item in sublist], dtype=str)
result_array
channels=result_array[0:102]
print('channels are')
print(channels)
print(channels.dtype)
# Out:
# channels are
# ['MEG0112+0113' 'MEG0122+0123' 'MEG0132+0133' 'MEG0142+0143'
#  'MEG0212+0213' 'MEG0222+0223' 'MEG0232+0233' 'MEG0242+0243'
#  'MEG0312+0313' 'MEG0322+0323' 'MEG0332+0333' 'MEG0342+0343'
#  'MEG0412+0413' 'MEG0422+0423' 'MEG0432+0433' 'MEG0442+0443'
#  'MEG0512+0513' 'MEG0522+0523' 'MEG0532+0533' 'MEG0542+0543'
#  'MEG0612+0613' 'MEG0622+0623' 'MEG0632+0633' 'MEG0642+0643'
#  'MEG0712+0713' 'MEG0722+0723' 'MEG0732+0733' 'MEG0742+0743'
#  'MEG0812+0813' 'MEG0822+0823' 'MEG0912+0913' 'MEG0922+0923'
#  'MEG0932+0933' 'MEG0942+0943' 'MEG1012+1013' 'MEG1022+1023'
#  'MEG1032+1033' 'MEG1042+1043' 'MEG1112+1113' 'MEG1122+1123'
#  'MEG1132+1133' 'MEG1142+1143' 'MEG1212+1213' 'MEG1222+1223'
#  'MEG1232+1233' 'MEG1242+1243' 'MEG1312+1313' 'MEG1322+1323'
#  'MEG1332+1333' 'MEG1342+1343' 'MEG1412+1413' 'MEG1422+1423'
#  'MEG1432+1433' 'MEG1442+1443' 'MEG1512+1513' 'MEG1522+1523'
#  'MEG1532+1533' 'MEG1542+1543' 'MEG1612+1613' 'MEG1622+1623'
# ...

# %%
list_1 = channels.tolist()

# %%
location=data_chan.iloc[2,0]
pos=location['chanpos']
position=pos[0:102,:]

# %%
position
# Out:
# array([[-1.00075722e+01,  3.65128630e+00, -2.25105759e+00],
#        [-1.00621064e+01,  5.41282576e+00,  1.21426809e+00],
#        [-1.05140172e+01,  2.08403908e+00,  1.12193825e+00],
#        [-1.01240423e+01,  2.99298532e-01, -2.43275739e+00],
#        [-1.08367367e+01,  2.42531954e+00,  4.56424844e+00],
#        [-1.04351099e+01,  3.27754793e+00,  7.96055022e+00],
#        [-1.04496296e+01, -3.25349648e-01,  7.97673586e+00],
#        [-1.07277930e+01, -9.80692656e-01,  4.55195115e+00],
#        [-9.09741576e+00,  9.13935512e+00,  4.74954632e+00],
#        [-9.61617502e+00,  6.87580031e+00,  7.98214670e+00],
#        [-8.13470060e+00,  7.04733974e+00,  1.11388049e+01],
#        [-1.03150464e+01,  5.76595163e+00,  4.57486396e+00],
#        [-9.01232708e+00,  3.53965618e+00,  1.12300844e+01],
#        [-6.48532589e+00,  3.67729556e+00,  1.38783412e+01],
#        [-6.42388187e+00,  2.05244753e-01,  1.41232341e+01],
#        [-9.03684434e+00,  1.97289632e-02,  1.13746798e+01],
# ...

# %%
# #left side channels
# ch_aud_loc=[]
# for i in range(len(position)):
#      if list_1[i] == 'MEG0142+0143' or list_1[i] == 'MEG1512+1513'or list_1[i] == 'MEG1542+1543' or list_1[i] =='MEG1812+1813' or list_1[i] == 'MEG1622+1623' or list_1[i] == 'MEG1522+1523' or list_1[i] == 'MEG1612+1613'or list_1[i] == 'MEG1632+1633'or list_1[i] == 'MEG0232+0233'or list_1[i] == 'MEG0242+0243':
#         ch_aud_loc.append(i)
# ch_aud_loc

# %%
# #right side channels
# ch_aud_loc=[]
# for i in range(len(position)):
#     if list_1[i] == 'MEG2412+2413' or list_1[i] == 'MEG2222+2223'or list_1[i] == 'MEG2422+2423' or list_1[i] =='MEG2442+2443' or list_1[i] == 'MEG1432+1433' or list_1[i] == 'MEG2612+2613' or list_1[i] == 'MEG2622+2623'or list_1[i] == 'MEG2642+2643'or list_1[i] == 'MEG1332+1333'or list_1[i] == 'MEG1342+1343':
#         ch_aud_loc.append(i)
# ch_aud_loc

# %%
# #rleft and ight side channels
# ch_aud_loc=[]
# for i in range(len(position)):
#     if list_1[i] == 'MEG2412+2413' or list_1[i] == 'MEG2222+2223'or list_1[i] == 'MEG2422+2423' or list_1[i] =='MEG2442+2443' or list_1[i] == 'MEG1432+1433' or list_1[i] == 'MEG2612+2613' or list_1[i] == 'MEG2622+2623'or list_1[i] == 'MEG2642+2643'or list_1[i] == 'MEG1332+1333'or list_1[i] == 'MEG1342+1343' or list_1[i] == 'MEG0142+0143' or list_1[i] == 'MEG1512+1513'or list_1[i] == 'MEG1542+1543' or list_1[i] =='MEG1812+1813' or list_1[i] == 'MEG1622+1623' or list_1[i] == 'MEG1522+1523' or list_1[i] == 'MEG1612+1613'or list_1[i] == 'MEG1632+1633'or list_1[i] == 'MEG0232+0233'or list_1[i] == 'MEG0242+0243':
#         ch_aud_loc.append(i)
# ch_aud_loc

# %%
# len(ch_aud_loc)

# %%
# position2=position[ch_aud_loc]
# position2

# %%
num_trials=0
for subject in range(len(matfiles)):
    subject_data = []
    dat = mat73.loadmat(matfiles[subject])
    data = pd.DataFrame.from_dict(dat)
    new=data.iloc[7,0]
    print(len(new))
    num_trials+=len(new)
# Out:
# 31
# 61
# 21
# 32
# 35
# 28
# 35
# 28
# 44
# 40
# 34
# 26
# 26
# 26
# 33
# 25

# %%
num_trials
# Out:
# 525

# %%
import numpy as np

# Define the size of the empty array
array_size = (num_trials, 102, 151)

# Create an empty array of zeros with the specified size
empty_array = np.zeros(array_size)

# Display the shape of the empty array
print(empty_array.shape)
# Out:
# (525, 102, 151)

# %%
empty_array.shape
# Out:
# (525, 102, 151)

# %%
import numpy as np
import pandas as pd

# Initialize an empty list to store subject data
subject_data_list = []

# Number of subjects
#num_subjects = 5


# Size of each array
array_size = (102, 201)
num_trials=0
start=0

# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject in range(len(matfiles)):
    subject_data = []
    dat = mat73.loadmat(matfiles[subject])
    data = pd.DataFrame.from_dict(dat)
    new=data.iloc[7,0]
    
    num_trials+=len(new)

    print(start)
    end=num_trials
    print(end)
    for trial1 in range(0,len(new)):
        # Simulating data for demonstration purposes
        trial=new[trial1][0:102,200:351]
        subject_data.append(trial)
        sub_data=np.array(subject_data)
        print(sub_data.shape)
    
    empty_array[start:num_trials,:,:]=sub_data
    start=num_trials
    end=num_trials
    print(empty_array.shape)
# Out:
# 0
# 31
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# (27, 102, 151)
# (28, 102, 151)
# (29, 102, 151)
# (30, 102, 151)
# (31, 102, 151)
# (525, 102, 151)
# 31
# 92
# (1, 102, 151)
# (2, 102, 151)
# (3, 102, 151)
# (4, 102, 151)
# (5, 102, 151)
# (6, 102, 151)
# (7, 102, 151)
# (8, 102, 151)
# (9, 102, 151)
# (10, 102, 151)
# (11, 102, 151)
# (12, 102, 151)
# (13, 102, 151)
# (14, 102, 151)
# (15, 102, 151)
# (16, 102, 151)
# (17, 102, 151)
# (18, 102, 151)
# (19, 102, 151)
# (20, 102, 151)
# (21, 102, 151)
# (22, 102, 151)
# (23, 102, 151)
# (24, 102, 151)
# (25, 102, 151)
# (26, 102, 151)
# ...

# %%
aud_data=empty_array[:,:,:]
print(aud_data)
# Out:
# [[[2.52651669e-12 2.47600476e-12 2.39582113e-12 ... 4.87943089e-12
#    5.24331335e-12 5.53127524e-12]
#   [3.00274355e-12 3.06934650e-12 3.06917920e-12 ... 7.00144127e-12
#    7.21571077e-12 7.33876674e-12]
#   [4.60371772e-12 4.85297196e-12 5.14311980e-12 ... 5.15999249e-12
#    5.89760516e-12 6.59613941e-12]
#   ...
#   [2.51959351e-12 2.43530450e-12 2.28739941e-12 ... 2.10148503e-12
#    2.29641088e-12 2.42910050e-12]
#   [3.71650909e-13 7.57128257e-13 1.16042836e-12 ... 2.75861843e-12
#    2.94515765e-12 3.09937576e-12]
#   [3.23381437e-12 3.19679950e-12 3.10008145e-12 ... 1.51949197e-12
#    1.82265921e-12 2.09418933e-12]]
#
#  [[2.46599728e-12 2.40724851e-12 2.35484571e-12 ... 2.40537979e-12
#    2.82981085e-12 3.38114018e-12]
#   [4.26617941e-12 4.26770867e-12 4.28197451e-12 ... 2.95341723e-12
#    2.91405728e-12 2.90021981e-12]
#   [4.45670133e-12 4.78947119e-12 5.01931613e-12 ... 5.46739117e-13
#    3.82075581e-13 2.53107341e-13]
#   ...
# ...

# %%
# # Selecting rows based on indices
# aud_data = empty_array[:, ch_aud_loc, :]

# # Printing the dimensions of the final array
# print(aud_data.shape)

# %%
n_channels_aud = len(aud_data[1,:,1])
n_channels_aud
# Out:
# 102

# %%
# ch_aud=list_1
# print(len(ch_aud))

# %%
# #left side channels
#  #   tfa on selected auditory channels of the brain
# ch_aud=['MEG0142+0143', 'MEG1512+1513','MEG1542+1543','MEG1812+1813', 'MEG1622+1623' ,'MEG1522+1523','MEG1612+1613','MEG1632+1633','MEG0232+0233','MEG0242+0243']

# %%
# #right side channels
# #tfa on selected auditory channels of the brain
# ch_aud=['MEG2412+2413','MEG2222+2223','MEG2422+2423','MEG2442+2443','MEG1432+1433','MEG2612+2613','MEG2622+2623','MEG2642+2643','MEG1332+1333','MEG1342+1343']

# %%
# #right side channels
# #tfa on selected auditory channels of the brain
# ch_aud=['MEG2412+2413','MEG2222+2223','MEG2422+2423','MEG2442+2443','MEG1432+1433','MEG2612+2613','MEG2622+2623','MEG2642+2643','MEG1332+1333','MEG1342+1343','MEG0142+0143', 'MEG1512+1513','MEG1542+1543','MEG1812+1813', 'MEG1622+1623' ,'MEG1522+1523','MEG1612+1613','MEG1632+1633','MEG0232+0233','MEG0242+0243']

# %%
ch_aud=list_1

# %%
sfreq = 1000

# %%
#n_channels = len(trials_sub[1,:,1])

# Initialize an info structure
info = mne.create_info(
        ch_names = ch_aud,
        ch_types = ['grad']*n_channels_aud,
        sfreq    = sfreq 
        )

# %%
# for i in range(len(position2)):
#     info['chs'][i]['loc'][:3]=position2[i,:]

# %%
for i in range(len(position)):
    info['chs'][i]['loc'][:3]=position[i,:]

# %%
import numpy as np
import mne
import matplotlib
matplotlib.use('Qt5Agg')
# or 'Qt4Agg' depending on your system and Matplotlib version
import os
import matplotlib.pyplot as plt

directory='D:/internship_ulster_university/figures/erp_1st_click_healthy_all_channels/'



# Assume you have a list of trial counts for each subject
trial_counts = [31, 61, 21,32,35,28,35,28,44,40,34,26,26,26,33,25]
#trial_counts = [45,34,39,44,44]

# Create an empty list to store evoked objects for each subject
evoked_list = []

# Loop through subjects
for subject_idx, trials in enumerate(trial_counts):
    # Extract data for the current subject
    subject_data = aud_data[:trials, :, :]  # Adjusted time range
    print(subject_data.shape)
    
    # Compute the average across trials for the current subject
    average_data = np.mean(subject_data, axis=0)
    
    # Create Evoked object for the current subject with time information
    evoked = mne.EvokedArray(average_data, info)  # Adjusted time range
    evoked_list.append(evoked)

grand_average_healthy = mne.grand_average(evoked_list)

# Plot the grand average
fig=grand_average_healthy.plot()
# fig.axes[0].set_ylim(data_min, data_max)
# Set xlabel and ylabel
fig.axes[0].set_xlabel('Time (s)')
fig.axes[0].set_ylabel('Amplitude (pT)')

    
fig.suptitle(f'ERP - ALL Channels')

fig.show()
fig.patch.set_facecolor('white')
   
# Save the figure with the specified filename
filename = "all channels.png"
filepath = os.path.join(directory, filename)
fig.savefig(filepath)
plt.close(fig)  # Close the figure to release memory

ylim = fig.axes[0].get_ylim()

# Plot the ERP for each channel separately
for ch_idx in range(len(info['ch_names'])):
    fig=grand_average_healthy.plot(picks=ch_aud[ch_idx], show=False)
    
    
    # Set y-axis limits to match the first plot
    fig.axes[0].set_ylim(ylim)
    
    fig.axes[0].set_xlabel('Time (s)')
    fig.axes[0].set_ylabel('Amplitude (pT)')

    
        # Plot PSD for the current channel
    fig.suptitle(f'ERP - Channel {ch_aud[ch_idx]}')

    # Optional: Save the plot
    # fig.savefig(f'psd_channel_{ch_name}.png')

    # Show the plot
    fig.show()
    fig.patch.set_facecolor('white')
   
   # Save the figure with the specified filename
    filename = f"channel_{ch_aud[ch_idx]}.png"
    filepath = os.path.join(directory, filename)
    fig.savefig(filepath)
    plt.close(fig)  # Close the figure to release memory
# Out:
# (31, 102, 151)
# (61, 102, 151)
# (21, 102, 151)
# (32, 102, 151)
# (35, 102, 151)
# (28, 102, 151)
# (35, 102, 151)
# (28, 102, 151)
# (44, 102, 151)
# (40, 102, 151)
# (34, 102, 151)
# (26, 102, 151)
# (26, 102, 151)
# (26, 102, 151)
# (33, 102, 151)
# (25, 102, 151)
# Identifying common channels ...
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# ...

# %%
import os
import glob


# Construct the path to the target folder
folder_path2 = "D:\internship_ulster_university\preprocessed_filtered_eyes_closed_healthy"

# Move into the target folder
os.chdir(folder_path2)

# Select all files ending with ".mat"
mat_files_rs = glob.glob("*.mat")

# Print the list of selected files
print("Selected .mat files:")
for file in mat_files_rs:
    print(file)
# Out:
# Selected .mat files:
# PreProcessed_AD001_Preprocessed_EC.mat
# PreProcessed_AD002_Preprocessed_EC.mat
# PreProcessed_AD003_Preprocessed_EC.mat
# PreProcessed_AD004_Preprocessed_EC.mat
# PreProcessed_AD006_Preprocessed_EC.mat
# PreProcessed_AD008_Preprocessed_EC.mat
# PreProcessed_AD010_Preprocessed_EC.mat
# PreProcessed_AD011_Preprocessed_EC.mat
# PreProcessed_AD012_Preprocessed_EC.mat
# PreProcessed_AD013_Preprocessed_EC.mat
# PreProcessed_AD014_Preprocessed_EC.mat
# PreProcessed_AD015_Preprocessed_EC.mat
# PreProcessed_AD016_Preprocessed_EC.mat
# PreProcessed_AD017_Preprocessed_EC.mat
# PreProcessed_AD018_Preprocessed_EC.mat
# PreProcessed_AD020_Preprocessed_EC.mat

# %%
num_trials_rs_ec=0
for subject in range(len(mat_files_rs)):
    subject_data_rs_es = []
    dat_rs_ec = mat73.loadmat(mat_files_rs[subject])
    data_rs_ec = pd.DataFrame.from_dict(dat_rs_ec)
    new_rs_ec=data_rs_ec.iloc[6,0]
    print(len(new_rs_ec))
    num_trials_rs_ec+=len(new_rs_ec)
# Out:
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16

# %%
import numpy as np

# Define the size of the empty array
array_size_rs_ec = (num_trials_rs_ec, 102, 9901)

# Create an empty array of zeros with the specified size
empty_array_rs_ec = np.zeros(array_size_rs_ec)

# Display the shape of the empty array
print(empty_array_rs_ec.shape)
# Out:
# (256, 102, 9901)

# %%
# Number of subjects
num_subjects = 5
trial_counts=[]

# Size of each array
array_size = (102, 401)
num_trials=0
start=0
num_actual_trials=0

# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject in range(len(mat_files_rs)):
    
    dat = mat73.loadmat(mat_files_rs[subject])
    data = pd.DataFrame.from_dict(dat)
    new=data.iloc[6,0]
    
    num_trials+=len(new)

    print(start)
    end=num_trials-num_actual_trials
    print(end)
    trial_counts.append(num_actual_trials)
  
    subject_data = []
    for trial1 in range(0,len(new)):
        # Simulating data for demonstration purposes
        trial=new[trial1][0:102,:9901]
        
        num_actual_trials=num_actual_trials+1
        print("nu actual")
        print(num_actual_trials)
        subject_data.append(trial)
        #print(subject_data)
        sub_data=np.array(subject_data)
        print(sub_data.shape)
    
    empty_array_rs_ec[start:num_actual_trials,:,:]=sub_data
    start=num_actual_trials
    end=num_actual_trials
    print(empty_array_rs_ec.shape)
# Out:
# 0
# 16
# nu actual
# 1
# (1, 102, 9901)
# nu actual
# 2
# (2, 102, 9901)
# nu actual
# 3
# (3, 102, 9901)
# nu actual
# 4
# (4, 102, 9901)
# nu actual
# 5
# (5, 102, 9901)
# nu actual
# 6
# (6, 102, 9901)
# nu actual
# 7
# (7, 102, 9901)
# nu actual
# 8
# (8, 102, 9901)
# nu actual
# 9
# (9, 102, 9901)
# nu actual
# 10
# (10, 102, 9901)
# nu actual
# 11
# (11, 102, 9901)
# nu actual
# 12
# (12, 102, 9901)
# nu actual
# 13
# (13, 102, 9901)
# nu actual
# 14
# (14, 102, 9901)
# nu actual
# 15
# (15, 102, 9901)
# nu actual
# 16
# (16, 102, 9901)
# (256, 102, 9901)
# 16
# 16
# nu actual
# 17
# (1, 102, 9901)
# nu actual
# 18
# (2, 102, 9901)
# nu actual
# 19
# (3, 102, 9901)
# nu actual
# 20
# (4, 102, 9901)
# nu actual
# 21
# (5, 102, 9901)
# nu actual
# 22
# (6, 102, 9901)
# nu actual
# 23
# (7, 102, 9901)
# nu actual
# 24
# (8, 102, 9901)
# nu actual
# 25
# (9, 102, 9901)
# nu actual
# 26
# (10, 102, 9901)
# nu actual
# 27
# (11, 102, 9901)
# nu actual
# 28
# (12, 102, 9901)
# ...

# %%
# # Selecting rows based on indices
# aud_data_rsec = empty_array_rs_ec[:, ch_aud_loc, :]

# # Printing the dimensions of the final array
# print(aud_data_rsec.shape)

# %%
aud_data_rsec = empty_array_rs_ec[:,:,:]
print(aud_data_rsec.shape)
# Out:
# (256, 102, 9901)

# %%
tr_counts=[16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16]
#tr_counts=[16,16,16,16]
tr_counts
# Out:
# [16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16]

# %%
import numpy as np
import mne
import matplotlib
matplotlib.use('Qt5Agg')  # or 'Qt4Agg' depending on your system and Matplotlib version

directory='D:/internship_ulster_university/figures/erp_resting_state_eyes_closed_healthy_all_channels/'



# Create an empty list to store evoked objects for each subject
evoked_list_rs_ec = []

# Loop through subjects
for subject_idx, trials in enumerate(tr_counts):
    # Extract data for the current subject
    subject_data_rsec= aud_data_rsec[:trials, :, :]
    
    # Compute the average across trials for the current subject
    average_data_rsec = np.mean(subject_data_rsec, axis=0)
    
    
    # Create Evoked object for the current subject
    evoked_rsec = mne.EvokedArray(average_data_rsec, info)
    
    # Append the Evoked object to the list
    evoked_list_rs_ec.append(evoked_rsec)

# Compute the grand average across subjects
grand_average_rsec_healthy = mne.grand_average(evoked_list_rs_ec)


# Plot the grand average
fig=grand_average_rsec_healthy.plot()


fig.axes[0].set_xlabel('Time (s)')
fig.axes[0].set_ylabel('Amplitude (pT)')

 
fig.suptitle(f'ERP - ALL Channels')

fig.show()
fig.patch.set_facecolor('white')
   
# Save the figure with the specified filename
filename = "all channels resting state eyes closed.png"
filepath = os.path.join(directory, filename)
fig.savefig(filepath)
plt.close(fig)  # Close the figure to release memory

ylim = fig.axes[0].get_ylim()

# Plot the ERP for each channel separately
for ch_idx in range(len(info['ch_names'])):
    fig=grand_average_rsec_healthy.plot(picks=ch_aud[ch_idx], show=False)
    
    
    fig.axes[0].set_ylim(ylim)
    fig.axes[0].set_xlabel('Time (s)')
    fig.axes[0].set_ylabel('Amplitude (pT)')

        # Plot PSD for the current channel
    fig.suptitle(f'ERP - Channel {ch_aud[ch_idx]}')

    # Optional: Save the plot
    # fig.savefig(f'psd_channel_{ch_name}.png')

    # Show the plot
    fig.show()
    fig.patch.set_facecolor('white')
   
   # Save the figure with the specified filename
    filename = f"channel_{ch_aud[ch_idx]}.png"
    filepath = os.path.join(directory, filename)
    fig.savefig(filepath)
    plt.close(fig)  # Close the figure to release memory
# Out:
# Identifying common channels ...
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# Need more than one channel to make topography for grad. Disabling interactivity.
# ...

# %% [markdown]
# # feature extraction: healthy subjects resting state eyes closed

# %%
import os
import glob


# Construct the path to the target folder
folder_path = "D:\internship_ulster_university\preprocessed_filtered_healthy_rsec"

# Move into the target folder
os.chdir(folder_path)

# Select all files ending with ".mat"
matfiles_healthy_rs = glob.glob("*.mat")

# Print the list of selected files
print("Selected .mat files:")
for file in matfiles_healthy_rs:
    print(file)
# Out:
# Selected .mat files:
# PreProcessed_AD001_Preprocessed_EC.mat
# PreProcessed_AD002_Preprocessed_EC.mat
# PreProcessed_AD003_Preprocessed_EC.mat
# PreProcessed_AD004_Preprocessed_EC.mat
# PreProcessed_AD006_Preprocessed_EC.mat
# PreProcessed_AD008_Preprocessed_EC.mat
# PreProcessed_AD010_Preprocessed_EC.mat
# PreProcessed_AD011_Preprocessed_EC.mat
# PreProcessed_AD012_Preprocessed_EC.mat
# PreProcessed_AD013_Preprocessed_EC.mat
# PreProcessed_AD014_Preprocessed_EC.mat
# PreProcessed_AD015_Preprocessed_EC.mat
# PreProcessed_AD016_Preprocessed_EC.mat
# PreProcessed_AD017_Preprocessed_EC.mat
# PreProcessed_AD018_Preprocessed_EC.mat
# PreProcessed_AD020_Preprocessed_EC.mat

# %%
num_trials=0
trial_counts_healthy_rs=[]
for subject in range(len(matfiles_healthy_rs)):
    subject_data = []
    name=matfiles_healthy_rs[subject]
    print(name)
    dat = mat73.loadmat(matfiles_healthy_rs[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
#     print(new)
    trial_counts_healthy_rs.append(len(new))
    print(len(new))
    num_trials+=len(new)
# Out:
# PreProcessed_AD001_Preprocessed_EC.mat
# 16
# PreProcessed_AD002_Preprocessed_EC.mat
# 16
# PreProcessed_AD003_Preprocessed_EC.mat
# 16
# PreProcessed_AD004_Preprocessed_EC.mat
# 16
# PreProcessed_AD006_Preprocessed_EC.mat
# 16
# PreProcessed_AD008_Preprocessed_EC.mat
# 16
# PreProcessed_AD010_Preprocessed_EC.mat
# 16
# PreProcessed_AD011_Preprocessed_EC.mat
# 16
# PreProcessed_AD012_Preprocessed_EC.mat
# 16
# PreProcessed_AD013_Preprocessed_EC.mat
# 16
# PreProcessed_AD014_Preprocessed_EC.mat
# 16
# PreProcessed_AD015_Preprocessed_EC.mat
# 16
# PreProcessed_AD016_Preprocessed_EC.mat
# 16
# PreProcessed_AD017_Preprocessed_EC.mat
# 16
# PreProcessed_AD018_Preprocessed_EC.mat
# 16
# PreProcessed_AD020_Preprocessed_EC.mat
# 16

# %%
print(trial_counts_healthy_rs)
# Out:
# [16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16]

# %%
import numpy as np
import pandas as pd

# Initialize an empty list to store subject data
subject_data_list = []

# Number of subjects
#num_subjects = 5


# Size of each array
array_size = (102, 201)
num_trials=0
start=0
raw_list_mean_healthy_rs = []
# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject, trials in enumerate(trial_counts_healthy_rs):
    subject_data = []
    print('subject idx is')
    print(subject)
    
    name=matfiles_healthy_rs[subject]
    print(name)
    dat = mat73.loadmat(matfiles_healthy_rs[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
    
    num_trials+=len(new)

    print(start)
    end=num_trials
    print(end)
    trial_data=[]
    

    for trial in range(trials):
        #print(new[0].shape[1])
        if new[0].shape[1] == 10001:
            #trial_data.append(new[trial][ch_aud_loc,:9901])
            trial_data.append(new[trial][:102,:9901])
            times = grand_average_rsec_healthy.times
            
        else:
            #trial_data.append(new[trial][ch_aud_loc,200:351])
            trial_data.append(new[trial][:102,200:351])
            times = grand_average_healthy.times
            
    # Compute the average across trials for the current subject
    average_data_healthy = np.mean(trial_data, axis=0)
    print(average_data_healthy.shape)
   # Create RawArray object for the current trial
    raw = mne.io.RawArray(average_data_healthy, info)

    # Append the Raw object to the list
    raw_list_mean_healthy_rs.append(raw)
    print(len(raw_list_mean_healthy_rs))
# #Concatenate Raw objects if needed
# raw_combined_mean_healthy_rs = mne.concatenate_raws(raw_list_mean_healthy_rs)

# print(len(raw_combined_mean_healthy_rs))
# Out:
# subject idx is
# 0
# PreProcessed_AD001_Preprocessed_EC.mat
# 0
# 16
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 1
# subject idx is
# 1
# PreProcessed_AD002_Preprocessed_EC.mat
# 0
# 32
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 2
# subject idx is
# 2
# PreProcessed_AD003_Preprocessed_EC.mat
# 0
# 48
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 3
# subject idx is
# 3
# PreProcessed_AD004_Preprocessed_EC.mat
# 0
# 64
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 4
# subject idx is
# 4
# PreProcessed_AD006_Preprocessed_EC.mat
# 0
# 80
# (102, 9901)
# ...

# %%
raw_list_mean_healthy_rs
# Out:
# [<RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>]

# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import kurtosis

# Define frequency bands
alpha_band = (8, 13)  # Alpha band frequencies
beta_band = (13, 30)  # Beta band frequencies

features_psd_healthy_rs = []
for raw in raw_list_mean_healthy_rs:
    # Compute PSD
    psd_spectrum_healthy = raw.compute_psd(method='multitaper', fmin=0, fmax=40, tmin=None, tmax=None)
    print(psd_spectrum_healthy.shape)
    
    
    features=[]
    for idx, ch_name in enumerate(ch_aud):
        psd_data = psd_spectrum_healthy[idx]  # PSD data for the current channel

    # Statistical Features
        mean_power = np.mean(psd_data)
        variance_power = np.var(psd_data)
    
        skewness_power = stats.skew(psd_data)
        kurtosis_power = stats.kurtosis(psd_data)
        print('mean_power')
        print(mean_power)
        print('v_power')
        print(variance_power)
        print('s_power')
        print(skewness_power)

    # Frequency-Domain Features
        freqs = psd_spectrum_healthy.freqs  # Frequency values
        max_power_freq = freqs[np.argmax(psd_data)]
        max_power = np.max(psd_data)
        band_power_alpha = np.sum(psd_data[:,(freqs >= 8) & (freqs <= 13)])  # Alpha band
        band_power_beta = np.sum(psd_data[:,(freqs >= 13) & (freqs <= 30)])  # Beta band
        
        
        
        
            # Compute entropy for alpha band
        alpha_prob = psd_data[:,(freqs >= alpha_band[0]) & (freqs <= alpha_band[1])] / np.sum(psd_data)
        spectral_entropy_alpha = -np.sum(alpha_prob * np.log2(alpha_prob + 1e-12))  # Add a small value to avoid log(0)

        # Compute entropy for beta band
        beta_prob = psd_data[:,(freqs >= beta_band[0]) & (freqs <= beta_band[1])] / np.sum(psd_data)
        spectral_entropy_beta = -np.sum(beta_prob * np.log2(beta_prob + 1e-12))  # Add a small value to avoid log(0)

        # Append features for the current channel
        channel_features = [mean_power, variance_power, skewness_power, kurtosis_power,
                            max_power_freq, max_power, band_power_alpha, band_power_beta,
                            spectral_entropy_alpha, spectral_entropy_beta]
        
        features.append(channel_features)

# Convert features to numpy array
    
    features_psd_healthy_rs.append(features)
    
features_psd_healthy_rs = np.array(features_psd_healthy_rs)

# %%
print(len(features_psd_healthy_rs))
# Out:
# 16

# %%
features_psd_healthy_rs[:,:,2]
# Out:
# array([[array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
# ...

# %%
# Exclude the 2nd and 3rd columns in the third dimension
new_features_psd_healthy_rs = np.delete(features_psd_healthy_rs, [2, 3], axis=2)

# %%
new_features_psd_healthy_rs.shape
# Out:
# (16, 102, 8)

# %%
import numpy as np
import pandas as pd
    
# Import necessary libraries
from scipy.stats import skew, kurtosis
from scipy.signal import find_peaks
from numpy import diff

# Initialize an empty list to store subject data
subject_data_list = []

# Number of subjects
#num_subjects = 5
# Create an empty list to store evoked objects for each subject
evoked_list = []
features_erp_healthy_rs = []

# Size of each array
array_size = (102, 201)
num_trials=0
start=0
raw_list = []
# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject, trials in enumerate(trial_counts_healthy_rs):
    subject_data = []
    print('subject idx is')
    print(subject)
    
    name=matfiles_healthy_rs[subject]
    print(name)
    dat = mat73.loadmat(matfiles_healthy_rs[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        print('in if')
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
    
    num_trials+=len(new)

    print(start)
    end=num_trials
    print(end) 
    print(new[0].shape)
    trial_data=[]
# Loop through subjects
    for trial in range(trials):
        #print(new[0].shape[1])
        if new[0].shape[1] == 10001:
            #trial_data.append(new[trial][ch_aud_loc,:9901])
            trial_data.append(new[trial][:102,:9901])
            times = grand_average_rsec_healthy.times
            
        else:
            #trial_data.append(new[trial][ch_aud_loc,200:351])
            trial_data.append(new[trial][:102,200:351])
            times = grand_average_healthy.times
            
    # Compute the average across trials for the current subject
    average_data_healthy = np.mean(trial_data, axis=0)
    print(average_data_healthy.shape)
    
# Create empty lists to store features
    peak_amplitudes = []
    latencies = []
    auc_values = []
    slopes = []
    features_erp_1st_click_healthy=[]
    features=[]
    from scipy.integrate import simps
    

    # Initialize empty lists to store features
    peak_to_peak_amplitudes = []
    mean_absolute_amplitudes = []
    rms_amplitudes = []
    std_devs = []
    skewness_values = []
    kurtosis_values = []
    zero_crossing_rates = []
    aar_values=[]
    zork_values=[]


# Iterate through channels
    for ch_idx in range(len(info['ch_names'])):
        # Extract ERP data for the current channel
        channel_data = average_data_healthy[ch_idx,:]
        
    
    # Compute peak amplitude and latency
        peak_amplitude = np.max(channel_data)
         # Compute peak-to-peak amplitude
        peak_to_peak_amplitude = np.max(channel_data) - np.min(channel_data)
        print('ptp amp for ch')
        print(ch_idx)
        print(peak_to_peak_amplitude)
        peak_to_peak_amplitudes.append(peak_to_peak_amplitude)
        # Compute mean absolute amplitude
        mean_absolute_amplitude = np.mean(np.abs(channel_data))
        print('ma amp for ch')
        print(ch_idx)
        print(mean_absolute_amplitude)
        mean_absolute_amplitudes.append(mean_absolute_amplitude)
            # Compute RMS amplitude
        rms_amplitude = np.sqrt(np.mean(channel_data**2))
        print('rms amp for ch')
        print(ch_idx)
        print(rms_amplitude)
        rms_amplitudes.append(rms_amplitude)

        # Compute standard deviation
        std_dev = np.std(channel_data)
        print('std for ch')
        print(ch_idx)
        print(std_dev)
        std_devs.append(std_dev)

        # Compute skewness
        skewness = skew(channel_data)
        print('s for ch')
        print(ch_idx)
        print(skewness)
        skewness_values.append(skewness)

        # Compute kurtosis
        kurtosis_val = kurtosis(channel_data)
        print('k for ch')
        print(ch_idx)
        print(kurtosis_val)
        kurtosis_values.append(kurtosis_val)

        # Compute zero crossing rate
        zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
        print('zc for ch')
        print(ch_idx)
        print(zero_crossings)
        zero_crossing_rates.append(zero_crossings)
        

        latency = times[np.argmax(channel_data)]
        print('l for ch')
        print(ch_idx)
        print(latency)
    
    # Calculate area under the curve (AUC)
        auc_value = simps(channel_data, times)
    
    # Calculate slope (e.g., by fitting a linear regression model)
    # You can use numpy's polyfit function for this purpose
        slope_coefficients = np.polyfit(times, channel_data, 1)
        slope = slope_coefficients[0]
        
        
        zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
        zero_crossing_rates.append(zero_crossings)

        # Compute AAR
        aar = peak_to_peak_amplitude / mean_absolute_amplitude
        aar_values.append(aar)

        # Compute ZORK
        zork = zero_crossings / kurtosis_val
        zork_values.append(zork)

        
        channel_features = [peak_amplitude,latency,auc_value,slope,
                            peak_to_peak_amplitude, 
                                 mean_absolute_amplitude, 
                                 rms_amplitude, 
                                 std_dev, 
                                 skewness, 
                                 kurtosis_val, 
                                 zero_crossings,aar,zork]
        features.append(channel_features)

# Convert features to numpy array

    
    features_erp_healthy_rs.append(features)
    
features_erp_healthy_rs = np.array(features_erp_healthy_rs,dtype=object)

# %%
print(features_erp_healthy_rs.shape)
# Out:
# (16, 102, 13)

# %%
# import numpy as np


# # Iterate over each element of the feature array
# nan_found = False
# for i in range(features_erp_healthy_rs.shape[0]):
#     for j in range(features_erp_healthy_rs.shape[1]):
#         for k in range(features_erp_healthy_rs.shape[2]):
#             # Check if the current element is NaN
#             print(features_erp_healthy_rs[i, j, k])

# %% [markdown]
# # feature extraction: MCI subjects resting state

# %%
import os
import glob


# Construct the path to the target folder
folder_path = "D:\internship_ulster_university\preprocessed_filtered_mci_rsec"

# Move into the target folder
os.chdir(folder_path)

# Select all files ending with ".mat"
matfiles_mci_rs = glob.glob("*.mat")

# Print the list of selected files
print("Selected .mat files:")
for file in matfiles_mci_rs:
    print(file)
# Out:
# Selected .mat files:
# PreProcessed_AD026_Preprocessed_EC.mat
# PreProcessed_AD027_Preprocessed_EC.mat
# PreProcessed_AD028_Preprocessed_EC.mat
# PreProcessed_AD030_Preprocessed_EC.mat

# %%
num_trials=0
trial_counts_mci_rs=[]
for subject in range(len(matfiles_mci_rs)):
    subject_data = []
    name=matfiles_mci_rs[subject]
    print(name)
    dat = mat73.loadmat(matfiles_mci_rs[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
#     print(new)
    trial_counts_mci_rs.append(len(new))
    print(len(new))
    num_trials+=len(new)
# Out:
# PreProcessed_AD026_Preprocessed_EC.mat
# 16
# PreProcessed_AD027_Preprocessed_EC.mat
# 16
# PreProcessed_AD028_Preprocessed_EC.mat
# 16
# PreProcessed_AD030_Preprocessed_EC.mat
# 16

# %%
trial_counts_mci_rs
# Out:
# [16, 16, 16, 16]

# %%
import numpy as np
import pandas as pd

# Initialize an empty list to store subject data
subject_data_list = []

# Number of subjects
#num_subjects = 5


# Size of each array
array_size = (102, 201)
num_trials=0
start=0
raw_list_mean_mci_rs = []
# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject, trials in enumerate(trial_counts_mci_rs):
    subject_data = []
    print('subject idx is')
    print(subject)
    
    name=matfiles_mci_rs[subject]
    print(name)
    dat = mat73.loadmat(matfiles_mci_rs[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]
    
    num_trials+=len(new)

    print(start)
    end=num_trials
    print(end)
    trial_data=[]
    

    for trial in range(trials):
        #print(new[0].shape[1])
        if new[0].shape[1] == 10001:
            #trial_data.append(new[trial][ch_aud_loc,:9901])
            trial_data.append(new[trial][:102,:9901])
            times = grand_average_rsec_healthy.times
            
        else:
            #trial_data.append(new[trial][ch_aud_loc,200:351])
            trial_data.append(new[trial][:102,200:351])
            times = grand_average_healthy.times
            
    # Compute the average across trials for the current subject
    average_data_healthy = np.mean(trial_data, axis=0)
    print(average_data_healthy.shape)
   # Create RawArray object for the current trial
    raw = mne.io.RawArray(average_data_healthy, info)

    # Append the Raw object to the list
    raw_list_mean_mci_rs.append(raw)
    print(len(raw_list_mean_mci_rs))
# #Concatenate Raw objects if needed
# raw_combined_mean_mci_rs = mne.concatenate_raws(raw_list_mean_mci_rs)

# print(len(raw_combined_mean_mci_rs))
# Out:
# subject idx is
# 0
# PreProcessed_AD026_Preprocessed_EC.mat
# 0
# 16
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 1
# subject idx is
# 1
# PreProcessed_AD027_Preprocessed_EC.mat
# 0
# 32
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 2
# subject idx is
# 2
# PreProcessed_AD028_Preprocessed_EC.mat
# 0
# 48
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 3
# subject idx is
# 3
# PreProcessed_AD030_Preprocessed_EC.mat
# 0
# 64
# (102, 9901)
# Creating RawArray with float64 data, n_channels=102, n_times=9901
#     Range : 0 ... 9900 =      0.000 ...     9.900 secs
# Ready.
# 4

# %%
raw_list_mean_mci_rs
# Out:
# [<RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>,
#  <RawArray | 102 x 9901 (9.9 s), ~7.8 MB, data loaded>]

# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import kurtosis

features_psd_mci_rs = []
for raw in raw_list_mean_mci_rs:
    # Compute PSD
    psd_spectrum_healthy = raw.compute_psd(method='multitaper', fmin=0, fmax=40, tmin=None, tmax=None)
    print(psd_spectrum_healthy.shape)
    
    
    features=[]
    for idx, ch_name in enumerate(ch_aud):
        psd_data = psd_spectrum_healthy[idx]  # PSD data for the current channel
        mean_power = np.mean(psd_data)
        variance_power = np.var(psd_data)
        skewness_power = stats.skew(psd_data)
        kurtosis_power = stats.kurtosis(psd_data)
        freqs = psd_spectrum_healthy.freqs  # Frequency values
        max_power_freq = freqs[np.argmax(psd_data)]
        max_power = np.max(psd_data)
        band_power_alpha = np.sum(psd_data[:,(freqs >= 8) & (freqs <= 13)])  # Alpha band
        band_power_beta = np.sum(psd_data[:,(freqs >= 13) & (freqs <= 30)])  # Beta band
        alpha_prob = psd_data[:,(freqs >= alpha_band[0]) & (freqs <= alpha_band[1])] / np.sum(psd_data)
        spectral_entropy_alpha = -np.sum(alpha_prob * np.log2(alpha_prob + 1e-12))  # Add a small value to avoid log(0)
        beta_prob = psd_data[:,(freqs >= beta_band[0]) & (freqs <= beta_band[1])] / np.sum(psd_data)
        spectral_entropy_beta = -np.sum(beta_prob * np.log2(beta_prob + 1e-12))  # Add a small value to avoid log(0)

        # Append features for the current channel
        channel_features = [mean_power, variance_power, skewness_power, kurtosis_power,
                            max_power_freq, max_power, band_power_alpha, band_power_beta,
                            spectral_entropy_alpha, spectral_entropy_beta]
        features.append(channel_features)

# Convert features to numpy array
    
    features_psd_mci_rs.append(features)
    
features_psd_mci_rs = np.array(features_psd_mci_rs)
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# (102, 397)
#     Using multitaper spectrum estimation with 7 DPSS windows
# (102, 397)
#     Using multitaper spectrum estimation with 7 DPSS windows
# (102, 397)
#     Using multitaper spectrum estimation with 7 DPSS windows
# (102, 397)
# C:\Users\stuti\AppData\Local\Temp\ipykernel_10716\4012177503.py:39: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   features_psd_mci_rs = np.array(features_psd_mci_rs)

# %%
features_psd_mci_rs.shape
# Out:
# (4, 102, 10)

# %%
features_psd_mci_rs[:,:,3]
# Out:
# array([[array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#                nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
# ...

# %%
# Exclude the 2nd and 3rd columns in the third dimension
new_features_psd_mci_rs = np.delete(features_psd_mci_rs, [2, 3], axis=2)

# %%
new_features_psd_mci_rs[:,:,4]
# Out:
# array([[4.192213723750181e-21, 4.907935493472457e-21,
#         4.171278242473252e-21, 9.796564480527497e-21,
#         4.2968916536254945e-21, 1.9462405303917737e-21,
#         2.0188092376732075e-21, 3.0801808018866998e-21,
#         2.166654103607047e-21, 1.2250747881361977e-21,
#         8.379323460275958e-22, 4.113934101214605e-21,
#         9.603566690518625e-22, 6.173144223135908e-22,
#         6.049157281004319e-22, 9.295232259740642e-22,
#         1.0941031849487558e-21, 8.4395363616426975e-22,
#         6.692066374377538e-22, 7.544857762933785e-22,
#         5.81036261294231e-22, 5.015086811351192e-22,
#         3.9525129503632176e-22, 5.39190265324032e-22,
#         4.3749056452862585e-22, 4.0979793303120896e-22,
#         3.638130310694175e-22, 3.3535982821836765e-22,
#         7.399715424556451e-22, 6.016556580679276e-22,
#         7.980513223840324e-22, 9.67886861878865e-22,
#         5.484502962088025e-22, 4.901172526462901e-22,
# ...

# %%
new_features_psd_mci_rs.shape
# Out:
# (4, 102, 8)

# %%
import numpy as np
import pandas as pd
    
# Import necessary libraries
from scipy.stats import skew, kurtosis
from scipy.signal import find_peaks
from numpy import diff

# Initialize an empty list to store subject data
subject_data_list = []

# Number of subjects
#num_subjects = 5
# Create an empty list to store evoked objects for each subject
evoked_list = []
features_erp_mci_rs = []

# Size of each array
array_size = (102, 201)
num_trials=0
start=0
raw_list = []
# Simulating data for demonstration purposes
# Replace this part with your actual data retrieval process in the nested loops
for subject, trials in enumerate(trial_counts_mci_rs):
    subject_data = []
    print('subject idx is')
    print(subject) 
    name=matfiles_mci_rs[subject]
    print(name)
    dat = mat73.loadmat(matfiles_mci_rs[subject])
    data = pd.DataFrame.from_dict(dat)
    if name.endswith('EC.mat') == True or name.endswith('EO.mat')==True:
        print('in if')
        new=data.iloc[6,0]
    else:
        new=data.iloc[7,0]   
    num_trials+=len(new)
    print(start)
    end=num_trials
    print(end) 
    print(new[0].shape)
    trial_data=[]
# Loop through subjects
    for trial in range(trials):
        #print(new[0].shape[1])
        if new[0].shape[1] == 10001:
            #trial_data.append(new[trial][ch_aud_loc,:9901])
            trial_data.append(new[trial][:102,:9901])
            times = grand_average_rsec_healthy.times
            
        else:
            #trial_data.append(new[trial][ch_aud_loc,200:351])
            trial_data.append(new[trial][:102,200:351])
            times = grand_average_healthy.times
            
    # Compute the average across trials for the current subject
    average_data_healthy = np.mean(trial_data, axis=0)
    print(average_data_healthy.shape)
    
# Create empty lists to store features
    peak_amplitudes = []
    latencies = []
    auc_values = []
    slopes = []
    features_erp_1st_click_healthy=[]
    features=[]
    from scipy.integrate import simps
    

    # Initialize empty lists to store features
    peak_to_peak_amplitudes = []
    mean_absolute_amplitudes = []
    rms_amplitudes = []
    std_devs = []
    skewness_values = []
    kurtosis_values = []
    zero_crossing_rates = []
    aar_values=[]
    zork_values=[]


# Iterate through channels
    for ch_idx in range(len(info['ch_names'])):
        # Extract ERP data for the current channel
        channel_data = average_data_healthy[ch_idx,:]
        
    
    # Compute peak amplitude and latency
        peak_amplitude = np.max(channel_data)
         # Compute peak-to-peak amplitude
        peak_to_peak_amplitude = np.max(channel_data) - np.min(channel_data)
        peak_to_peak_amplitudes.append(peak_to_peak_amplitude)
        # Compute mean absolute amplitude
        mean_absolute_amplitude = np.mean(np.abs(channel_data))
        mean_absolute_amplitudes.append(mean_absolute_amplitude)
            # Compute RMS amplitude
        rms_amplitude = np.sqrt(np.mean(channel_data**2))
        rms_amplitudes.append(rms_amplitude)

        # Compute standard deviation
        std_dev = np.std(channel_data)
        std_devs.append(std_dev)

        # Compute skewness
        skewness = skew(channel_data)
        skewness_values.append(skewness)

        # Compute kurtosis
        kurtosis_val = kurtosis(channel_data)
        kurtosis_values.append(kurtosis_val)

        # Compute zero crossing rate
        zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
        zero_crossing_rates.append(zero_crossings)

        latency = times[np.argmax(channel_data)]
    
    # Calculate area under the curve (AUC)
        auc_value = simps(channel_data, times)
    
    # Calculate slope (e.g., by fitting a linear regression model)
    # You can use numpy's polyfit function for this purpose
        slope_coefficients = np.polyfit(times, channel_data, 1)
        slope = slope_coefficients[0]
        
        
        zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
        zero_crossing_rates.append(zero_crossings)

        # Compute AAR
        aar = peak_to_peak_amplitude / mean_absolute_amplitude
        aar_values.append(aar)

        # Compute ZORK
        zork = zero_crossings / kurtosis_val
        zork_values.append(zork)
        channel_features = [peak_amplitude,latency,auc_value,slope,
                            peak_to_peak_amplitude, 
                                 mean_absolute_amplitude, 
                                 rms_amplitude, 
                                 std_dev, 
                                 skewness, 
                                 kurtosis_val, 
                                 zero_crossings,aar,zork]

        features.append(channel_features)

# Convert features to numpy array

    
    features_erp_mci_rs.append(features)
    
features_erp_mci_rs = np.array(features_erp_mci_rs,dtype=object)
# Out:
# subject idx is
# 0
# PreProcessed_AD026_Preprocessed_EC.mat
# in if
# 0
# 16
# (204, 10001)
# (102, 9901)
# subject idx is
# 1
# PreProcessed_AD027_Preprocessed_EC.mat
# in if
# 0
# 32
# (204, 10001)
# (102, 9901)
# subject idx is
# 2
# PreProcessed_AD028_Preprocessed_EC.mat
# in if
# 0
# 48
# (204, 10001)
# (102, 9901)
# subject idx is
# 3
# PreProcessed_AD030_Preprocessed_EC.mat
# in if
# 0
# 64
# (204, 10001)
# (102, 9901)

# %%
features_erp_mci_rs.shape
# Out:
# (4, 102, 13)

# %%
import numpy as np


# Iterate over each element of the feature array
nan_found = False
for i in range(features_erp_mci_rs.shape[0]):
    for j in range(features_erp_mci_rs.shape[1]):
        for k in range(features_erp_mci_rs.shape[2]):
            # Check if the current element is NaN
            print(features_erp_mci_rs[i, j, k])
# Out:
# 2.1354916715332417e-11
# 6.098
# 1.3291867509694958e-10
# -1.4167595993440035e-13
# 1.3651728933833489e-11
# 1.3426407563621047e-11
# 1.359241289575087e-11
# 2.1178451936140424e-12
# 0.257269907418758
# 0.08819998776752103
# 0
# 1.0167819551987198
# 0.0
# 2.2330570425576908e-11
# 6.093
# 1.2854491410827265e-10
# 7.622351370667254e-15
# 1.495356428406757e-11
# 1.2984531431542067e-11
# 1.3151733000101541e-11
# 2.090460334293871e-12
# 0.5334376495854519
# 0.5773481815015655
# 0
# 1.151644505841953
# 0.0
# 1.9208457118656298e-11
# 5.703
# 1.180246032038132e-10
# 6.621929386861228e-14
# 1.2718142361906617e-11
# 1.1921906889195512e-11
# 1.2067248264913682e-11
# 1.8672484602791542e-12
# 0.3284208678674905
# 0.0830828499588816
# 0
# 1.0667875936384565
# 0.0
# 2.6711341619615444e-11
# 4.187
# 1.676726840427089e-10
# -1.5550562890691934e-14
# 1.769350866079607e-11
# 1.693709028188052e-11
# 1.7145769017613607e-11
# 2.6669023208184845e-12
# 0.3196466724217462
# -0.14190409863280928
# 0
# ...

# %% [markdown]
# # feature extraction:healthy and MCI subjects movie state

# %%
import os
import glob


# Construct the path to the target folder
folder_path = "D:\internship_ulster_university\combined_grad_movie_state"

# Move into the target folder
os.chdir(folder_path)

# Select all files ending with ".mat"
matfiles_ms = glob.glob("*.mat")

# Print the list of selected files
print("Selected .mat files:")
for file in matfiles_ms:
    print(file)
# Out:
# Selected .mat files:
# Combined_grad_AD001_MoviesWatching.mat
# Combined_grad_AD002_MoviesWatching.mat
# Combined_grad_AD003_MoviesWatching.mat
# Combined_grad_AD004_MoviesWatching.mat
# Combined_grad_AD006_MoviesWatching.mat
# Combined_grad_AD008_MoviesWatching.mat
# Combined_grad_AD010_MoviesWatching.mat
# Combined_grad_AD011_MoviesWatching.mat
# Combined_grad_AD012_MoviesWatching.mat
# Combined_grad_AD013_MoviesWatching.mat
# Combined_grad_AD014_MoviesWatching.mat
# Combined_grad_AD015_MoviesWatching.mat
# Combined_grad_AD016_MoviesWatching.mat
# Combined_grad_AD017_MoviesWatching.mat
# Combined_grad_AD018_MoviesWatching.mat
# Combined_grad_AD020_MoviesWatching.mat
# Combined_grad_AD026_MoviesWatching.mat
# Combined_grad_AD027_MoviesWatching.mat
# Combined_grad_AD028_MoviesWatching.mat
# Combined_grad_AD030_MoviesWatching.mat
# Combined_grad_AD031_MoviesWatching.mat

# %%
trial_counts_movie_state=[]
num_trials=0
for subject in range(len(matfiles_ms)):
    name=matfiles_ms[subject]
    print(name)
    dat = mat73.loadmat(matfiles_ms[subject])
    for key, value in dat.items():
        print(key)
    data=dat['MEG']
    for key, value in data.items():
        print(key)
    new=data['trial']
    print('new shape')
    print(len(new))
    data2=np.asarray(new)
    print(data2.shape[0])
    trial_counts_movie_state.append(data2.shape[0])
    num_trials+=data2.shape[0]
# Out:
# Combined_grad_AD001_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 52
# 52
# Combined_grad_AD002_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 51
# 51
# Combined_grad_AD003_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 52
# 52
# Combined_grad_AD004_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49
# Combined_grad_AD006_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 48
# 48
# Combined_grad_AD008_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49
# Combined_grad_AD010_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 50
# 50
# Combined_grad_AD011_MoviesWatching.mat
# MEG
# cfg
# ...

# %%
print(num_trials)
# Out:
# 1041

# %%
print(trial_counts_movie_state)
# Out:
# [52, 51, 52, 49, 48, 49, 50, 50, 49, 49, 50, 50, 49, 49, 49, 49, 50, 49, 49, 49, 49]

# %%
import numpy as np
import pandas as pd

trial_data=[]
num_trials_movie_state_healthy=0
start=0
raw_list_mean_ms_healthy = []
for subject, trials in enumerate(trial_counts_movie_state[:16]):
    print('subject idx is')
    print(subject)
    print("trials is")
    print(trials)
    name=matfiles_ms[subject]
    print(name)
    dat = mat73.loadmat(matfiles_ms[subject])
    data=dat['MEG']
    new=data['trial']
    data2=np.asarray(new)
    print(data2.shape)
    num_trials_movie_state_healthy+=data2.shape[0]
    average_data_ms_healthy = np.mean(data2[:,:102,:], axis=0)
    print("data averaged for all trials of 1 subject")
    print(average_data_ms_healthy.shape)
    raw = mne.io.RawArray(average_data_ms_healthy, info)
    raw_list_mean_ms_healthy.append(raw)
    print(len(raw_list_mean_ms_healthy))
# Out:
# subject idx is
# 0
# trials is
# 52
# Combined_grad_AD001_MoviesWatching.mat
# (52, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 1
# subject idx is
# 1
# trials is
# 51
# Combined_grad_AD002_MoviesWatching.mat
# (51, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 2
# subject idx is
# 2
# trials is
# 52
# Combined_grad_AD003_MoviesWatching.mat
# (52, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 3
# subject idx is
# 3
# trials is
# 49
# Combined_grad_AD004_MoviesWatching.mat
# (49, 204, 10000)
# ...

# %%
print(len(raw_list_mean_ms_healthy))
# Out:
# 16

# %%
import numpy as np
import pandas as pd
trial_data=[]
num_trials_movie_state_mci=0
start=0
raw_list_mean_ms_mci = []
trial_counts_movie_state_mci=trial_counts_movie_state[16:20]

for subject in range(16,21):
    print('subject idx is')
    print(subject)
    name=matfiles_ms[subject]
    print(name)
    dat = mat73.loadmat(matfiles_ms[subject])
    data=dat['MEG']
    new=data['trial']
    data2=np.asarray(new)
    print(data2.shape)
    num_trials_movie_state_mci+=data2.shape[0]
    average_data_ms_mci = np.mean(data2[:,:102,:], axis=0)
    print("data averaged for all trials of 1 subject")
    print(average_data_ms_mci.shape)
    raw = mne.io.RawArray(average_data_ms_mci, info)
    raw_list_mean_ms_mci.append(raw)
    print(len(raw_list_mean_ms_mci))
# Out:
# subject idx is
# 16
# Combined_grad_AD026_MoviesWatching.mat
# (50, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 1
# subject idx is
# 17
# Combined_grad_AD027_MoviesWatching.mat
# (49, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 2
# subject idx is
# 18
# Combined_grad_AD028_MoviesWatching.mat
# (49, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 3
# subject idx is
# 19
# Combined_grad_AD030_MoviesWatching.mat
# (49, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# ...

# %%
print(len(raw_list_mean_ms_mci))
# Out:
# 5

# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import kurtosis
# Define frequency bands
alpha_band = (8, 13)  # Alpha band frequencies
beta_band = (13, 30)  # Beta band frequencies
features_psd_ms_healthy = []
for raw in raw_list_mean_ms_healthy:
    # Compute PSD
    psd_spectrum_ms_healthy = raw.compute_psd(method='multitaper', fmin=0, fmax=40, tmin=None, tmax=None)
    print(psd_spectrum_ms_healthy.shape)
    features=[]
    for idx, ch_name in enumerate(list_1):
        psd_data = psd_spectrum_ms_healthy[idx]  # PSD data for the current channel  
         # Statistical Features
        
        print("shape of data")
        print(psd_data.shape)
        mean_power = np.mean(psd_data)
        variance_power = np.var(psd_data)
    
        skewness_power = stats.skew(psd_data)
        kurtosis_power = stats.kurtosis(psd_data)
        print('mean_power')
        print(mean_power)
        print('v_power')
        print(variance_power)
        print('s_power')
        print(skewness_power)

    # Frequency-Domain Features
        freqs = psd_spectrum_ms_healthy.freqs  # Frequency values
        max_power_freq = freqs[np.argmax(psd_data)]
        max_power = np.max(psd_data)
        band_power_alpha = np.sum(psd_data[:,(freqs >= 8) & (freqs <= 13)])  # Alpha band
        band_power_beta = np.sum(psd_data[:,(freqs >= 13) & (freqs <= 30)])  # Beta band
        
            # Compute entropy for alpha band
        alpha_prob = psd_data[:,(freqs >= alpha_band[0]) & (freqs <= alpha_band[1])] / np.sum(psd_data)
        spectral_entropy_alpha = -np.sum(alpha_prob * np.log2(alpha_prob + 1e-12))  # Add a small value to avoid log(0)

        # Compute entropy for beta band
        beta_prob = psd_data[:,(freqs >= beta_band[0]) & (freqs <= beta_band[1])] / np.sum(psd_data)
        spectral_entropy_beta = -np.sum(beta_prob * np.log2(beta_prob + 1e-12))  # Add a small value to avoid log(0)

        # Append features for the current channel
        channel_features = [mean_power, variance_power, skewness_power, kurtosis_power,
                            max_power_freq, max_power, band_power_alpha, band_power_beta,
                            spectral_entropy_alpha, spectral_entropy_beta]
        
        features.append(channel_features)
    features_psd_ms_healthy.append(features) 
features_psd_ms_healthy = np.array(features_psd_ms_healthy)

# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import kurtosis
# Define frequency bands
alpha_band = (8, 13)  # Alpha band frequencies
beta_band = (13, 30)  # Beta band frequencies
features_psd_ms_mci = []
for raw in raw_list_mean_ms_mci:
    # Compute PSD
    psd_spectrum_ms_mci = raw.compute_psd(method='multitaper', fmin=0, fmax=40, tmin=None, tmax=None)
    print(psd_spectrum_ms_mci.shape)
    features=[]
    for idx, ch_name in enumerate(list_1):
        psd_data = psd_spectrum_ms_mci[idx]  # PSD data for the current channel  
         # Statistical Features
        
        print("shape of data")
        print(psd_data.shape)
        mean_power = np.mean(psd_data)
        variance_power = np.var(psd_data)
    
        skewness_power = stats.skew(psd_data)
        kurtosis_power = stats.kurtosis(psd_data)
        print('mean_power')
        print(mean_power)
        print('v_power')
        print(variance_power)
        print('s_power')
        print(skewness_power)

    # Frequency-Domain Features
        freqs = psd_spectrum_ms_mci.freqs  # Frequency values
        max_power_freq = freqs[np.argmax(psd_data)]
        max_power = np.max(psd_data)
        band_power_alpha = np.sum(psd_data[:,(freqs >= 8) & (freqs <= 13)])  # Alpha band
        band_power_beta = np.sum(psd_data[:,(freqs >= 13) & (freqs <= 30)])  # Beta band
        
            # Compute entropy for alpha band
        alpha_prob = psd_data[:,(freqs >= alpha_band[0]) & (freqs <= alpha_band[1])] / np.sum(psd_data)
        spectral_entropy_alpha = -np.sum(alpha_prob * np.log2(alpha_prob + 1e-12))  # Add a small value to avoid log(0)

        # Compute entropy for beta band
        beta_prob = psd_data[:,(freqs >= beta_band[0]) & (freqs <= beta_band[1])] / np.sum(psd_data)
        spectral_entropy_beta = -np.sum(beta_prob * np.log2(beta_prob + 1e-12))  # Add a small value to avoid log(0)

        # Append features for the current channel
        channel_features = [mean_power, variance_power, skewness_power, kurtosis_power,
                            max_power_freq, max_power, band_power_alpha, band_power_beta,
                            spectral_entropy_alpha, spectral_entropy_beta]
        
        features.append(channel_features)
    features_psd_ms_mci.append(features) 
features_psd_ms_mci = np.array(features_psd_ms_mci)

# %%
features_psd_ms_healthy.shape
# Out:
# (16, 102, 10)

# %%
features_psd_ms_mci.shape
# Out:
# (5, 102, 10)

# %%
import numpy as np
import pandas as pd
from scipy.stats import skew, kurtosis
from scipy.signal import find_peaks
from numpy import diff


features_erp_healthy_ms = []


num_trials=0
start=0


for subject in range(0,16):
    print('subject idx is')
    print(subject)
    name=matfiles_ms[subject]
    print(name)
    dat = mat73.loadmat(matfiles_ms[subject])
    data=dat['MEG']
    times=data['time']
    time_1_trial=times[0]
    print("1st trial times")
    #print(time_1_trial)
    new=data['trial']
    data2=np.asarray(new)
    print(data2.shape)
    num_trials_movie_state_healthy+=data2.shape[0]
    average_data_ms_healthy = np.mean(data2[:,:102,:], axis=0)
    print("data averaged for all trials of 1 subject")
    print(average_data_ms_healthy.shape)
    peak_amplitudes = []
    latencies = []
    auc_values = []
    slopes = []
    features=[]
    from scipy.integrate import simps
    
    
    # Initialize empty lists to store features
    peak_to_peak_amplitudes = []
    mean_absolute_amplitudes = []
    rms_amplitudes = []
    std_devs = []
    skewness_values = []
    kurtosis_values = []
    zero_crossing_rates = []
    aar_values=[]
    zork_values=[]


# Iterate through channels
    for idx, ch_name in enumerate(list_1):
        # Extract ERP data for the current channel
        channel_data = average_data_ms_healthy[idx,:]
        
    
    # Compute peak amplitude and latency
        peak_amplitude = np.max(channel_data)
         # Compute peak-to-peak amplitude
        peak_to_peak_amplitude = np.max(channel_data) - np.min(channel_data)
        peak_to_peak_amplitudes.append(peak_to_peak_amplitude)
        # Compute mean absolute amplitude
        mean_absolute_amplitude = np.mean(np.abs(channel_data))
        mean_absolute_amplitudes.append(mean_absolute_amplitude)
            # Compute RMS amplitude
        rms_amplitude = np.sqrt(np.mean(channel_data**2))
        rms_amplitudes.append(rms_amplitude)

        # Compute standard deviation
        std_dev = np.std(channel_data)
        std_devs.append(std_dev)

        # Compute skewness
        skewness = skew(channel_data)
        skewness_values.append(skewness)

        # Compute kurtosis
        kurtosis_val = kurtosis(channel_data)
        kurtosis_values.append(kurtosis_val)

        # Compute zero crossing rate
        zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
        zero_crossing_rates.append(zero_crossings)
        

        latency = time_1_trial[np.argmax(channel_data)]
    
    # Calculate area under the curve (AUC)
        auc_value = simps(channel_data, time_1_trial)
    
    # Calculate slope (e.g., by fitting a linear regression model)
    # You can use numpy's polyfit function for this purpose
        slope_coefficients = np.polyfit(time_1_trial, channel_data, 1)
        slope = slope_coefficients[0]
        
        
        zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
        zero_crossing_rates.append(zero_crossings)

        # Compute AAR
        aar = peak_to_peak_amplitude / mean_absolute_amplitude
        aar_values.append(aar)

        # Compute ZORK
        zork = zero_crossings / kurtosis_val
        zork_values.append(zork)

        
        channel_features = [peak_amplitude,latency,auc_value,slope,
                            peak_to_peak_amplitude, 
                                 mean_absolute_amplitude, 
                                 rms_amplitude, 
                                 std_dev, 
                                 skewness, 
                                 kurtosis_val, 
                                 zero_crossings,aar,zork]
        features.append(channel_features)

# Convert features to numpy array

    
    features_erp_healthy_ms.append(features)
    
features_erp_healthy_ms = np.array(features_erp_healthy_ms,dtype=object)
# Out:
# subject idx is
# 0
# Combined_grad_AD001_MoviesWatching.mat
# 1st trial times
# (52, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# subject idx is
# 1
# Combined_grad_AD002_MoviesWatching.mat
# 1st trial times
# (51, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# subject idx is
# 2
# Combined_grad_AD003_MoviesWatching.mat
# 1st trial times
# (52, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# subject idx is
# 3
# Combined_grad_AD004_MoviesWatching.mat
# 1st trial times
# (49, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# subject idx is
# 4
# Combined_grad_AD006_MoviesWatching.mat
# 1st trial times
# (48, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# subject idx is
# 5
# Combined_grad_AD008_MoviesWatching.mat
# 1st trial times
# (49, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# subject idx is
# 6
# ...

# %%
features_erp_healthy_ms.shape
# Out:
# (16, 102, 13)

# %%
import numpy as np
import pandas as pd
from scipy.stats import skew, kurtosis
from scipy.signal import find_peaks
from numpy import diff


features_erp_mci_ms = []


num_trials=0
start=0


for subject in range(16,21):
    print('subject idx is')
    print(subject)
    name=matfiles_ms[subject]
    print(name)
    dat = mat73.loadmat(matfiles_ms[subject])
    data=dat['MEG']
    times=data['time']
    time_1_trial=times[0]
    print("1st trial times")
    print(time_1_trial)
    new=data['trial']
    data2=np.asarray(new)
    print(data2.shape)
    num_trials_movie_state_mci+=data2.shape[0]
    average_data_ms_mci = np.mean(data2[:,:102,:], axis=0)
    print("data averaged for all trials of 1 subject")
    print(average_data_ms_mci.shape)
    peak_amplitudes = []
    latencies = []
    auc_values = []
    slopes = []
    features=[]
    from scipy.integrate import simps
    
    
    # Initialize empty lists to store features
    peak_to_peak_amplitudes = []
    mean_absolute_amplitudes = []
    rms_amplitudes = []
    std_devs = []
    skewness_values = []
    kurtosis_values = []
    zero_crossing_rates = []
    aar_values=[]
    zork_values=[]


# Iterate through channels
    for idx, ch_name in enumerate(list_1):
        # Extract ERP data for the current channel
        channel_data = average_data_ms_mci[idx,:]
        
    
    # Compute peak amplitude and latency
        peak_amplitude = np.max(channel_data)
         # Compute peak-to-peak amplitude
        peak_to_peak_amplitude = np.max(channel_data) - np.min(channel_data)
        peak_to_peak_amplitudes.append(peak_to_peak_amplitude)
        # Compute mean absolute amplitude
        mean_absolute_amplitude = np.mean(np.abs(channel_data))
        mean_absolute_amplitudes.append(mean_absolute_amplitude)
        rms_amplitude = np.sqrt(np.mean(channel_data**2))
        rms_amplitudes.append(rms_amplitude)

        # Compute standard deviation
        std_dev = np.std(channel_data)
        std_devs.append(std_dev)

        # Compute skewness
        skewness = skew(channel_data)
        skewness_values.append(skewness)

        # Compute kurtosis
        kurtosis_val = kurtosis(channel_data)
        kurtosis_values.append(kurtosis_val)

        # Compute zero crossing rate
        zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
        zero_crossing_rates.append(zero_crossings)
        

        latency = time_1_trial[np.argmax(channel_data)]
    # Calculate area under the curve (AUC)
        auc_value = simps(channel_data, time_1_trial)
    
    # Calculate slope (e.g., by fitting a linear regression model)
    # You can use numpy's polyfit function for this purpose
        slope_coefficients = np.polyfit(time_1_trial, channel_data, 1)
        slope = slope_coefficients[0]
        
        
        zero_crossings = len(np.where(np.diff(np.sign(channel_data)))[0])
        zero_crossing_rates.append(zero_crossings)

        # Compute AAR
        aar = peak_to_peak_amplitude / mean_absolute_amplitude
        aar_values.append(aar)

        # Compute ZORK
        zork = zero_crossings / kurtosis_val
        zork_values.append(zork)

        
        channel_features = [peak_amplitude,latency,auc_value,slope,
                            peak_to_peak_amplitude, 
                                 mean_absolute_amplitude, 
                                 rms_amplitude, 
                                 std_dev, 
                                 skewness, 
                                 kurtosis_val, 
                                 zero_crossings,aar,zork]
        features.append(channel_features)

# Convert features to numpy array

    
    features_erp_mci_ms.append(features)
    
features_erp_mci_ms = np.array(features_erp_mci_ms,dtype=object)
# Out:
# subject idx is
# 16
# Combined_grad_AD026_MoviesWatching.mat
# 1st trial times
# [0.000e+00 1.000e-03 2.000e-03 ... 9.997e+00 9.998e+00 9.999e+00]
# (50, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# subject idx is
# 17
# Combined_grad_AD027_MoviesWatching.mat
# 1st trial times
# [0.000e+00 1.000e-03 2.000e-03 ... 9.997e+00 9.998e+00 9.999e+00]
# (49, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# subject idx is
# 18
# Combined_grad_AD028_MoviesWatching.mat
# 1st trial times
# [0.000e+00 1.000e-03 2.000e-03 ... 9.997e+00 9.998e+00 9.999e+00]
# (49, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# subject idx is
# 19
# Combined_grad_AD030_MoviesWatching.mat
# 1st trial times
# [0.000e+00 1.000e-03 2.000e-03 ... 9.997e+00 9.998e+00 9.999e+00]
# (49, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# subject idx is
# 20
# Combined_grad_AD031_MoviesWatching.mat
# 1st trial times
# ...

# %%
print(features_erp_mci_ms.shape)
# Out:
# (5, 102, 13)

# %%
features_psd_ms_mci.shape
# Out:
# (5, 102, 10)

# %%
print(features_erp_healthy_ms.shape)
# Out:
# (16, 102, 13)

# %%
features_psd_ms_healthy.shape
# Out:
# (16, 102, 10)

# %%
new_features_psd_ms_healthy = np.delete(features_psd_ms_healthy, [2, 3], axis=2)

# %%
new_features_psd_ms_mci = np.delete(features_psd_ms_mci, [2, 3], axis=2)

# %%
new_features_psd_ms_healthy.shape
# Out:
# (16, 102, 8)

# %%
new_features_psd_ms_mci.shape
# Out:
# (5, 102, 8)

# %%
new_features_psd_healthy_rs.shape
# Out:
# (16, 102, 8)

# %%
new_features_psd_mci_rs.shape
# Out:
# (4, 102, 8)

# %% [markdown]
# ## summary of feature shapes

# %%
usable_features_psd_healthy_rs=new_features_psd_healthy_rs[:,:,4:8]
print(usable_features_psd_healthy_rs.shape)
# Out:
# (16, 102, 4)

# %%
features_erp_healthy_rs.shape
# Out:
# (16, 102, 13)

# %%
usable_features_psd_mci_rs=new_features_psd_mci_rs[:,:,4:8]
print(usable_features_psd_mci_rs.shape)
# Out:
# (4, 102, 4)

# %%
features_erp_mci_rs.shape
# Out:
# (4, 102, 13)

# %%
usable_features_psd_ms_healthy=new_features_psd_ms_healthy[:,:,4:8]
print(usable_features_psd_ms_healthy.shape)
# Out:
# (16, 102, 4)

# %%
features_erp_healthy_ms.shape
# Out:
# (16, 102, 13)

# %%
usable_features_psd_ms_mci=new_features_psd_ms_mci[:,:,4:8]
print(usable_features_psd_ms_mci.shape)
# Out:
# (5, 102, 4)

# %%
features_erp_mci_ms.shape
# Out:
# (5, 102, 13)

# %% [markdown]
# # binary classification: healthy subjects resting state vs healthy subjects task state

# %%
import numpy as np
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.metrics import classification_report
resting_state_features = np.concatenate((usable_features_psd_healthy_rs, features_erp_healthy_rs), axis=2)

# Combine PSD and ERP features for movie state
movie_state_features = np.concatenate((usable_features_psd_ms_healthy, features_erp_healthy_ms), axis=2)

# Combine the labels
resting_state_labels = np.zeros(resting_state_features.shape[0])
movie_state_labels = np.ones(movie_state_features.shape[0])

# Combine the features and labels
all_features = np.concatenate((resting_state_features, movie_state_features), axis=0)
all_labels = np.concatenate((resting_state_labels, movie_state_labels), axis=0)


indices = np.arange(all_features.shape[0])
np.random.shuffle(indices)

shuffled_features = all_features[indices]
shuffled_labels = all_labels[indices]
n_samples, n_channels, n_features = shuffled_features.shape
X_train = shuffled_features.reshape(n_samples, -1)
print("crude training data shape")
print(X_train.shape)

# Convert to float to handle potential non-numeric data
X_train = X_train.astype(float)
nan_indices = np.isnan(X_train).any(axis=0)
print("indices of nan values")
print(nan_indices.shape)
X_train1 = X_train[:, ~nan_indices]
print("Shape of train_healthy_selected_features_rsec after removing NaN columns:", X_train1.shape)
from sklearn.metrics import make_scorer, f1_score, roc_auc_score


# Define the number of repetitions for train/test splitting and evaluation
n_repeats = 10

# Lists to store metrics for each repetition
accuracy_scores = []
precision_0_scores = []
precision_1_scores = []
recall_0_scores = []
recall_1_scores = []
f1_0_scores = []
f1_1_scores = []
mavg_precision_scores=[]
mavg_recall_scores=[]
mavg_f1_scores=[]
wavg_precision_scores=[]
wavg_recall_scores=[]
wavg_f1_scores=[]
for _ in range(n_repeats):
    # Split data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_train1, shuffled_labels, test_size=0.2, random_state=None)

    print("shape of train and test features")
    print(X_train.shape)
    print(X_test.shape)

    from sklearn.linear_model import LassoCV

    # Create the LASSO model
    lasso = LassoCV(cv=5)

    # Use SelectFromModel for feature selection
    sfm = SelectFromModel(lasso)
    X_train_selected = sfm.fit_transform(X_train, y_train)

    # Print the selected features
    print("Shape of selected features:", X_train_selected.shape)
    # Use SelectFromModel to select features for test data
    X_test_selected = sfm.transform(X_test)
    # Print the selected features for test data
    print("Shape of selected test features:", X_test_selected.shape)
    
    # Define the k-fold cross-validation
    k_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=None)

    # Define a new Random Forest classifier
    clf_selected = RandomForestClassifier()

    # Perform cross-validation
    cv_scores = cross_val_score(clf_selected, X_train_selected, y_train, cv=k_fold, scoring='accuracy')

    # Train the classifier on the full training data
    clf_selected.fit(X_train_selected, y_train)
    
    from sklearn.metrics import classification_report
    y_pred = clf_selected.predict(X_test_selected)

    # Calculate and store metrics
    report = classification_report(y_test, y_pred, output_dict=True)
    print(report)
    accuracy_scores.append(report['accuracy'])
    mavg_precision_scores.append(report['macro avg']['precision'])
    mavg_recall_scores.append(report['macro avg']['recall'])
    mavg_f1_scores.append(report['macro avg']['f1-score'])
    wavg_precision_scores.append(report['weighted avg']['precision'])
    wavg_recall_scores.append(report['weighted avg']['recall'])
    wavg_f1_scores.append(report['weighted avg']['f1-score'])
    # Check if both classes are present in the testing data
    if '0.0' in report:
        precision_0_scores.append(report['0.0']['precision'])
        recall_0_scores.append(report['0.0']['recall'])
        f1_0_scores.append(report['0.0']['f1-score'])
       
    if '1.0' in report:
        precision_1_scores.append(report['1.0']['precision'])
        recall_1_scores.append(report['1.0']['recall'])
        f1_1_scores.append(report['1.0']['f1-score'])
# Print average metrics and standard deviations
print("Accuracy: {:.2f} ± {:.2f}".format(np.mean(accuracy_scores), np.std(accuracy_scores)))
print("Precision (class 0): {:.2f} ± {:.2f}".format(np.mean(precision_0_scores), np.std(precision_0_scores)))
print("Precision (class 1): {:.2f} ± {:.2f}".format(np.mean(precision_1_scores), np.std(precision_1_scores)))
print("Recall (class 0): {:.2f} ± {:.2f}".format(np.mean(recall_0_scores), np.std(recall_0_scores)))
print("Recall (class 1): {:.2f} ± {:.2f}".format(np.mean(recall_1_scores), np.std(recall_1_scores)))
print("F1-score (class 0): {:.2f} ± {:.2f}".format(np.mean(f1_0_scores), np.std(f1_0_scores)))
print("F1-score (class 1): {:.2f} ± {:.2f}".format(np.mean(f1_1_scores), np.std(f1_1_scores)))
print("Macro avg precision: {:.2f} ± {:.2f}".format(np.mean(mavg_precision_scores), np.std(mavg_precision_scores)))
print("Macro avg recall: {:.2f} ± {:.2f}".format(np.mean(mavg_recall_scores), np.std(mavg_recall_scores)))
print("Macro avg f1-score: {:.2f} ± {:.2f}".format(np.mean(mavg_f1_scores), np.std(mavg_f1_scores)))
print("Weighted avg precision: {:.2f} ± {:.2f}".format(np.mean(wavg_precision_scores), np.std(wavg_precision_scores)))
print("weighted avg recall: {:.2f} ± {:.2f}".format(np.mean(wavg_recall_scores), np.std(wavg_recall_scores)))
print("weighted avg f1-score: {:.2f} ± {:.2f}".format(np.mean(wavg_f1_scores), np.std(wavg_f1_scores)))
# Out:
# crude training data shape
# (32, 1734)
# indices of nan values
# (1734,)
# Shape of train_healthy_selected_features_rsec after removing NaN columns: (32, 1728)
# shape of train and test features
# (25, 1728)
# (7, 1728)
# Shape of selected features: (25, 4)
# Shape of selected test features: (7, 4)
# {'0.0': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4}, '1.0': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3}, 'accuracy': 1.0, 'macro avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7}, 'weighted avg': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7}}
# shape of train and test features
# (25, 1728)
# (7, 1728)
# Shape of selected features: (25, 3)
# Shape of selected test features: (7, 3)
# ...

# %%
import numpy as np
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# Combine PSD and ERP features for resting state
resting_state_features = np.concatenate((usable_features_psd_healthy_rs, features_erp_healthy_rs), axis=2)

# Combine PSD and ERP features for task state
movie_state_features = np.concatenate((usable_features_psd_ms_healthy, features_erp_healthy_ms), axis=2)

# Combine the labels
resting_state_labels = np.zeros(resting_state_features.shape[0])
movie_state_labels = np.ones(movie_state_features.shape[0])

# Combine the features and labels
all_features = np.concatenate((resting_state_features, movie_state_features), axis=0)
all_labels = np.concatenate((resting_state_labels, movie_state_labels), axis=0)

# %%
# (32, 20, 17)
# (32, 20, 17)
# (64,)
all_features.shape
print(resting_state_features.shape)
print(movie_state_features.shape)
print(all_labels.shape)
# Out:
# (16, 102, 17)
# (16, 102, 17)
# (32,)

# %%
resting_state_features[1,1,3]
# Out:
# 2.167694154498525

# %%
all_features[1,1,3]
# Out:
# 2.167694154498525

# %%
print(all_labels.reshape(-1, 1).shape)
# Out:
# (32, 1)

# %%
import numpy as np
import pandas as pd

# Reshape all_features
reshaped_features = all_features.reshape(all_features.shape[0], -1)  # Flatten the last two dimensions
print(reshaped_features.shape)
# Add labels as an additional column
features_with_labels = np.column_stack((reshaped_features, all_labels.reshape(-1, 1)))

# Convert to DataFrame
df = pd.DataFrame(features_with_labels)

# Save to CSV
df.to_csv('binary_class_healthy_rs_vs_ts.csv', index=False)
# Out:
# (32, 1734)

# %%
reshaped_features[1,20]
# Out:
# 2.167694154498525

# %%
len(ch_aud)
# Out:
# 102

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('binary_class_healthy_rs_vs_ts.csv')

# Define column names
channels = ['MEG0112+0113',
 'MEG0122+0123',
 'MEG0132+0133',
 'MEG0142+0143',
 'MEG0212+0213',
 'MEG0222+0223',
 'MEG0232+0233',
 'MEG0242+0243',
 'MEG0312+0313',
 'MEG0322+0323',
 'MEG0332+0333',
 'MEG0342+0343',
 'MEG0412+0413',
 'MEG0422+0423',
 'MEG0432+0433',
 'MEG0442+0443',
 'MEG0512+0513',
 'MEG0522+0523',
 'MEG0532+0533',
 'MEG0542+0543',
 'MEG0612+0613',
 'MEG0622+0623',
 'MEG0632+0633',
 'MEG0642+0643',
 'MEG0712+0713',
 'MEG0722+0723',
 'MEG0732+0733',
 'MEG0742+0743',
 'MEG0812+0813',
 'MEG0822+0823',
 'MEG0912+0913',
 'MEG0922+0923',
 'MEG0932+0933',
 'MEG0942+0943',
 'MEG1012+1013',
 'MEG1022+1023',
 'MEG1032+1033',
 'MEG1042+1043',
 'MEG1112+1113',
 'MEG1122+1123',
 'MEG1132+1133',
 'MEG1142+1143',
 'MEG1212+1213',
 'MEG1222+1223',
 'MEG1232+1233',
 'MEG1242+1243',
 'MEG1312+1313',
 'MEG1322+1323',
 'MEG1332+1333',
 'MEG1342+1343',
 'MEG1412+1413',
 'MEG1422+1423',
 'MEG1432+1433',
 'MEG1442+1443',
 'MEG1512+1513',
 'MEG1522+1523',
 'MEG1532+1533',
 'MEG1542+1543',
 'MEG1612+1613',
 'MEG1622+1623',
 'MEG1632+1633',
 'MEG1642+1643',
 'MEG1712+1713',
 'MEG1722+1723',
 'MEG1732+1733',
 'MEG1742+1743',
 'MEG1812+1813',
 'MEG1822+1823',
 'MEG1832+1833',
 'MEG1842+1843',
 'MEG1912+1913',
 'MEG1922+1923',
 'MEG1932+1933',
 'MEG1942+1943',
 'MEG2012+2013',
 'MEG2022+2023',
 'MEG2032+2033',
 'MEG2042+2043',
 'MEG2112+2113',
 'MEG2122+2123',
 'MEG2132+2133',
 'MEG2142+2143',
 'MEG2212+2213',
 'MEG2222+2223',
 'MEG2232+2233',
 'MEG2242+2243',
 'MEG2312+2313',
 'MEG2322+2323',
 'MEG2332+2333',
 'MEG2342+2343',
 'MEG2412+2413',
 'MEG2422+2423',
 'MEG2432+2433',
 'MEG2442+2443',
 'MEG2512+2513',
 'MEG2522+2523',
 'MEG2532+2533',
 'MEG2542+2543',
 'MEG2612+2613',
 'MEG2622+2623',
 'MEG2632+2633',
 'MEG2642+2643']
print(len(channels))
features = ['band_power_alpha', 'band_power_beta', 'spectral_entropy_alpha', 'spectral_entropy_beta',
            'peak_amplitude', 'latency', 'auc_value', 'slope', 'peak_to_peak_amplitude',
            'mean_absolute_amplitude', 'rms_amplitude', 'std_dev', 'skewness', 'kurtosis_val',
            'zero_crossings', 'aar', 'zork']

# Generate column names
column_names = [f'Channel {channel_idx} {feature}' for channel_idx in range(1, 103) for feature in features]
# Add "labels" column name
column_names.append("labels")
# Assign column names to DataFrame
df.columns = column_names

# Save DataFrame to CSV
df.to_csv('features_and_labels_with_names.csv', index=False)
# Out:
# 102

# %%
import numpy as np
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# Combine PSD and ERP features for resting state
resting_state_features = np.concatenate((usable_features_psd_healthy_rs, features_erp_healthy_rs), axis=2)

# Combine PSD and ERP features for movie state
movie_state_features = np.concatenate((usable_features_psd_ms_healthy, features_erp_healthy_ms), axis=2)

# Combine the labels
resting_state_labels = np.zeros(resting_state_features.shape[0])
movie_state_labels = np.ones(movie_state_features.shape[0])

# Combine the features and labels
all_features = np.concatenate((resting_state_features, movie_state_features), axis=0)
all_labels = np.concatenate((resting_state_labels, movie_state_labels), axis=0)


indices = np.arange(all_features.shape[0])
np.random.shuffle(indices)

shuffled_features = all_features[indices]
shuffled_labels = all_labels[indices]
n_samples, n_channels, n_features = shuffled_features.shape
X_train = shuffled_features.reshape(n_samples, -1)
print("crude training data shape")
print(X_train.shape)

# Convert to float to handle potential non-numeric data
X_train = X_train.astype(float)
nan_indices = np.isnan(X_train).any(axis=0)
print("indices of nan values")
print(nan_indices.shape)
X_train1 = X_train[:, ~nan_indices]
print("Shape of train_healthy_selected_features_rsec after removing NaN columns:", X_train1.shape)
from sklearn.metrics import make_scorer, f1_score, roc_auc_score

print("Shape of X_test after removing NaN columns:", shuffled_labels.shape)
X_train, X_test, y_train, y_test = train_test_split(X_train1, shuffled_labels, test_size=0.2, random_state=42)


print("shape of train and test features")
print(X_train.shape)
print(X_test.shape)

from sklearn.linear_model import LassoCV

# Create the LASSO model
lasso = LassoCV(cv=5)

# Use SelectFromModel for feature selection
sfm = SelectFromModel(lasso)
X_train_selected = sfm.fit_transform(X_train, y_train)

# Print the selected features
print("Shape of selected features:", X_train_selected.shape)
# Use SelectFromModel to select features for test data
X_test_selected = sfm.transform(X_test)

# Print the selected features for test data
print("Shape of selected test features:", X_test_selected.shape)
# Out:
# crude training data shape
# (32, 1734)
# indices of nan values
# (1734,)
# Shape of train_healthy_selected_features_rsec after removing NaN columns: (32, 1728)
# Shape of X_test after removing NaN columns: (32,)
# shape of train and test features
# (25, 1728)
# (7, 1728)
# C:\Users\stuti\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.332e-04, tolerance: 5.000e-04
#   model = cd_fast.enet_coordinate_descent(
# Shape of selected features: (25, 3)
# Shape of selected test features: (7, 3)

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold

# Define the k-fold cross-validation
k_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Define a new Random Forest classifier
clf_selected = RandomForestClassifier()

# Perform cross-validation
cv_scores = cross_val_score(clf_selected, X_train_selected, y_train, cv=k_fold, scoring='accuracy')

# Print the cross-validation scores
print("Cross-validation scores:", cv_scores)
print("Mean accuracy:", np.mean(cv_scores))

# Train the classifier on the full training data
clf_selected.fit(X_train_selected, y_train)

# Evaluate the classifier on the test data
accuracy = clf_selected.score(X_test_selected, y_test)
print("Accuracy on test data:", accuracy)
# Out:
# Cross-validation scores: [1.  0.8 1.  1.  1. ]
# Mean accuracy: 0.96
# Accuracy on test data: 1.0

# %%
print(X_test_selected)
print(y_test)
# Out:
# [[ 1.15943686e+00  1.22504140e+00  8.57178479e-01]
#  [ 1.22602329e-01  4.00863493e-01 -1.91063688e-02]
#  [ 1.28404678e+00 -2.48391847e-01 -2.62379808e-01]
#  [ 1.47152201e+00 -1.59487936e-01 -1.63721038e-01]
#  [ 2.59495079e+00  1.17369142e-01  5.60805887e-01]
#  [ 2.24094609e+01  2.37245444e+01  2.35929654e+01]
#  [ 1.49386005e+01  1.79649228e+01  4.13999233e+00]]
# [0. 0. 0. 0. 0. 1. 1.]

# %%
from sklearn.metrics import classification_report

# Train the classifier on the full training data
clf_selected.fit(X_train_selected, y_train)

# Predict labels for test data
y_pred = clf_selected.predict(X_test_selected)

# Print classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         5
#          1.0       1.00      1.00      1.00         2
#
#     accuracy                           1.00         7
#    macro avg       1.00      1.00      1.00         7
# weighted avg       1.00      1.00      1.00         7

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict the labels for the test data
y_pred = clf_selected.predict(X_test_selected)

# Generate the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap="YlGnBu", fmt="d", xticklabels=['Resting State', 'Task State'], yticklabels=['Resting State', 'Task State'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for Random Forest Classifier on Test Data')
plt.savefig('confusion_matrix_heatmap.jpeg')  # Save the heatmap as an image
plt.show()

# %%
import numpy as np
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# Combine PSD and ERP features for resting state
resting_state_features = np.concatenate((usable_features_psd_healthy_rs, features_erp_healthy_rs), axis=2)

# Combine PSD and ERP features for movie state
movie_state_features = np.concatenate((usable_features_psd_ms_healthy, features_erp_healthy_ms), axis=2)

# Combine the labels
resting_state_labels = np.zeros(resting_state_features.shape[0])
movie_state_labels = np.ones(movie_state_features.shape[0])

# Combine the features and labels
all_features = np.concatenate((resting_state_features, movie_state_features), axis=0)
all_labels = np.concatenate((resting_state_labels, movie_state_labels), axis=0)


indices = np.arange(all_features.shape[0])
np.random.shuffle(indices)

shuffled_features = all_features[indices]
shuffled_labels = all_labels[indices]
n_samples, n_channels, n_features = shuffled_features.shape
X_train = shuffled_features.reshape(n_samples, -1)
print("crude training data shape")
print(X_train.shape)

# Convert to float to handle potential non-numeric data
X_train = X_train.astype(float)
nan_indices = np.isnan(X_train).any(axis=0)
print("indices of nan values")
print(nan_indices.shape)
X_train1 = X_train[:, ~nan_indices]
print("Shape of train_healthy_selected_features_rsec after removing NaN columns:", X_train1.shape)
from sklearn.metrics import make_scorer, f1_score, roc_auc_score

print("Shape of X_test after removing NaN columns:", shuffled_labels.shape)
X_train, X_test, y_train, y_test = train_test_split(X_train1, shuffled_labels, test_size=0.2, random_state=42)


print("shape of train and test features")
print(X_train.shape)
print(X_test.shape)


# Create a Random Forest classifier
clf = RandomForestClassifier()

# Use SelectFromModel for feature selection
sfm = SelectFromModel(clf)
X_train_selected = sfm.fit_transform(X_train, y_train)

# Print the selected features
print("Shape of selected features:", X_train_selected.shape)

# Print the selected features
print("Shape of selected features:", X_train_selected.shape)
# Use SelectFromModel to select features for test data
X_test_selected = sfm.transform(X_test)

# Print the selected features for test data
print("Shape of selected test features:", X_test_selected.shape)
# Out:
# crude training data shape
# (32, 1734)
# indices of nan values
# (1734,)
# Shape of train_healthy_selected_features_rsec after removing NaN columns: (32, 1728)
# Shape of X_test after removing NaN columns: (32,)
# shape of train and test features
# (25, 1728)
# (7, 1728)
# Shape of selected features: (25, 82)
# Shape of selected features: (25, 82)
# Shape of selected test features: (7, 82)

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold

# Define the k-fold cross-validation
k_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Define a new Random Forest classifier
clf_selected = RandomForestClassifier()

# Perform cross-validation
cv_scores = cross_val_score(clf_selected, X_train_selected, y_train, cv=k_fold, scoring='accuracy')

# Print the cross-validation scores
print("Cross-validation scores:", cv_scores)
print("Mean accuracy:", np.mean(cv_scores))

# Train the classifier on the full training data
clf_selected.fit(X_train_selected, y_train)

# Evaluate the classifier on the test data
accuracy = clf_selected.score(X_test_selected, y_test)
print("Accuracy on test data:", accuracy)
# Out:
# Cross-validation scores: [1. 1. 1. 1. 1.]
# Mean accuracy: 1.0
# Accuracy on test data: 1.0

# %%
from sklearn.svm import SVC

# Define a new SVC classifier
clf_selected_svc = SVC()

# Perform cross-validation
cv_scores_svc = cross_val_score(clf_selected_svc, X_train_selected, y_train, cv=k_fold, scoring='accuracy')

# Print the cross-validation scores for SVC
print("Cross-validation scores for SVC:", cv_scores_svc)
print("Mean accuracy for SVC:", np.mean(cv_scores_svc))

# Train the SVC classifier on the full training data
clf_selected_svc.fit(X_train_selected, y_train)

# Evaluate the classifier on the test data
accuracy_svc = clf_selected_svc.score(X_test_selected, y_test)
print("Accuracy on test data for SVC:", accuracy_svc)
# Out:
# Cross-validation scores for SVC: [1. 1. 1. 1. 1.]
# Mean accuracy for SVC: 1.0
# Accuracy on test data for SVC: 1.0

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict the labels for the test data
y_pred = clf_selected_svc.predict(X_test_selected)

# Generate the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap="YlGnBu", fmt="d", xticklabels=['Resting State', 'Task State'], yticklabels=['Resting State', 'Task State'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for SVC Classifier on Test Data')
plt.savefig('confusion_matrix_heatmap.jpeg')  # Save the heatmap as an image
plt.show()

# %%
from sklearn.metrics import classification_report

# Train the classifier on the full training data
clf_selected_svc.fit(X_train_selected, y_train)

# Predict labels for test data
y_pred = clf_selected_svc.predict(X_test_selected)

# Print classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         5
#          1.0       1.00      1.00      1.00         2
#
#     accuracy                           1.00         7
#    macro avg       1.00      1.00      1.00         7
# weighted avg       1.00      1.00      1.00         7

# %%
import numpy as np
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# Combine PSD and ERP features for resting state
resting_state_features = np.concatenate((usable_features_psd_healthy_rs, features_erp_healthy_rs), axis=2)

# Combine PSD and ERP features for movie state
movie_state_features = np.concatenate((usable_features_psd_ms_healthy, features_erp_healthy_ms), axis=2)

# Combine the labels
resting_state_labels = np.zeros(resting_state_features.shape[0])
movie_state_labels = np.ones(movie_state_features.shape[0])

# Combine the features and labels
all_features = np.concatenate((resting_state_features, movie_state_features), axis=0)
all_labels = np.concatenate((resting_state_labels, movie_state_labels), axis=0)


indices = np.arange(all_features.shape[0])
np.random.shuffle(indices)

shuffled_features = all_features[indices]
shuffled_labels = all_labels[indices]
n_samples, n_channels, n_features = shuffled_features.shape
X_train = shuffled_features.reshape(n_samples, -1)
print("crude training data shape")
print(X_train.shape)

# Convert to float to handle potential non-numeric data
X_train = X_train.astype(float)
nan_indices = np.isnan(X_train).any(axis=0)
print("indices of nan values")
print(nan_indices.shape)
X_train1 = X_train[:, ~nan_indices]
print("Shape of train_healthy_selected_features_rsec after removing NaN columns:", X_train1.shape)
from sklearn.metrics import make_scorer, f1_score, roc_auc_score

print("Shape of X_test after removing NaN columns:", shuffled_labels.shape)
X_train, X_test, y_train, y_test = train_test_split(X_train1, shuffled_labels, test_size=0.2, random_state=42)


print("shape of train and test features")
print(X_train.shape)
print(X_test.shape)

# from sklearn.linear_model import LassoCV

# # Create the LASSO model
# lasso = LassoCV(cv=5)

# # Use SelectFromModel for feature selection
# sfm = SelectFromModel(lasso)
# X_train_selected = sfm.fit_transform(X_train, y_train)

# # Print the selected features
# print("Shape of selected features:", X_train_selected.shape)
# # Use SelectFromModel to select features for test data
# X_test_selected = sfm.transform(X_test)

# # Print the selected features for test data
# print("Shape of selected test features:", X_test_selected.shape)
# Out:
# crude training data shape
# (32, 1734)
# indices of nan values
# (1734,)
# Shape of train_healthy_selected_features_rsec after removing NaN columns: (32, 1728)
# Shape of X_test after removing NaN columns: (32,)
# shape of train and test features
# (25, 1728)
# (7, 1728)

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold

# Define the k-fold cross-validation
k_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Define a new Random Forest classifier
clf_selected = RandomForestClassifier()

# Perform cross-validation
cv_scores = cross_val_score(clf_selected, X_train, y_train, cv=k_fold, scoring='accuracy')

# Print the cross-validation scores
print("Cross-validation scores:", cv_scores)
print("Mean accuracy:", np.mean(cv_scores))

# Train the classifier on the full training data
clf_selected.fit(X_train, y_train)

# Evaluate the classifier on the test data
accuracy = clf_selected.score(X_test, y_test)
print("Accuracy on test data:", accuracy)
# Out:
# Cross-validation scores: [1. 1. 1. 1. 1.]
# Mean accuracy: 1.0
# Accuracy on test data: 1.0

# %%
y_test
# Out:
# array([1., 1., 0., 0., 0., 0., 0.])

# %%
from sklearn.metrics import classification_report

# Train the classifier on the full training data
clf_selected.fit(X_train, y_train)

# Predict labels for test data
y_pred = clf_selected.predict(X_test)

# Print classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         3
#          1.0       1.00      1.00      1.00         4
#
#     accuracy                           1.00         7
#    macro avg       1.00      1.00      1.00         7
# weighted avg       1.00      1.00      1.00         7

# %% [markdown]
# # binary classification: MCI subjects resting state vs MCI subjects task state

# %%
plt.close()

# %%
import numpy as np
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.metrics import classification_report
resting_state_features = np.concatenate((usable_features_psd_mci_rs, features_erp_mci_rs), axis=2)

# Combine PSD and ERP features for movie state
movie_state_features = np.concatenate((usable_features_psd_ms_mci, features_erp_mci_ms), axis=2)

# Combine the labels
resting_state_labels = np.zeros(resting_state_features.shape[0])
movie_state_labels = np.ones(movie_state_features.shape[0])

# Combine the features and labels
all_features = np.concatenate((resting_state_features, movie_state_features), axis=0)
all_labels = np.concatenate((resting_state_labels, movie_state_labels), axis=0)


indices = np.arange(all_features.shape[0])
np.random.shuffle(indices)

shuffled_features = all_features[indices]
shuffled_labels = all_labels[indices]
n_samples, n_channels, n_features = shuffled_features.shape
X_train = shuffled_features.reshape(n_samples, -1)
print("crude training data shape")
print(X_train.shape)

# Convert to float to handle potential non-numeric data
X_train = X_train.astype(float)
nan_indices = np.isnan(X_train).any(axis=0)
print("indices of nan values")
print(nan_indices.shape)
X_train1 = X_train[:, ~nan_indices]
print("Shape of train_healthy_selected_features_rsec after removing NaN columns:", X_train1.shape)
from sklearn.metrics import make_scorer, f1_score, roc_auc_score


# Define the number of repetitions for train/test splitting and evaluation
n_repeats = 10

# Lists to store metrics for each repetition
accuracy_scores = []
precision_0_scores = []
precision_1_scores = []
recall_0_scores = []
recall_1_scores = []
f1_0_scores = []
f1_1_scores = []
mavg_precision_scores=[]
mavg_recall_scores=[]
mavg_f1_scores=[]
wavg_precision_scores=[]
wavg_recall_scores=[]
wavg_f1_scores=[]
for _ in range(n_repeats):
    # Split data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_train1, shuffled_labels, test_size=0.2, random_state=None)

    print("shape of train and test features")
    print(X_train.shape)
    print(X_test.shape)

    from sklearn.linear_model import LassoCV

    # Create the LASSO model
    lasso = LassoCV(cv=3)

    # Use SelectFromModel for feature selection
    sfm = SelectFromModel(lasso)
    X_train_selected = sfm.fit_transform(X_train, y_train)

    # Print the selected features
    print("Shape of selected features:", X_train_selected.shape)
    # Use SelectFromModel to select features for test data
    X_test_selected = sfm.transform(X_test)
    # Print the selected features for test data
    print("Shape of selected test features:", X_test_selected.shape)
    
    # Define the k-fold cross-validation
    k_fold = StratifiedKFold(n_splits=3, shuffle=True, random_state=None)

    # Define a new Random Forest classifier
    clf_selected = RandomForestClassifier()

    # Perform cross-validation
    cv_scores = cross_val_score(clf_selected, X_train_selected, y_train, cv=k_fold, scoring='accuracy')

    # Train the classifier on the full training data
    clf_selected.fit(X_train_selected, y_train)
    
    from sklearn.metrics import classification_report

    # Predict labels for test data
    y_pred = clf_selected.predict(X_test_selected)

    # Calculate and store metrics
    report = classification_report(y_test, y_pred, output_dict=True)
    print(report)
    
    accuracy_scores.append(report['accuracy'])
    mavg_precision_scores.append(report['macro avg']['precision'])
    mavg_recall_scores.append(report['macro avg']['recall'])
    mavg_f1_scores.append(report['macro avg']['f1-score'])
    wavg_precision_scores.append(report['weighted avg']['precision'])
    wavg_recall_scores.append(report['weighted avg']['recall'])
    wavg_f1_scores.append(report['weighted avg']['f1-score'])
    # Check if both classes are present in the testing data
    if '0.0' in report:
        precision_0_scores.append(report['0.0']['precision'])
        recall_0_scores.append(report['0.0']['recall'])
        f1_0_scores.append(report['0.0']['f1-score'])
       
    if '1.0' in report:
        precision_1_scores.append(report['1.0']['precision'])
        recall_1_scores.append(report['1.0']['recall'])
        f1_1_scores.append(report['1.0']['f1-score'])

# Print average metrics and standard deviations
print("Accuracy: {:.2f} ± {:.2f}".format(np.mean(accuracy_scores), np.std(accuracy_scores)))
print("Precision (class 0): {:.2f} ± {:.2f}".format(np.mean(precision_0_scores), np.std(precision_0_scores)))
print("Precision (class 1): {:.2f} ± {:.2f}".format(np.mean(precision_1_scores), np.std(precision_1_scores)))
print("Recall (class 0): {:.2f} ± {:.2f}".format(np.mean(recall_0_scores), np.std(recall_0_scores)))
print("Recall (class 1): {:.2f} ± {:.2f}".format(np.mean(recall_1_scores), np.std(recall_1_scores)))
print("F1-score (class 0): {:.2f} ± {:.2f}".format(np.mean(f1_0_scores), np.std(f1_0_scores)))
print("F1-score (class 1): {:.2f} ± {:.2f}".format(np.mean(f1_1_scores), np.std(f1_1_scores)))
print("Macro avg precision: {:.2f} ± {:.2f}".format(np.mean(mavg_precision_scores), np.std(mavg_precision_scores)))
print("Macro avg recall: {:.2f} ± {:.2f}".format(np.mean(mavg_recall_scores), np.std(mavg_recall_scores)))
print("Macro avg f1-score: {:.2f} ± {:.2f}".format(np.mean(mavg_f1_scores), np.std(mavg_f1_scores)))
print("Weighted avg precision: {:.2f} ± {:.2f}".format(np.mean(wavg_precision_scores), np.std(wavg_precision_scores)))
print("weighted avg recall: {:.2f} ± {:.2f}".format(np.mean(wavg_recall_scores), np.std(wavg_recall_scores)))
print("weighted avg f1-score: {:.2f} ± {:.2f}".format(np.mean(wavg_f1_scores), np.std(wavg_f1_scores)))
# Out:
# crude training data shape
# (9, 1734)
# indices of nan values
# (1734,)
# Shape of train_healthy_selected_features_rsec after removing NaN columns: (9, 1734)
# shape of train and test features
# (7, 1734)
# (2, 1734)
# Shape of selected features: (7, 4)
# Shape of selected test features: (2, 4)
# C:\Users\stuti\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=3.
#   warnings.warn(
# C:\Users\stuti\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
import numpy as np
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# Combine PSD and ERP features for resting state
resting_state_features = np.concatenate((usable_features_psd_mci_rs, features_erp_mci_rs), axis=2)

# Combine PSD and ERP features for movie state
movie_state_features = np.concatenate((usable_features_psd_ms_mci, features_erp_mci_ms), axis=2)

# Combine the labels
resting_state_labels = np.zeros(resting_state_features.shape[0])
movie_state_labels = np.ones(movie_state_features.shape[0])

# Combine the features and labels
all_features = np.concatenate((resting_state_features, movie_state_features), axis=0)
all_labels = np.concatenate((resting_state_labels, movie_state_labels), axis=0)

# %%
all_features.shape
print(resting_state_features.shape)
print(movie_state_features.shape)
print(all_labels.shape)
# Out:
# (4, 102, 17)
# (5, 102, 17)
# (9,)

# %%
import numpy as np
import pandas as pd

# Reshape all_features
reshaped_features = all_features.reshape(all_features.shape[0], -1)  # Flatten the last two dimensions
print(reshaped_features.shape)
# Add labels as an additional column
features_with_labels = np.column_stack((reshaped_features, all_labels.reshape(-1, 1)))

# Convert to DataFrame
df = pd.DataFrame(features_with_labels)

# Save to CSV
df.to_csv('binary_class_MCI_rs_vs_ts.csv', index=False)
# Out:
# (9, 1734)

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('binary_class_MCI_rs_vs_ts.csv')

# Define column names
channels = ['MEG0112+0113',
 'MEG0122+0123',
 'MEG0132+0133',
 'MEG0142+0143',
 'MEG0212+0213',
 'MEG0222+0223',
 'MEG0232+0233',
 'MEG0242+0243',
 'MEG0312+0313',
 'MEG0322+0323',
 'MEG0332+0333',
 'MEG0342+0343',
 'MEG0412+0413',
 'MEG0422+0423',
 'MEG0432+0433',
 'MEG0442+0443',
 'MEG0512+0513',
 'MEG0522+0523',
 'MEG0532+0533',
 'MEG0542+0543',
 'MEG0612+0613',
 'MEG0622+0623',
 'MEG0632+0633',
 'MEG0642+0643',
 'MEG0712+0713',
 'MEG0722+0723',
 'MEG0732+0733',
 'MEG0742+0743',
 'MEG0812+0813',
 'MEG0822+0823',
 'MEG0912+0913',
 'MEG0922+0923',
 'MEG0932+0933',
 'MEG0942+0943',
 'MEG1012+1013',
 'MEG1022+1023',
 'MEG1032+1033',
 'MEG1042+1043',
 'MEG1112+1113',
 'MEG1122+1123',
 'MEG1132+1133',
 'MEG1142+1143',
 'MEG1212+1213',
 'MEG1222+1223',
 'MEG1232+1233',
 'MEG1242+1243',
 'MEG1312+1313',
 'MEG1322+1323',
 'MEG1332+1333',
 'MEG1342+1343',
 'MEG1412+1413',
 'MEG1422+1423',
 'MEG1432+1433',
 'MEG1442+1443',
 'MEG1512+1513',
 'MEG1522+1523',
 'MEG1532+1533',
 'MEG1542+1543',
 'MEG1612+1613',
 'MEG1622+1623',
 'MEG1632+1633',
 'MEG1642+1643',
 'MEG1712+1713',
 'MEG1722+1723',
 'MEG1732+1733',
 'MEG1742+1743',
 'MEG1812+1813',
 'MEG1822+1823',
 'MEG1832+1833',
 'MEG1842+1843',
 'MEG1912+1913',
 'MEG1922+1923',
 'MEG1932+1933',
 'MEG1942+1943',
 'MEG2012+2013',
 'MEG2022+2023',
 'MEG2032+2033',
 'MEG2042+2043',
 'MEG2112+2113',
 'MEG2122+2123',
 'MEG2132+2133',
 'MEG2142+2143',
 'MEG2212+2213',
 'MEG2222+2223',
 'MEG2232+2233',
 'MEG2242+2243',
 'MEG2312+2313',
 'MEG2322+2323',
 'MEG2332+2333',
 'MEG2342+2343',
 'MEG2412+2413',
 'MEG2422+2423',
 'MEG2432+2433',
 'MEG2442+2443',
 'MEG2512+2513',
 'MEG2522+2523',
 'MEG2532+2533',
 'MEG2542+2543',
 'MEG2612+2613',
 'MEG2622+2623',
 'MEG2632+2633',
 'MEG2642+2643']
print(len(channels))
features = ['band_power_alpha', 'band_power_beta', 'spectral_entropy_alpha', 'spectral_entropy_beta',
            'peak_amplitude', 'latency', 'auc_value', 'slope', 'peak_to_peak_amplitude',
            'mean_absolute_amplitude', 'rms_amplitude', 'std_dev', 'skewness', 'kurtosis_val',
            'zero_crossings', 'aar', 'zork']

# Generate column names
column_names = [f'Channel {channel_idx} {feature}' for channel_idx in range(1, 103) for feature in features]
# Add "labels" column name
column_names.append("labels")
# Assign column names to DataFrame
df.columns = column_names

# Save DataFrame to CSV
df.to_csv('features_and_labels_with_names.csv', index=False)
# Out:
# 102

# %%
import numpy as np
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# Combine PSD and ERP features for resting state
resting_state_features = np.concatenate((usable_features_psd_mci_rs, features_erp_mci_rs), axis=2)

# Combine PSD and ERP features for movie state
movie_state_features = np.concatenate((usable_features_psd_ms_mci, features_erp_mci_ms), axis=2)

# Combine the labels
resting_state_labels = np.zeros(resting_state_features.shape[0])
movie_state_labels = np.ones(movie_state_features.shape[0])

# Combine the features and labels
all_features = np.concatenate((resting_state_features, movie_state_features), axis=0)
all_labels = np.concatenate((resting_state_labels, movie_state_labels), axis=0)


indices = np.arange(all_features.shape[0])
np.random.shuffle(indices)

shuffled_features = all_features[indices]
shuffled_labels = all_labels[indices]


# Reshape the features for Random Forest
n_samples, n_channels, n_features = shuffled_features.shape
X_train = shuffled_features.reshape(n_samples, -1)
print(X_train.shape)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_train, shuffled_labels, test_size=0.2, random_state=42)



from sklearn.linear_model import LassoCV

# Create the LASSO model
lasso = LassoCV(cv=5)

# Use SelectFromModel for feature selection
sfm = SelectFromModel(lasso)
X_train_selected = sfm.fit_transform(X_train, y_train)

# Print the selected features
print("Shape of selected features:", X_train_selected.shape)
# Use SelectFromModel to select features for test data
X_test_selected = sfm.transform(X_test)

# Print the selected features for test data
print("Shape of selected test features:", X_test_selected.shape)
# Out:
# (9, 1734)
# Shape of selected features: (7, 3)
# Shape of selected test features: (2, 3)

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold

# Define the k-fold cross-validation
k_fold = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Define a new Random Forest classifier
clf_selected = RandomForestClassifier()

# Perform cross-validation
cv_scores = cross_val_score(clf_selected, X_train_selected, y_train, cv=k_fold, scoring='accuracy')

# Print the cross-validation scores
print("Cross-validation scores:", cv_scores)
print("Mean accuracy:", np.mean(cv_scores))

# Train the classifier on the full training data
clf_selected.fit(X_train_selected, y_train)

# Evaluate the classifier on the test data
accuracy = clf_selected.score(X_test_selected, y_test)
print("Accuracy on test data:", accuracy)
# Out:
# Cross-validation scores: [1.  0.5 1. ]
# Mean accuracy: 0.8333333333333334
# Accuracy on test data: 1.0

# %%
from sklearn.metrics import classification_report

# Train the classifier on the full training data
clf_selected.fit(X_train_selected, y_train)

# Predict labels for test data
y_pred = clf_selected.predict(X_test_selected)

# Print classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LassoCV
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split

# Your feature selection and data splitting code

# Define the k-fold cross-validation
k_fold = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Define a new Random Forest classifier
clf_selected = RandomForestClassifier()

# Perform cross-validation
cv_scores = cross_val_score(clf_selected, X_train_selected, y_train, cv=k_fold, scoring='accuracy')

# Print the cross-validation scores
print("Cross-validation scores:", cv_scores)
print("Mean accuracy:", np.mean(cv_scores))

# Plotting heatmap
sns.heatmap(np.array(cv_scores).reshape(1, -1), annot=True, cmap="YlGnBu", fmt=".3f", cbar=False)
plt.title("Cross-validation scores")
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.show()
# Out:
# Cross-validation scores: [1.  0.5 1. ]
# Mean accuracy: 0.8333333333333334

# %%
import numpy as np
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# Combine PSD and ERP features for resting state
resting_state_features = np.concatenate((usable_features_psd_mci_rs, features_erp_mci_rs), axis=2)

# Combine PSD and ERP features for movie state
movie_state_features = np.concatenate((usable_features_psd_ms_mci, features_erp_mci_ms), axis=2)

# Combine the labels
resting_state_labels = np.zeros(resting_state_features.shape[0])
movie_state_labels = np.ones(movie_state_features.shape[0])

# Combine the features and labels
all_features = np.concatenate((resting_state_features, movie_state_features), axis=0)
all_labels = np.concatenate((resting_state_labels, movie_state_labels), axis=0)


indices = np.arange(all_features.shape[0])
np.random.shuffle(indices)

shuffled_features = all_features[indices]
shuffled_labels = all_labels[indices]


# Reshape the features for Random Forest
n_samples, n_channels, n_features = shuffled_features.shape
X_train = shuffled_features.reshape(n_samples, -1)
print(X_train.shape)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_train, shuffled_labels, test_size=0.2, random_state=42)




# Create a Random Forest classifier
clf = RandomForestClassifier()

# Use SelectFromModel for feature selection
sfm = SelectFromModel(clf)
X_train_selected = sfm.fit_transform(X_train, y_train)

# Print the selected features
print("Shape of selected features:", X_train_selected.shape)

# Print the selected features
print("Shape of selected features:", X_train_selected.shape)
# Use SelectFromModel to select features for test data
X_test_selected = sfm.transform(X_test)

# Print the selected features for test data
print("Shape of selected test features:", X_test_selected.shape)
# Out:
# (9, 1734)
# Shape of selected features: (7, 91)
# Shape of selected features: (7, 91)
# Shape of selected test features: (2, 91)

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold

# Define the k-fold cross-validation
k_fold = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Define a new Random Forest classifier
clf_selected = RandomForestClassifier()

# Perform cross-validation
cv_scores = cross_val_score(clf_selected, X_train_selected, y_train, cv=k_fold, scoring='accuracy')

# Print the cross-validation scores
print("Cross-validation scores:", cv_scores)
print("Mean accuracy:", np.mean(cv_scores))

# Train the classifier on the full training data
clf_selected.fit(X_train_selected, y_train)

# Evaluate the classifier on the test data
accuracy = clf_selected.score(X_test_selected, y_test)
print("Accuracy on test data:", accuracy)
# Out:
# Cross-validation scores: [1. 1. 1.]
# Mean accuracy: 1.0
# Accuracy on test data: 1.0

# %%
from sklearn.svm import SVC

# Define a new SVC classifier
clf_selected_svc = SVC()

# Perform cross-validation
cv_scores_svc = cross_val_score(clf_selected_svc, X_train_selected, y_train, cv=k_fold, scoring='accuracy')

# Print the cross-validation scores for SVC
print("Cross-validation scores for SVC:", cv_scores_svc)
print("Mean accuracy for SVC:", np.mean(cv_scores_svc))

# Train the SVC classifier on the full training data
clf_selected_svc.fit(X_train_selected, y_train)

# Evaluate the classifier on the test data
accuracy_svc = clf_selected_svc.score(X_test_selected, y_test)
print("Accuracy on test data for SVC:", accuracy_svc)
# Out:
# Cross-validation scores for SVC: [1. 1. 1.]
# Mean accuracy for SVC: 1.0
# Accuracy on test data for SVC: 0.5

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict the labels for the test data
y_pred = clf_selected_svc.predict(X_test_selected)

# Generate the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap="YlGnBu", fmt="d", xticklabels=['Resting State', 'Task State'], yticklabels=['Resting State', 'Task State'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for SVC Classifier on Test Data')
plt.savefig('confusion_matrix_heatmap_mci.jpeg')  # Save the heatmap as an image
plt.show()

# %%
from sklearn.metrics import classification_report

# Train the classifier on the full training data
clf_selected_svc.fit(X_train_selected, y_train)

# Predict labels for test data
y_pred = clf_selected_svc.predict(X_test_selected)

# Print classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
# C:\Users\stuti\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\stuti\AppData\Roaming\Python\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
plt.close()

# %%
# features_erp_healthy_rs[:,:,1]

# %%
# features_erp_healthy_ts[:,:,1]

# %% [markdown]
# ## features aggregation for visulaisation of topoplots

# %%
import os
import glob


# Construct the path to the target folder
folder_path = "D:\internship_ulster_university\combined_grad_movie_state"

# Move into the target folder
os.chdir(folder_path)

# Select all files ending with ".mat"
matfiles_ms = glob.glob("*.mat")

# Print the list of selected files
print("Selected .mat files:")
for file in matfiles_ms:
    print(file)
# Out:
# Selected .mat files:
# Combined_grad_AD001_MoviesWatching.mat
# Combined_grad_AD002_MoviesWatching.mat
# Combined_grad_AD003_MoviesWatching.mat
# Combined_grad_AD004_MoviesWatching.mat
# Combined_grad_AD006_MoviesWatching.mat
# Combined_grad_AD008_MoviesWatching.mat
# Combined_grad_AD010_MoviesWatching.mat
# Combined_grad_AD011_MoviesWatching.mat
# Combined_grad_AD012_MoviesWatching.mat
# Combined_grad_AD013_MoviesWatching.mat
# Combined_grad_AD014_MoviesWatching.mat
# Combined_grad_AD015_MoviesWatching.mat
# Combined_grad_AD016_MoviesWatching.mat
# Combined_grad_AD017_MoviesWatching.mat
# Combined_grad_AD018_MoviesWatching.mat
# Combined_grad_AD020_MoviesWatching.mat
# Combined_grad_AD026_MoviesWatching.mat
# Combined_grad_AD027_MoviesWatching.mat
# Combined_grad_AD028_MoviesWatching.mat
# Combined_grad_AD030_MoviesWatching.mat
# Combined_grad_AD031_MoviesWatching.mat

# %%
trial_counts_movie_state=[]
num_trials=0
for subject in range(len(matfiles_ms)):
    name=matfiles_ms[subject]
    print(name)
    dat = mat73.loadmat(matfiles_ms[subject])
    for key, value in dat.items():
        print(key)
    data=dat['MEG']
    for key, value in data.items():
        print(key)
    new=data['trial']
    print('new shape')
    print(len(new))
    data2=np.asarray(new)
    print(data2.shape[0])
    trial_counts_movie_state.append(data2.shape[0])
    num_trials+=data2.shape[0]
# Out:
# Combined_grad_AD001_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 52
# 52
# Combined_grad_AD002_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 51
# 51
# Combined_grad_AD003_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 52
# 52
# Combined_grad_AD004_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49
# Combined_grad_AD006_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 48
# 48
# Combined_grad_AD008_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 49
# 49
# Combined_grad_AD010_MoviesWatching.mat
# MEG
# cfg
# fsample
# grad
# hdr
# label
# sampleinfo
# time
# trial
# new shape
# 50
# 50
# Combined_grad_AD011_MoviesWatching.mat
# MEG
# cfg
# ...

# %%
num_trials
# Out:
# 1041

# %%
print(trial_counts_movie_state)
print(num_trials)
# Out:
# [52, 51, 52, 49, 48, 49, 50, 50, 49, 49, 50, 50, 49, 49, 49, 49, 50, 49, 49, 49, 49]
# 1041

# %%
import numpy as np
import pandas as pd

trial_data=[]
num_trials_movie_state_healthy=0
start=0
raw_list_mean_ms_healthy = []
for subject, trials in enumerate(trial_counts_movie_state[:16]):
    print('subject idx is')
    print(subject)
    print("trials is")
    print(trials)
    name=matfiles_ms[subject]
    print(name)
    dat = mat73.loadmat(matfiles_ms[subject])
    data=dat['MEG']
    new=data['trial']
    data2=np.asarray(new)
    print(data2.shape)
    num_trials_movie_state_healthy+=data2.shape[0]
    average_data_ms_healthy = np.mean(data2[:,:102,:], axis=0)
    print("data averaged for all trials of 1 subject")
    print(average_data_ms_healthy.shape)
    raw = mne.io.RawArray(average_data_ms_healthy, info)
    raw_list_mean_ms_healthy.append(raw)
    print(len(raw_list_mean_ms_healthy))
# Out:
# subject idx is
# 0
# trials is
# 52
# Combined_grad_AD001_MoviesWatching.mat
# (52, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 1
# subject idx is
# 1
# trials is
# 51
# Combined_grad_AD002_MoviesWatching.mat
# (51, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 2
# subject idx is
# 2
# trials is
# 52
# Combined_grad_AD003_MoviesWatching.mat
# (52, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 3
# subject idx is
# 3
# trials is
# 49
# Combined_grad_AD004_MoviesWatching.mat
# (49, 204, 10000)
# ...

# %%
print(len( raw_list_mean_ms_healthy))
# Out:
# 16

# %%
import numpy as np
import pandas as pd
trial_data=[]
num_trials_movie_state_mci=0
start=0
raw_list_mean_ms_mci = []
trial_counts_movie_state_mci=trial_counts_movie_state[16:20]

for subject in range(16,21):
    print('subject idx is')
    print(subject)
    name=matfiles_ms[subject]
    print(name)
    dat = mat73.loadmat(matfiles_ms[subject])
    data=dat['MEG']
    new=data['trial']
    data2=np.asarray(new)
    print(data2.shape)
    num_trials_movie_state_mci+=data2.shape[0]
    average_data_ms_mci = np.mean(data2[:,:102,:], axis=0)
    print("data averaged for all trials of 1 subject")
    print(average_data_ms_mci.shape)
    raw = mne.io.RawArray(average_data_ms_mci, info)
    raw_list_mean_ms_mci.append(raw)
    print(len(raw_list_mean_ms_mci))
# Out:
# subject idx is
# 16
# Combined_grad_AD026_MoviesWatching.mat
# (50, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 1
# subject idx is
# 17
# Combined_grad_AD027_MoviesWatching.mat
# (49, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 2
# subject idx is
# 18
# Combined_grad_AD028_MoviesWatching.mat
# (49, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# Creating RawArray with float64 data, n_channels=102, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...     9.999 secs
# Ready.
# 3
# subject idx is
# 19
# Combined_grad_AD030_MoviesWatching.mat
# (49, 204, 10000)
# data averaged for all trials of 1 subject
# (102, 10000)
# ...

# %%
len(raw_list_mean_ms_mci)
# Out:
# 5

# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import kurtosis

features_psd_ms_healthy = []
for raw in raw_list_mean_ms_healthy:
    # Compute PSD
    psd_spectrum_ms_healthy = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
    #psd_spectrum_ms_healthy = raw.compute_psd(method='multitaper', fmin=0, fmax=40, tmin=None, tmax=None)
    print(psd_spectrum_ms_healthy.shape)
    print(psd_spectrum_ms_healthy.freqs)
    features=[]
    for idx, ch_name in enumerate(list_1):
        psd_data = psd_spectrum_ms_healthy[idx]  # PSD data for the current channel
        freqs = psd_spectrum_ms_healthy.freqs  # Frequency values
        band_power_alpha = np.sum(psd_data[:,(freqs >= 8) & (freqs <= 13)])  # Alpha band
        band_power_beta = np.sum(psd_data[:,(freqs >= 13) & (freqs <= 30)])  # Beta band
        channel_features = [ band_power_alpha, band_power_beta]
        features.append(channel_features)    
    features_psd_ms_healthy.append(features) 
features_psd_ms_healthy = np.array(features_psd_ms_healthy)
# Out:
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# ...

# %%
# import pickle
# with open('features_psd_ms_healthy.pkl', 'wb') as file: 
#     pickle.dump(features_psd_ms_healthy, file)

# %%
# Construct the path to the target folder
folder_path = "D:\internship_ulster_university\combined_grad_movie_state"

# Move into the target folder
os.chdir(folder_path)

# %%
import pickle
with open('features_psd_ms_healthy.csv', 'wb') as file: 
    pickle.dump(features_psd_ms_healthy, file)

# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import kurtosis

features_psd_ms_mci = []
for raw in raw_list_mean_ms_mci:
    # Compute PSD
    psd_spectrum_ms_mci = raw.compute_psd(method='welch', fmin=4, fmax=40, tmin=None, tmax=None,n_fft=110 )
  
  #  psd_spectrum_ms_mci = raw.compute_psd(method='multitaper', fmin=0, fmax=40, tmin=None, tmax=None)
    print(psd_spectrum_ms_mci.shape)
    print(psd_spectrum_ms_mci.freqs)
    features=[]
    for idx, ch_name in enumerate(list_1):
        psd_data = psd_spectrum_ms_mci[idx]  # PSD data for the current channel
        freqs = psd_spectrum_ms_mci.freqs  # Frequency values
        band_power_alpha = np.sum(psd_data[:,(freqs >= 8) & (freqs <= 13)])  # Alpha band
        band_power_beta = np.sum(psd_data[:,(freqs >= 13) & (freqs <= 30)])  # Beta band
        channel_features = [ band_power_alpha, band_power_beta]
        features.append(channel_features)    
    features_psd_ms_mci.append(features) 
features_psd_ms_mci = np.array(features_psd_ms_mci)
# Out:
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]
# Effective window size : 0.110 (s)
# (102, 4)
# [ 9.09090909 18.18181818 27.27272727 36.36363636]

# %%
import pickle
with open('features_psd_ms_mci.pkl', 'wb') as file: 
    pickle.dump(features_psd_ms_mci, file)

# %%
# import pickle
# with open('features_psd_ms_mci.csv', 'wb') as file: 
#     pickle.dump(features_psd_ms_mci, file)

# %%
features_psd_ms_mci[:,:,0]
# Out:
# array([[1.74751861e-26, 1.96261082e-26, 1.63069965e-26, 2.30743195e-26,
#         2.11130029e-26, 9.68933698e-27, 1.02163521e-26, 1.99654948e-26,
#         6.88287562e-27, 5.76188013e-27, 3.81961301e-27, 1.45988816e-26,
#         4.58835518e-27, 3.00608590e-27, 3.16737189e-27, 5.19402333e-27,
#         4.46884682e-27, 2.94413376e-27, 2.26837370e-27, 3.13905585e-27,
#         2.45175615e-27, 2.88053871e-27, 2.40458333e-27, 2.83877446e-27,
#         2.34051627e-27, 2.53629811e-27, 2.31333738e-27, 1.97990314e-27,
#         3.34611103e-27, 2.16652144e-27, 3.86424067e-27, 4.54539814e-27,
#         3.29243290e-27, 2.22411414e-27, 2.37585653e-27, 2.42394928e-27,
#         3.07280574e-27, 2.80421840e-27, 3.82083095e-27, 5.26661576e-27,
#         4.53119262e-27, 3.13634081e-27, 5.62039739e-27, 9.64665085e-27,
#         6.29784972e-27, 4.16709388e-27, 7.66503673e-27, 1.20662803e-26,
#         1.13630428e-26, 6.84123080e-27, 1.10961877e-26, 8.39717561e-27,
# ...

# %%
features_psd_ms_healthy[:,:,0]
# Out:
# array([[2.15365221e-27, 3.31975879e-27, 3.21575457e-27, ...,
#         2.66687582e-27, 3.46827455e-27, 5.02735741e-27],
#        [2.21754776e-27, 4.72648784e-27, 5.48287125e-27, ...,
#         3.94868085e-27, 4.17783930e-27, 9.05433449e-27],
#        [1.13710249e-27, 2.12073589e-27, 2.01040135e-27, ...,
#         1.35618841e-27, 2.05268593e-27, 2.75509756e-27],
#        ...,
#        [1.62822578e-27, 4.24663353e-27, 5.01810051e-27, ...,
#         2.09398643e-27, 2.77780968e-27, 3.22560481e-27],
#        [1.40133597e-26, 1.90781682e-26, 1.64654574e-26, ...,
#         4.37950971e-27, 5.00912709e-27, 7.34165569e-27],
#        [8.97280143e-27, 4.46525339e-27, 5.46706825e-27, ...,
#         3.22556423e-27, 4.06674729e-27, 3.46846221e-27]])

# %%
# Construct the path to the target folder
folder_path = "D:\internship_ulster_university\preprocessed_filtered_eyes_closed"

# Move into the target folder
os.chdir(folder_path)
import pickle
with open('features_psd_rsec.pkl','rb') as file:
    usable_features_psd_rsec=pickle.load(file)

# %%
usable_features_psd_rsec.shape
# Out:
# (20, 102, 4)

# %%
features_psd_rsec_healthy=usable_features_psd_rsec[:16,:,:2]
print(features_psd_rsec_healthy.shape)
# Out:
# (16, 102, 2)

# %%
# Reshape to the desired shape
reshaped_features1 = features_psd_rsec_healthy.reshape(16, 102 * 2)

# %%
# import pandas as pd

# # Convert to DataFrame and save to CSV using pandas
# df = pd.DataFrame(reshaped_features1)
# df.to_csv('rsec_healthy_band_power_alpha_beta.csv', index=False)

# %%
features_psd_rsec_mci=usable_features_psd_rsec[16:,:,:2]
print(features_psd_rsec_mci.shape)
# Out:
# (4, 102, 2)

# %%
# Reshape to the desired shape
reshaped_features2 = features_psd_rsec_mci.reshape(4, 102 * 2)

# %%
# import pandas as pd

# # Convert to DataFrame and save to CSV using pandas
# df = pd.DataFrame(reshaped_features2)
# df.to_csv('rsec_mci_band_power_alpha_beta.csv', index=False)

# %%
# import pickle
# with open('features_psd_rsec_healthy.pkl', 'wb') as file: 
#     pickle.dump(features_psd_rsec_healthy, file)

# %%
# import pickle
# with open('features_psd_rsec_healthy.csv', 'wb') as file: 
#     pickle.dump(features_psd_rsec_healthy, file)

# %%
# import pickle
# with open('features_psd_rsec_mci.pkl', 'wb') as file: 
#     pickle.dump(features_psd_rsec_mci, file)

# %%
# import pickle
# with open('features_psd_rsec_mci.csv', 'wb') as file: 
#     pickle.dump(features_psd_rsec_mci, file)

# %%
# Construct the path to the target folder
folder_path = "D:\internship_ulster_university\preprocessed_filtered_eyes_open"

# Move into the target folder
os.chdir(folder_path)
import pickle
with open('features_psd_rseo.pkl','rb') as file:
    usable_features_psd_rseo=pickle.load(file)

# %%
usable_features_psd_rseo.shape
# Out:
# (21, 102, 4)

# %%
features_psd_rseo_healthy=usable_features_psd_rseo[:16,:,:2]
print(features_psd_rseo_healthy.shape)
# Out:
# (16, 102, 2)

# %%
# Reshape to the desired shape
reshaped_features3 = features_psd_rseo_healthy.reshape(16, 102 * 2)

# %%
# import pandas as pd

# # Convert to DataFrame and save to CSV using pandas
# df = pd.DataFrame(reshaped_features3)
# df.to_csv('rseo_healthy_band_power_alpha_beta.csv', index=False)

# %%
features_psd_rseo_mci=usable_features_psd_rseo[16:,:,:2]
print(features_psd_rseo_mci.shape)
# Out:
# (5, 102, 2)

# %%
# Reshape to the desired shape
reshaped_features4 = features_psd_rseo_mci.reshape(5, 102 * 2)

# %%
# import pandas as pd

# # Convert to DataFrame and save to CSV using pandas
# df = pd.DataFrame(reshaped_features4)
# df.to_csv('rseo_mci_band_power_alpha_beta.csv', index=False)

# %%
# import pickle
# with open('features_psd_rseo_healthy.pkl', 'wb') as file: 
#     pickle.dump(features_psd_rseo_healthy, file)

# %%
# import pickle
# with open('features_psd_rseo_healthy.csv', 'wb') as file: 
#     pickle.dump(features_psd_rseo_healthy, file)

# %%
# import pickle
# with open('features_psd_rseo_mci.pkl', 'wb') as file: 
#     pickle.dump(features_psd_rseo_mci, file)

# %%
# import pickle
# with open('features_psd_rseo_mci.csv', 'wb') as file: 
#     pickle.dump(features_psd_rseo_mci, file)

# %%
import os
# Construct the path to the target folder
folder_path = "D:\internship_ulster_university\preprocessed_filtered_1st_click"

# Move into the target folder
os.chdir(folder_path)
import pickle
with open('features_psd_1st_click.pkl','rb') as file:
    usable_features_psd_1st_click=pickle.load(file)

# %%
usable_features_psd_1st_click.shape
# Out:
# (21, 102, 4)

# %%
features_psd_1st_click_healthy=usable_features_psd_1st_click[:16,:,:2]
print(features_psd_1st_click_healthy.shape)
# Out:
# (16, 102, 2)

# %%
# Reshape to the desired shape
reshaped_features5 = features_psd_1st_click_healthy.reshape(16, 102 * 2)

# %%
# import pandas as pd

# # Convert to DataFrame and save to CSV using pandas
# df = pd.DataFrame(reshaped_features5)
# df.to_csv('1st_click_healthy_band_power_alpha_beta.csv', index=False)

# %%
features_psd_1st_click_mci=usable_features_psd_1st_click[16:,:,:2]
print(features_psd_1st_click_mci.shape)
# Out:
# (5, 102, 2)

# %%
# Reshape to the desired shape
reshaped_features6 = features_psd_1st_click_mci.reshape(5, 102 * 2)

# %%
# import pandas as pd

# # Convert to DataFrame and save to CSV using pandas
# df = pd.DataFrame(reshaped_features6)
# df.to_csv('1st_click_mci_band_power_alpha_beta.csv', index=False)

# %%
# import pickle
# with open('features_psd_1st_click_healthy.pkl', 'wb') as file: 
#     pickle.dump(features_psd_1st_click_healthy, file)

# %%
# import pickle
# with open('features_psd_1st_click_mci.pkl', 'wb') as file: 
#     pickle.dump(features_psd_1st_click_mci, file)

# %%
# Construct the path to the target folder
folder_path = "D:\internship_ulster_university\preprocessed_filtered_2nd_click"

# Move into the target folder
os.chdir(folder_path)
import pickle
with open('features_psd_2nd_click.pkl','rb') as file:
    usable_features_psd_2nd_click=pickle.load(file)

# %%
usable_features_psd_2nd_click.shape
# Out:
# (21, 102, 4)

# %%
features_psd_2nd_click_healthy=usable_features_psd_2nd_click[:16,:,:2]
print(features_psd_2nd_click_healthy.shape)
# Out:
# (16, 102, 2)

# %%
# Reshape to the desired shape
reshaped_features7 = features_psd_2nd_click_healthy.reshape(16, 102 * 2)

# %%
# import pandas as pd

# # Convert to DataFrame and save to CSV using pandas
# df = pd.DataFrame(reshaped_features7)
# df.to_csv('2nd_click_healthy_band_power_alpha_beta.csv', index=False)

# %%
features_psd_2nd_click_mci=usable_features_psd_2nd_click[16:,:,:2]
print(features_psd_2nd_click_mci.shape)
# Out:
# (5, 102, 2)

# %%
# Reshape to the desired shape
reshaped_features8 = features_psd_2nd_click_mci.reshape(5, 102 * 2)

# %%
# import pandas as pd

# # Convert to DataFrame and save to CSV using pandas
# df = pd.DataFrame(reshaped_features8)
# df.to_csv('2nd_click_mci_band_power_alpha_beta.csv', index=False)

# %%
# import pickle
# with open('features_psd_2nd_click_healthy.pkl', 'wb') as file: 
#     pickle.dump(features_psd_2nd_click_healthy, file)

# %%
# import pickle
# with open('features_psd_2nd_click_mci.pkl', 'wb') as file: 
#     pickle.dump(features_psd_2nd_click_mci, file)

# %%
print(features_psd_1st_click_healthy.shape)
print(features_psd_1st_click_mci.shape)
print(features_psd_2nd_click_healthy.shape)
print(features_psd_2nd_click_mci.shape)
# Out:
# (16, 102, 2)
# (5, 102, 2)
# (16, 102, 2)
# (5, 102, 2)

# %%
print(features_psd_rsec_healthy.shape)
print(features_psd_rsec_mci.shape)
print(features_psd_rseo_healthy.shape)
print(features_psd_rseo_mci.shape)
print(features_psd_ms_healthy.shape)
print(features_psd_ms_mci.shape)
# Out:
# (16, 102, 2)
# (4, 102, 2)
# (16, 102, 2)
# (5, 102, 2)
# (16, 102, 2)
# (5, 102, 2)

# %%
position
# Out:
# array([[-1.00075722e+01,  3.65128630e+00, -2.25105759e+00],
#        [-1.00621064e+01,  5.41282576e+00,  1.21426809e+00],
#        [-1.05140172e+01,  2.08403908e+00,  1.12193825e+00],
#        [-1.01240423e+01,  2.99298532e-01, -2.43275739e+00],
#        [-1.08367367e+01,  2.42531954e+00,  4.56424844e+00],
#        [-1.04351099e+01,  3.27754793e+00,  7.96055022e+00],
#        [-1.04496296e+01, -3.25349648e-01,  7.97673586e+00],
#        [-1.07277930e+01, -9.80692656e-01,  4.55195115e+00],
#        [-9.09741576e+00,  9.13935512e+00,  4.74954632e+00],
#        [-9.61617502e+00,  6.87580031e+00,  7.98214670e+00],
#        [-8.13470060e+00,  7.04733974e+00,  1.11388049e+01],
#        [-1.03150464e+01,  5.76595163e+00,  4.57486396e+00],
#        [-9.01232708e+00,  3.53965618e+00,  1.12300844e+01],
#        [-6.48532589e+00,  3.67729556e+00,  1.38783412e+01],
#        [-6.42388187e+00,  2.05244753e-01,  1.41232341e+01],
#        [-9.03684434e+00,  1.97289632e-02,  1.13746798e+01],
# ...

# %%
position_xy=position[:,:2]
print(position_xy)
# Out:
# [[-1.00075722e+01  3.65128630e+00]
#  [-1.00621064e+01  5.41282576e+00]
#  [-1.05140172e+01  2.08403908e+00]
#  [-1.01240423e+01  2.99298532e-01]
#  [-1.08367367e+01  2.42531954e+00]
#  [-1.04351099e+01  3.27754793e+00]
#  [-1.04496296e+01 -3.25349648e-01]
#  [-1.07277930e+01 -9.80692656e-01]
#  [-9.09741576e+00  9.13935512e+00]
#  [-9.61617502e+00  6.87580031e+00]
#  [-8.13470060e+00  7.04733974e+00]
#  [-1.03150464e+01  5.76595163e+00]
#  [-9.01232708e+00  3.53965618e+00]
#  [-6.48532589e+00  3.67729556e+00]
#  [-6.42388187e+00  2.05244753e-01]
#  [-9.03684434e+00  1.97289632e-02]
#  [-7.07210463e+00  1.19415687e+01]
#  [-4.16394793e+00  1.35577312e+01]
#  [-4.52085838e+00  1.23830239e+01]
#  [-7.70068027e+00  1.03274429e+01]
#  [-4.92502678e+00  1.01580182e+01]
#  [-1.46904798e+00  7.67545381e+00]
#  [-3.23796088e+00  4.23655394e+00]
#  [-5.06940022e+00  7.23435429e+00]
#  [-3.10327932e+00  8.92683020e-01]
#  [ 5.82680683e-01  1.10865396e+00]
#  [ 8.13844449e-01 -2.28044256e+00]
# ...

# %% [markdown]
# ## rsec healthy and mci alpha and beta plots

# %%
# Find the minimum and maximum values across both arrays
overall_min = min(features_psd_rsec_healthy.min(),features_psd_rseo_healthy.min(), features_psd_ms_healthy.min(),features_psd_1st_click_healthy.min(),features_psd_2nd_click_healthy.min(),
                  features_psd_rsec_mci.min(),features_psd_rseo_mci.min(), features_psd_ms_mci.min(),features_psd_1st_click_mci.min(),features_psd_2nd_click_mci.min())
overall_max = max(features_psd_rsec_healthy.max(),features_psd_rseo_healthy.max(), features_psd_ms_healthy.max(),features_psd_1st_click_healthy.max(),features_psd_2nd_click_healthy.max(),
                  features_psd_rsec_mci.max(),features_psd_rseo_mci.max(), features_psd_ms_mci.max(),features_psd_1st_click_mci.max(),features_psd_2nd_click_mci.max())

print(f"Overall Minimum: {overall_min}")
print(f"Overall Maximum: {overall_max}")
# Out:
# Overall Minimum: 0.0
# Overall Maximum: 4.419070986720331e-25

# %%
rsec_min=min(features_psd_rsec_healthy.min(),features_psd_rsec_mci.min())
rsec_max=max(features_psd_rsec_healthy.max(),features_psd_rsec_mci.max())
print("range of rsec")
print(f"rsec Minimum: {rsec_min}")
print(f"rsec Maximum: {rsec_max}")
# Out:
# range of rsec
# rsec Minimum: 0.0
# rsec Maximum: 4.419070986720331e-25

# %%
rseo_min=min(features_psd_rseo_healthy.min(),features_psd_rseo_mci.min())
rseo_max=max(features_psd_rseo_healthy.max(),features_psd_rseo_mci.max())
print("range of rseo")
print(f"rseo Minimum: {rseo_min}")
print(f"rseo Maximum: {rseo_max}")
# Out:
# range of rseo
# rseo Minimum: 0.0
# rseo Maximum: 3.2478105231807944e-25

# %%
ms_min=min(features_psd_ms_healthy.min(),features_psd_ms_mci.min())
ms_max=max(features_psd_ms_healthy.max(),features_psd_ms_mci.max())
print("range of ms")
print(f"ms Minimum: {ms_min}")
print(f"ms Maximum: {ms_max}")
# Out:
# range of ms
# ms Minimum: 0.0
# ms Maximum: 1.8886780059567125e-25

# %%
click_1_min=min(features_psd_1st_click_healthy.min(),features_psd_1st_click_mci.min())
click_1_max=max(features_psd_1st_click_healthy.max(),features_psd_1st_click_mci.max())
print("range of 1st_click")
print(f"1st_click Minimum: {click_1_min}")
print(f"1st_click Maximum: {click_1_max}")
# Out:
# range of 1st_click
# 1st_click Minimum: 0.0
# 1st_click Maximum: 1.9097354388257697e-25

# %%
click_2_min=min(features_psd_2nd_click_healthy.min(),features_psd_2nd_click_mci.min())
click_2_max=max(features_psd_2nd_click_healthy.max(),features_psd_2nd_click_mci.max())
print("range of 2st_click")
print(f"2st_click Minimum: {click_2_min}")
print(f"2st_click Maximum: {click_2_max}")
# Out:
# range of 2st_click
# 2st_click Minimum: 0.0
# 2st_click Maximum: 3.209288444642926e-25

# %%
# Define the data arrays
healthy_data_rsec = features_psd_rsec_healthy  # Shape: (16, 102, 2)
mci_data_rsec = features_psd_rsec_mci  # Shape: (16, 2, 102)

# Compute average power spectral densities
avg_healthy_alpha_rsec = np.mean(healthy_data_rsec[:, :, 0], axis=0)
avg_healthy_beta_rsec = np.mean(healthy_data_rsec[:, :, 1], axis=0)
avg_mci_alpha_rsec = np.mean(mci_data_rsec[:, :, 0], axis=0)
avg_mci_beta_rsec = np.mean(mci_data_rsec[:, :, 1], axis=0)


avg_healthy_alpha_rsec1 = avg_healthy_alpha_rsec.astype(float)
avg_healthy_beta_rsec1 = avg_healthy_beta_rsec.astype(float)
avg_mci_alpha_rsec1 = avg_mci_alpha_rsec.astype(float)
avg_mci_beta_rsec1 = avg_mci_beta_rsec.astype(float)

min_rsec=min(avg_healthy_alpha_rsec1.min(),avg_healthy_beta_rsec1.min(),avg_mci_alpha_rsec1.min(),avg_mci_beta_rsec1.min())
max_rsec=max(avg_healthy_alpha_rsec1.max(),avg_healthy_beta_rsec1.max(),avg_mci_alpha_rsec1.max(),avg_mci_beta_rsec1.max())
print("range of averaged rsec data")
print(f"rsec Minimum: {min_rsec}")
print(f"rsec Maximum: {max_rsec}")
# Out:
# range of averaged rsec data
# rsec Minimum: 6.3855618631731304e-27
# rsec Maximum: 1.2588654009589642e-25

# %%
# Define the data arrays
healthy_data_rseo = features_psd_rseo_healthy  # Shape: (16, 102, 2)
mci_data_rseo = features_psd_rseo_mci  # Shape: (16, 2, 102)

# Compute average power spectral densities
avg_healthy_alpha_rseo = np.mean(healthy_data_rseo[:, :, 0], axis=0)
avg_healthy_beta_rseo = np.mean(healthy_data_rseo[:, :, 1], axis=0)
avg_mci_alpha_rseo = np.mean(mci_data_rseo[:, :, 0], axis=0)
avg_mci_beta_rseo = np.mean(mci_data_rseo[:, :, 1], axis=0)


avg_healthy_alpha_rseo1 = avg_healthy_alpha_rseo.astype(float)
avg_healthy_beta_rseo1 = avg_healthy_beta_rseo.astype(float)
avg_mci_alpha_rseo1 = avg_mci_alpha_rseo.astype(float)
avg_mci_beta_rseo1 = avg_mci_beta_rseo.astype(float)

min_rseo=min(avg_healthy_alpha_rseo1.min(),avg_healthy_beta_rseo1.min(),avg_mci_alpha_rseo1.min(),avg_mci_beta_rseo1.min())
max_rseo=max(avg_healthy_alpha_rseo1.max(),avg_healthy_beta_rseo1.max(),avg_mci_alpha_rseo1.max(),avg_mci_beta_rseo1.max())
print("range of averaged rseo data")
print(f"rseo Minimum: {min_rseo}")
print(f"rseo Maximum: {max_rseo}")
# Out:
# range of averaged rseo data
# rseo Minimum: 6.671829062979368e-27
# rseo Maximum: 1.455226190209539e-25

# %%
# Define the data arrays
healthy_data_ms = features_psd_ms_healthy  # Shape: (16, 102, 2)
mci_data_ms = features_psd_ms_mci  # Shape: (16, 2, 102)

# Compute average power spectral densities
avg_healthy_alpha_ms = np.mean(healthy_data_ms[:, :, 0], axis=0)
avg_healthy_beta_ms = np.mean(healthy_data_ms[:, :, 1], axis=0)
avg_mci_alpha_ms = np.mean(mci_data_ms[:, :, 0], axis=0)
avg_mci_beta_ms = np.mean(mci_data_ms[:, :, 1], axis=0)


avg_healthy_alpha_ms1 = avg_healthy_alpha_ms.astype(float)
avg_healthy_beta_ms1 = avg_healthy_beta_ms.astype(float)
avg_mci_alpha_ms1 = avg_mci_alpha_ms.astype(float)
avg_mci_beta_ms1 = avg_mci_beta_ms.astype(float)

min_ms=min(avg_healthy_alpha_ms1.min(),avg_healthy_beta_ms1.min(),avg_mci_alpha_ms1.min(),avg_mci_beta_ms1.min())
max_ms=max(avg_healthy_alpha_ms1.max(),avg_healthy_beta_ms1.max(),avg_mci_alpha_ms1.max(),avg_mci_beta_ms1.max())
print("range of averaged ms data")
print(f"ms Minimum: {min_ms}")
print(f"ms Maximum: {max_ms}")
# Out:
# range of averaged ms data
# ms Minimum: 1.5886842052588345e-27
# ms Maximum: 4.356626433535221e-26

# %%
# Define the data arrays
healthy_data_1st_click = features_psd_1st_click_healthy  # Shape: (16, 102, 2)
mci_data_1st_click = features_psd_1st_click_mci  # Shape: (16, 2, 102)

# Compute average power spectral densities
avg_healthy_alpha_1st_click = np.mean(healthy_data_1st_click[:, :, 0], axis=0)
avg_healthy_beta_1st_click = np.mean(healthy_data_1st_click[:, :, 1], axis=0)
avg_mci_alpha_1st_click = np.mean(mci_data_1st_click[:, :, 0], axis=0)
avg_mci_beta_1st_click = np.mean(mci_data_1st_click[:, :, 1], axis=0)


avg_healthy_alpha_1st_click1 = avg_healthy_alpha_1st_click.astype(float)
avg_healthy_beta_1st_click1 = avg_healthy_beta_1st_click.astype(float)
avg_mci_alpha_1st_click1 = avg_mci_alpha_1st_click.astype(float)
avg_mci_beta_1st_click1 = avg_mci_beta_1st_click.astype(float)

min_1st_click=min(avg_healthy_alpha_1st_click1.min(),avg_healthy_beta_1st_click1.min(),avg_mci_alpha_1st_click1.min(),avg_mci_beta_1st_click1.min())
max_1st_click=max(avg_healthy_alpha_1st_click1.max(),avg_healthy_beta_1st_click1.max(),avg_mci_alpha_1st_click1.max(),avg_mci_beta_1st_click1.max())
print("range of averaged 1st_click data")
print(f"1st_click Minimum: {min_1st_click}")
print(f"1st_click Maximum: {max_1st_click}")
# Out:
# range of averaged 1st_click data
# 1st_click Minimum: 1.868354245554979e-27
# 1st_click Maximum: 4.0884677153419884e-26

# %%
# Define the data arrays
healthy_data_2nd_click = features_psd_2nd_click_healthy  # Shape: (16, 102, 2)
mci_data_2nd_click = features_psd_2nd_click_mci  # Shape: (16, 2, 102)

# Compute average power spectral densities
avg_healthy_alpha_2nd_click = np.mean(healthy_data_2nd_click[:, :, 0], axis=0)
avg_healthy_beta_2nd_click = np.mean(healthy_data_2nd_click[:, :, 1], axis=0)
avg_mci_alpha_2nd_click = np.mean(mci_data_2nd_click[:, :, 0], axis=0)
avg_mci_beta_2nd_click = np.mean(mci_data_2nd_click[:, :, 1], axis=0)


avg_healthy_alpha_2nd_click1 = avg_healthy_alpha_2nd_click.astype(float)
avg_healthy_beta_2nd_click1 = avg_healthy_beta_2nd_click.astype(float)
avg_mci_alpha_2nd_click1 = avg_mci_alpha_2nd_click.astype(float)
avg_mci_beta_2nd_click1 = avg_mci_beta_2nd_click.astype(float)

min_2nd_click=min(avg_healthy_alpha_2nd_click1.min(),avg_healthy_beta_2nd_click1.min(),avg_mci_alpha_2nd_click1.min(),avg_mci_beta_2nd_click1.min())
max_2nd_click=max(avg_healthy_alpha_2nd_click1.max(),avg_healthy_beta_2nd_click1.max(),avg_mci_alpha_2nd_click1.max(),avg_mci_beta_2nd_click1.max())
print("range of averaged 2nd_click data")
print(f"2nd_click Minimum: {min_2nd_click}")
print(f"2nd_click Maximum: {max_2nd_click}")
# Out:
# range of averaged 2nd_click data
# 2nd_click Minimum: 5.591987672796021e-28
# 2nd_click Maximum: 6.718316673249522e-26

# %%
# Find the minimum and maximum values across both arrays
overall_min = min(min_rsec,min_rseo, min_ms,min_1st_click,min_2nd_click)
overall_max = max(max_rsec,max_rseo,max_ms,max_1st_click,max_2nd_click)

print(f"Overall Minimum: {overall_min}")
print(f"Overall Maximum: {overall_max}")
# Out:
# Overall Minimum: 5.591987672796021e-28
# Overall Maximum: 1.455226190209539e-25

# %%
# folder_path = "D:\internship_ulster_university\diagrams for paper"

# # Move into the target folder
# os.chdir(folder_path)

# import numpy as np
# import matplotlib.pyplot as plt
# import mne##
# from matplotlib.colors import Normalize

# healthy_data = features_psd_rsec_healthy  # Shape: (16, 102, 2)
# mci_data = features_psd_rsec_mci  # Shape: (16, 2, 102)
# freqs = ['Alpha', 'Beta']


# avg_healthy_alpha = np.mean(healthy_data[:, :, 0], axis=0)
# avg_healthy_beta = np.mean(healthy_data[:, :, 1], axis=0)
# avg_mci_alpha = np.mean(mci_data[:, :, 0], axis=0)
# avg_mci_beta = np.mean(mci_data[:, :, 1], axis=0)
# print(avg_healthy_alpha.shape)

# vmax=1e-21
# vmin=1e-22
# norm = Normalize(vmin=vmin, vmax=vmax)
# # healthy alpha 
# plt.figure(figsize=(20,20))
# plt.suptitle('Average Alpha Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_healthy_alpha, position_xy, show=False, cmap='viridis', sensors=False,size=2,vlim=(vmin,vmax))
# plt.colorbar(img, ax=plt.gca())
# #plt.colorbar(img, ax=plt.gca()).set_clim(vmin, vmax)
# plt.savefig('rsec_healthy_alpha_topoplot.jpeg',dpi=500)  # Increase DPI for higher resolution
# plt.show()

# # healthy beta 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average beta Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_healthy_beta, position_xy, show=False, cmap='viridis', sensors=False,size=2,vlim=(vmin,vmax))
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('rsec_healthy_beta_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()

# # mci alpha 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average Alpha Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_mci_alpha, position_xy, show=False, cmap='viridis', sensors=False,size=2,vlim=(vmin,vmax))
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('rsec_mci_alpha_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()


# # healthy beta 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average beta Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_mci_beta, position_xy, show=False, cmap='viridis', sensors=False,size=2,vlim=(vmin,vmax))
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('rsec_mci_beta_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import mne
from matplotlib.colors import Normalize

# Ensure plots are displayed inline in the notebook
# %matplotlib inline


folder_path = "D:\internship_ulster_university\diagrams for paper"
os.chdir(folder_path)


def normalize_data(data, min_val, max_val):
    normalized_data = (data - min_val) / (max_val - min_val)
    return normalized_data


avg_healthy_alpha_normalized = normalize_data(avg_healthy_alpha_rsec1, overall_min, overall_max)
avg_healthy_beta_normalized = normalize_data(avg_healthy_beta_rsec1, overall_min, overall_max)
avg_mci_alpha_normalized = normalize_data(avg_mci_alpha_rsec1, overall_min, overall_max)
avg_mci_beta_normalized = normalize_data(avg_mci_beta_rsec1, overall_min, overall_max)


print(avg_healthy_alpha_normalized)
def plot_topomap(data, filename, vmin=None, vmax=None):
    fig, ax = plt.subplots(figsize=(9, 12))
    img, _ = mne.viz.plot_topomap(data, position_xy, axes=ax, show=False,
                                   cmap='inferno', sensors=False,vlim=(0,1), size=1, sphere=(0, 0, 0, 15))
    cbar = plt.colorbar(img, ax=ax)
    cbar.ax.tick_params(labelsize=18)
    cbar.ax.yaxis.get_offset_text().set(size=18)
    plt.savefig(filename, dpi=500)  # Increase DPI for higher resolution
    plt.show()

# Define color scale limits
vmin = 0
vmax = log_transform(1)  # Logarithmic transformation maximum

# # List of color maps to try
# color_maps = ['viridis', 'plasma', 'inferno', 'magma', 'cividis', 
#               'coolwarm', 'bwr', 'Spectral', 'RdBu', 'PiYG']

# Plotting the topomaps with different color maps
#for cmap in color_maps:
plot_topomap(avg_healthy_alpha_normalized, f'rsec_healthy_alpha_topoplot.jpeg', vmin=vmin, vmax=vmax)
plot_topomap(avg_healthy_beta_normalized, f'rsec_healthy_beta_topoplot.jpeg', vmin=vmin, vmax=vmax)
plot_topomap(avg_mci_alpha_normalized, f'rsec_mci_alpha_topoplot.jpeg', vmin=vmin, vmax=vmax)
plot_topomap(avg_mci_beta_normalized, f'rsec_mci_beta_topoplot.jpeg', vmin=vmin, vmax=vmax)
# Out:
# [0.25697398 0.22678813 0.22625663 0.26929653 0.19726025 0.17365556
#  0.25981708 0.31525946 0.12788558 0.11135343 0.07697563 0.18558294
#  0.14119359 0.09938283 0.16461045 0.21463002 0.07069249 0.06112597
#  0.04019195 0.05478347 0.04245759 0.06186827 0.08248556 0.06085062
#  0.12944163 0.14577482 0.15988739 0.17659466 0.062204   0.0460311
#  0.05946179 0.06585814 0.0672709  0.04922847 0.04473086 0.04473216
#  0.0697809  0.09999081 0.12070263 0.1298792  0.21198968 0.20642212
#  0.10836666 0.15913901 0.11688195 0.08206668 0.17381229 0.20069599
#  0.29181216 0.26730363 0.16968155 0.11560244 0.15416109 0.18962909
#  0.25602925 0.28157769 0.2283923  0.23088801 0.32042312 0.33397892
#  0.34157377 0.34395798 0.2008722  0.29388021 0.33534987 0.2068257
#  0.27424699 0.2033314  0.24083339 0.25697961 0.33917873 0.40954981
#  0.2599796  0.41085201 0.33391238 0.33855262 0.39345012 0.44200078
#  0.35941863 0.22362166 0.1291674  0.14654172 0.21170049 0.2325034
# ...

# %% [markdown]
# ## rseo healthy and mci alpha and beta plots

# %%
# folder_path = "D:\internship_ulster_university\diagrams for paper"

# # Move into the target folder
# os.chdir(folder_path)

# import numpy as np
# import matplotlib.pyplot as plt
# import mne##
# from matplotlib.colors import Normalize

# healthy_data = features_psd_rseo_healthy  # Shape: (16, 102, 2)
# mci_data = features_psd_rseo_mci  # Shape: (16, 2, 102)
# freqs = ['Alpha', 'Beta']


# avg_healthy_alpha = np.mean(healthy_data[:, :, 0], axis=0)
# avg_healthy_beta = np.mean(healthy_data[:, :, 1], axis=0)
# avg_mci_alpha = np.mean(mci_data[:, :, 0], axis=0)
# avg_mci_beta = np.mean(mci_data[:, :, 1], axis=0)
# print(avg_healthy_alpha.shape)

# vmax=1e-21
# vmin=1e-22
# norm = Normalize(vmin=vmin, vmax=vmax)
# # healthy alpha 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average Alpha Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_healthy_alpha, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('rseo_healthy_alpha_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()

# # healthy beta 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average beta Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_healthy_beta, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('rseo_healthy_beta_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()

# # mci alpha 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average Alpha Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_mci_alpha, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('rseo_mci_alpha_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()


# # healthy beta 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average beta Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_mci_beta, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('rseo_mci_beta_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()

# %%
# import os
# import numpy as np
# import matplotlib.pyplot as plt
# import mne
# from matplotlib.colors import Normalize


# # Ensure plots are displayed inline in the notebook
# %matplotlib inline





# folder_path = "D:\internship_ulster_university\diagrams for paper"
# os.chdir(folder_path)

# healthy_data = features_psd_rseo_healthy  # Shape: (16, 102, 2)
# mci_data = features_psd_rseo_mci  # Shape: (16, 2, 102)
# freqs = ['Alpha', 'Beta']

# avg_healthy_alpha = np.mean(healthy_data[:, :, 0], axis=0)
# avg_healthy_beta = np.mean(healthy_data[:, :, 1], axis=0)
# avg_mci_alpha = np.mean(mci_data[:, :, 0], axis=0)
# avg_mci_beta = np.mean(mci_data[:, :, 1], axis=0)

# vmax = 1e-20
# vmin = 1e-23
# norm = Normalize(vmin=overall_min, vmax=overall_max)

# def plot_topomap(data, filename):
#     fig, ax = plt.subplots(figsize=(9, 12))
#     img, _ = mne.viz.plot_topomap(data, position_xy, axes=ax, show=False,
#                                   cmap='viridis', sensors=False, size=1, cnorm=norm,sphere=(0, 0, 0,15))
#     cbar=plt.colorbar(img, ax=ax)
#     cbar.ax.tick_params(labelsize=18)
#     cbar.ax.yaxis.get_offset_text().set(size=18)
#     plt.savefig(filename, dpi=500)  # Increase DPI for higher resolution
#     plt.show()

# # Plotting the topomaps
# plot_topomap(avg_healthy_alpha,  'rseo_healthy_alpha_topoplot.jpeg')
# plot_topomap(avg_healthy_beta, 'rseo_healthy_beta_topoplot.jpeg')
# plot_topomap(avg_mci_alpha, 'rseo_mci_alpha_topoplot.jpeg')
# plot_topomap(avg_mci_beta, 'rseo_mci_beta_topoplot.jpeg')

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import mne
from matplotlib.colors import Normalize

# Ensure plots are displayed inline in the notebook
# %matplotlib inline


folder_path = "D:\internship_ulster_university\diagrams for paper"
os.chdir(folder_path)



def normalize_data(data, min_val, max_val):
    normalized_data = (data - min_val) / (max_val - min_val)
    return normalized_data


avg_healthy_alpha_normalized = normalize_data(avg_healthy_alpha_rseo1, overall_min, overall_max)
avg_healthy_beta_normalized = normalize_data(avg_healthy_beta_rseo1, overall_min, overall_max)
avg_mci_alpha_normalized = normalize_data(avg_mci_alpha_rseo1, overall_min, overall_max)
avg_mci_beta_normalized = normalize_data(avg_mci_beta_rseo1, overall_min, overall_max)


print(avg_healthy_alpha_normalized)



def plot_topomap(data, filename, vmin=None, vmax=None):
    fig, ax = plt.subplots(figsize=(9, 12))
    img, _ = mne.viz.plot_topomap(data, position_xy, axes=ax, show=False,
                                   cmap='inferno', sensors=False,vlim=(0,1), size=1, sphere=(0, 0, 0, 15))
    cbar = plt.colorbar(img, ax=ax)
    cbar.ax.tick_params(labelsize=18)
    cbar.ax.yaxis.get_offset_text().set(size=18)
    plt.savefig(filename, dpi=500)  # Increase DPI for higher resolution
    plt.show()

# Define color scale limits
vmin = 0
vmax = log_transform(1)  # Logarithmic transformation maximum

# List of color maps to try
color_maps = ['viridis', 'plasma', 'inferno', 'magma', 'cividis', 
              'coolwarm', 'bwr', 'Spectral', 'RdBu', 'PiYG']

# Plotting the topomaps with different color maps
#for cmap in color_maps:
plot_topomap(avg_healthy_alpha_normalized, f'rseo_healthy_alpha_topoplot.jpeg', vmin=vmin, vmax=vmax)
plot_topomap(avg_healthy_beta_normalized, f'rseo_healthy_beta_topoplot.jpeg', vmin=vmin, vmax=vmax)
plot_topomap(avg_mci_alpha_normalized, f'rseo_mci_alpha_topoplot.jpeg', vmin=vmin, vmax=vmax)
plot_topomap(avg_mci_beta_normalized, f'rseo_mci_beta_topoplot.jpeg', vmin=vmin, vmax=vmax)
# Out:
# [0.27252947 0.2491949  0.23760112 0.26312129 0.19520081 0.16831382
#  0.25238962 0.27926053 0.15569149 0.11982139 0.07881849 0.19474674
#  0.13358274 0.09932844 0.15626415 0.22966397 0.09282684 0.07694228
#  0.04656687 0.06487917 0.04216671 0.05820878 0.07492861 0.05655704
#  0.11783524 0.11767719 0.12900511 0.15775841 0.0696396  0.04870378
#  0.07087906 0.08521106 0.07354382 0.05136906 0.04442179 0.04558035
#  0.06316409 0.08583292 0.1079747  0.12156236 0.18477086 0.15372181
#  0.13324461 0.17447941 0.12276743 0.07962045 0.16072762 0.20388883
#  0.23462639 0.22590154 0.18585455 0.11710451 0.14147727 0.19927744
#  0.2440647  0.24026111 0.18989485 0.22322359 0.27275956 0.28456559
#  0.25647789 0.25350133 0.16379076 0.21150935 0.21834131 0.15443932
#  0.23933073 0.18380835 0.19043439 0.19598647 0.23507455 0.24447356
#  0.16031415 0.23492329 0.2185826  0.19527315 0.22829735 0.23070565
#  0.19385868 0.1288242  0.08945751 0.10827903 0.15312906 0.19063447
# ...

# %% [markdown]
# ## movie state healthy and mci alpha and beta plots

# %%
# folder_path = "D:\internship_ulster_university\diagrams for paper"

# # Move into the target folder
# os.chdir(folder_path)

# import numpy as np
# import matplotlib.pyplot as plt
# import mne##
# from matplotlib.colors import Normalize


# healthy_data = features_psd_ms_healthy  # Shape: (16, 102, 2)
# mci_data = features_psd_ms_mci  # Shape: (16, 2, 102)
# freqs = ['Alpha', 'Beta']


# avg_healthy_alpha = np.mean(healthy_data[:, :, 0], axis=0)
# avg_healthy_beta = np.mean(healthy_data[:, :, 1], axis=0)
# avg_mci_alpha = np.mean(mci_data[:, :, 0], axis=0)
# avg_mci_beta = np.mean(mci_data[:, :, 1], axis=0)
# print(avg_healthy_alpha.shape)

# vmax=1e-21
# vmin=1e-22
# norm = Normalize(vmin=vmin, vmax=vmax)
# # healthy alpha 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average Alpha Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_healthy_alpha, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('ms_healthy_alpha_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()

# # healthy beta 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average beta Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_healthy_beta, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('ms_healthy_beta_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()

# # mci alpha 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average Alpha Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_mci_alpha, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('ms_mci_alpha_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()


# # healthy beta 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average beta Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_mci_beta, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('ms_mci_beta_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()

# %%
# import os
# import numpy as np
# import matplotlib.pyplot as plt
# import mne
# from matplotlib.colors import Normalize

# # Ensure plots are displayed inline in the notebook
# %matplotlib inline



# folder_path = "D:\internship_ulster_university"
# os.chdir(folder_path)
# # Load your custom layout file
# layout = mne.channels.read_layout('neuromag306cmb.lay')

# folder_path = "D:\internship_ulster_university\diagrams for paper"
# os.chdir(folder_path)

# healthy_data = features_psd_ms_healthy  # Shape: (16, 102, 2)
# mci_data = features_psd_ms_mci  # Shape: (16, 2, 102)
# freqs = ['Alpha', 'Beta']

# avg_healthy_alpha = np.mean(healthy_data[:, :, 0], axis=0)
# avg_healthy_beta = np.mean(healthy_data[:, :, 1], axis=0)
# avg_mci_alpha = np.mean(mci_data[:, :, 0], axis=0)
# avg_mci_beta = np.mean(mci_data[:, :, 1], axis=0)
# print(avg_mci_beta)
# vmax = 1e-20
# vmin = 1e-23
# norm = Normalize(vmin=overall_min, vmax=overall_max)

# def plot_topomap(data, filename):
#     fig, ax = plt.subplots(figsize=(9, 12))
#     img, _ = mne.viz.plot_topomap(data, position_xy, axes=ax, show=False,
#                                   cmap='viridis', sensors=False, size=1, cnorm=norm,sphere=(0, 0, 0,15))
#     cbar=plt.colorbar(img, ax=ax)
#     cbar.ax.tick_params(labelsize=18)
#     cbar.ax.yaxis.get_offset_text().set(size=18)
#     plt.savefig(filename, dpi=500)  # Increase DPI for higher resolution
#     plt.show()

# # Plotting the topomaps
# plot_topomap(avg_healthy_alpha, 'ms_healthy_alpha_topoplot.jpeg')
# plot_topomap(avg_healthy_beta, 'ms_healthy_beta_topoplot.jpeg')
# plot_topomap(avg_mci_alpha, 'ms_mci_alpha_topoplot.jpeg')
# plot_topomap(avg_mci_beta, 'ms_mci_beta_topoplot.jpeg')

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import mne
from matplotlib.colors import Normalize

# Ensure plots are displayed inline in the notebook
# %matplotlib inline


folder_path = "D:\internship_ulster_university\diagrams for paper"
os.chdir(folder_path)



def normalize_data(data, min_val, max_val):
    normalized_data = (data - min_val) / (max_val - min_val)
    return normalized_data


avg_healthy_alpha_normalized = normalize_data(avg_healthy_alpha_ms1, overall_min,  overall_max)
avg_healthy_beta_normalized = normalize_data(avg_healthy_beta_ms1,  overall_min,  overall_max)
avg_mci_alpha_normalized = normalize_data(avg_mci_alpha_ms1,  overall_min,  overall_max)
avg_mci_beta_normalized = normalize_data(avg_mci_beta_ms1,  overall_min,  overall_max)



print(avg_healthy_alpha_normalized)

def plot_topomap(data, filename, vmin=None, vmax=None):
    fig, ax = plt.subplots(figsize=(9, 12))
    img, _ = mne.viz.plot_topomap(data, position_xy, axes=ax, show=False,
                                   cmap='inferno', sensors=False,vlim=(0,1), size=1, sphere=(0, 0, 0, 15))
    cbar = plt.colorbar(img, ax=ax)
    cbar.ax.tick_params(labelsize=18)
    cbar.ax.yaxis.get_offset_text().set(size=18)
    plt.savefig(filename, dpi=500)  # Increase DPI for higher resolution
    plt.show()

# Define color scale limits
vmin = 0
vmax = log_transform(1)  # Logarithmic transformation maximum

# List of color maps to try
color_maps = ['viridis', 'plasma', 'inferno', 'magma', 'cividis', 
              'coolwarm', 'bwr', 'Spectral', 'RdBu', 'PiYG']

# Plotting the topomaps with different color maps
#for cmap in color_maps:
plot_topomap(avg_healthy_alpha_normalized, f'ms_healthy_alpha_topoplot.jpeg', vmin=vmin, vmax=vmax)
plot_topomap(avg_healthy_beta_normalized, f'ms_healthy_beta_topoplot.jpeg', vmin=vmin, vmax=vmax)
plot_topomap(avg_mci_alpha_normalized, f'ms_mci_alpha_topoplot.jpeg', vmin=vmin, vmax=vmax)
plot_topomap(avg_mci_beta_normalized, f'ms_mci_beta_topoplot.jpeg', vmin=vmin, vmax=vmax)
# Out:
# [0.0458476  0.06598708 0.06005672 0.0419696  0.05983095 0.04257422
#  0.06198744 0.07648948 0.0356571  0.02620599 0.01513745 0.05383542
#  0.02824271 0.01892128 0.02924922 0.04434606 0.01989601 0.01533482
#  0.00897936 0.01289544 0.00786667 0.0104094  0.0145836  0.01140507
#  0.02021195 0.01910983 0.02278712 0.02713878 0.01337551 0.00903988
#  0.01328896 0.01638695 0.01206336 0.00866357 0.00759163 0.00714427
#  0.01091342 0.01560883 0.02167976 0.02740233 0.04461416 0.03102163
#  0.02969299 0.04479318 0.02417014 0.01481524 0.04059552 0.05949305
#  0.06616578 0.06025307 0.05032629 0.03067685 0.03872321 0.05183798
#  0.07541632 0.068943   0.03939199 0.04355352 0.07372608 0.06867498
#  0.05721013 0.06212838 0.03107712 0.05607004 0.06080986 0.03019701
#  0.05129062 0.0327283  0.03077209 0.03551461 0.04791065 0.05815261
#  0.04628812 0.05827827 0.03891966 0.03534013 0.05064612 0.05536396
#  0.05956861 0.0411722  0.01928431 0.02183216 0.02940089 0.0452147
# ...

# %% [markdown]
# ## 1st click healthy and mci alpha and beta plots

# %%
# folder_path = "D:\internship_ulster_university\diagrams for paper"

# # Move into the target folder
# os.chdir(folder_path)

# import numpy as np
# import matplotlib.pyplot as plt
# import mne##
# from matplotlib.colors import Normalize


# healthy_data = features_psd_1st_click_healthy  # Shape: (16, 102, 2)
# mci_data = features_psd_1st_click_mci  # Shape: (16, 2, 102)
# freqs = ['Alpha', 'Beta']


# avg_healthy_alpha = np.mean(healthy_data[:, :, 0], axis=0)
# avg_healthy_beta = np.mean(healthy_data[:, :, 1], axis=0)
# avg_mci_alpha = np.mean(mci_data[:, :, 0], axis=0)
# avg_mci_beta = np.mean(mci_data[:, :, 1], axis=0)
# print(avg_healthy_alpha.shape)

# vmax=1e-21
# vmin=1e-22
# norm = Normalize(vmin=vmin, vmax=vmax)
# # healthy alpha 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average Alpha Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_healthy_alpha, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('1st_click_healthy_alpha_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()

# # healthy beta 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average beta Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_healthy_beta, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('1st_click_healthy_beta_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()

# # mci alpha 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average Alpha Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_mci_alpha, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('1st_click_mci_alpha_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()


# # healthy beta 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average beta Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_mci_beta, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('1st_click_mci_beta_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()

# %%
print(features_psd_1st_click_healthy[:,:,1])
#print(features_psd_rseo_healthy[:,2,1])
# Out:
# [[1.4701839811538767e-27 4.369017007612471e-27 2.449822005515292e-27 ...
#   4.5298971093539155e-27 1.0143628235339576e-26 2.7936497032578626e-27]
#  [6.147847834534874e-27 2.0067348251479095e-27 7.474586189539147e-27 ...
#   3.640633055067016e-27 5.661733286786515e-27 8.602617243028475e-27]
#  [5.5290036702969484e-27 2.3925866532634712e-27 2.7147562452415622e-27
#   ... 1.177066123376675e-26 9.373627643328695e-27 5.758972438455935e-27]
#  ...
#  [3.316816591639189e-27 1.5672266213716167e-26 3.679551304098256e-26 ...
#   1.0547314878842964e-26 1.0235467058970241e-26 9.379525846025987e-27]
#  [3.439248337850574e-26 1.0915766968829081e-26 1.0088097708980729e-26 ...
#   7.280217432670058e-27 1.5490079151161634e-27 1.0436631710815041e-26]
#  [1.4265413982160247e-26 1.429241176701261e-26 7.32809851967985e-27 ...
#   4.000774009637252e-27 6.283772248083748e-27 2.6995377500885305e-26]]

# %%
plt.close()

# %%
# import os
# import numpy as np
# import matplotlib.pyplot as plt
# import mne
# from matplotlib.colors import Normalize



# # Ensure plots are displayed inline in the notebook
# %matplotlib inline



# folder_path = "D:\internship_ulster_university"
# os.chdir(folder_path)
# # Load your custom layout file
# layout = mne.channels.read_layout('neuromag306cmb.lay')

# folder_path = "D:\internship_ulster_university\diagrams for paper"
# os.chdir(folder_path)

# healthy_data = features_psd_1st_click_healthy  # Shape: (16, 102, 2)
# mci_data = features_psd_1st_click_mci  # Shape: (16, 2, 102)
# freqs = ['Alpha', 'Beta']



# avg_healthy_alpha = np.mean(healthy_data[:, :, 0], axis=0)
# avg_healthy_beta = np.mean(healthy_data[:, :, 1], axis=0)
# avg_mci_alpha = np.mean(mci_data[:, :, 0], axis=0)
# avg_mci_beta = np.mean(mci_data[:, :, 1], axis=0)
# print(avg_healthy_alpha.shape)
# print(avg_healthy_beta.shape)

# vmax = 1e-20
# vmin = 1e-23
# norm = Normalize(vmin=0, vmax=1)

# def plot_topomap(data, filename):
#     fig, ax = plt.subplots(figsize=(9, 12))
#     img, _ = mne.viz.plot_topomap(data, position_xy, axes=ax, show=False,
#                                   cmap='viridis', sensors=False, size=1,cnorm=norm, sphere=(0, 0, 0,15))
#     cbar=plt.colorbar(img, ax=ax)
#     cbar.ax.tick_params(labelsize=18)
#     cbar.ax.yaxis.get_offset_text().set(size=18)
#     plt.savefig(filename, dpi=500)  # Increase DPI for higher resolution
#     plt.show()

# # Plotting the topomaps
# plot_topomap(avg_healthy_alpha,'1st_click_healthy_alpha_topoplot.jpeg')
# plot_topomap(avg_healthy_beta,'1st_click_healthy_beta_topoplot.jpeg')
# plot_topomap(avg_mci_alpha, '1st_click_mci_alpha_topoplot.jpeg')
# plot_topomap(avg_mci_beta, '1st_click_mci_beta_topoplot.jpeg')

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import mne
from matplotlib.colors import Normalize

# Ensure plots are displayed inline in the notebook
# %matplotlib inline

folder_path = "D:\internship_ulster_university\diagrams for paper"
os.chdir(folder_path)



def normalize_data(data, min_val, max_val):
    normalized_data = (data - min_val) / (max_val - min_val)
    return normalized_data


avg_healthy_alpha_normalized = normalize_data(avg_healthy_alpha_1st_click1, overall_min, overall_max)
avg_healthy_beta_normalized = normalize_data(avg_healthy_beta_1st_click1, overall_min,overall_max)
avg_mci_alpha_normalized = normalize_data(avg_mci_alpha_1st_click1, overall_min, overall_max)
avg_mci_beta_normalized = normalize_data(avg_mci_beta_1st_click1, overall_min, overall_max)

def plot_topomap(data, filename, vmin=None, vmax=None):
    fig, ax = plt.subplots(figsize=(9, 12))
    img, _ = mne.viz.plot_topomap(data, position_xy, axes=ax, show=False,
                                   cmap='inferno', sensors=False, vlim=(0, 1), size=1, sphere=(0, 0, 0, 15))
    cbar = plt.colorbar(img, ax=ax)
    cbar.ax.tick_params(labelsize=18)
    cbar.ax.yaxis.get_offset_text().set(size=18)
    plt.savefig(filename, dpi=500)  # Increase DPI for higher resolution
    plt.show()

# Define color scale limits
vmin = 0
vmax = log_transform(1)  # Logarithmic transformation maximum

# List of color maps to try
color_maps = ['viridis', 'plasma', 'inferno', 'magma', 'cividis', 
              'coolwarm', 'bwr', 'Spectral', 'RdBu', 'PiYG']

# Plotting the topomaps with different color maps
#for cmap in color_maps:
plot_topomap(avg_healthy_alpha_normalized, f'1st_click_healthy_alpha_topoplot.jpeg', vmin=vmin, vmax=vmax)
plot_topomap(avg_healthy_beta_normalized, f'1st_click_healthy_beta_topoplot.jpeg', vmin=vmin, vmax=vmax)
plot_topomap(avg_mci_alpha_normalized, f'1st_click_mci_alpha_topoplot.jpeg', vmin=vmin, vmax=vmax)
plot_topomap(avg_mci_beta_normalized, f'1st_click_mci_beta_topoplot.jpeg', vmin=vmin, vmax=vmax)

# %% [markdown]
# ## 2nd click healthy and mci alpha and beta plots

# %%
# folder_path = "D:\internship_ulster_university\diagrams for paper"

# # Move into the target folder
# os.chdir(folder_path)

# import numpy as np
# import matplotlib.pyplot as plt
# import mne##
# from matplotlib.colors import Normalize


# healthy_data = features_psd_2nd_click_healthy  # Shape: (16, 102, 2)
# mci_data = features_psd_2nd_click_mci  # Shape: (16, 2, 102)
# freqs = ['Alpha', 'Beta']


# avg_healthy_alpha = np.mean(healthy_data[:, :, 0], axis=0)
# avg_healthy_beta = np.mean(healthy_data[:, :, 1], axis=0)
# avg_mci_alpha = np.mean(mci_data[:, :, 0], axis=0)
# avg_mci_beta = np.mean(mci_data[:, :, 1], axis=0)
# print(avg_healthy_alpha.shape)

# vmax=1e-21
# vmin=1e-22
# norm = Normalize(vmin=vmin, vmax=vmax)
# # healthy alpha 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average Alpha Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_healthy_alpha, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('2nd_click_healthy_alpha_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()

# # healthy beta 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average beta Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_healthy_beta, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('2nd_click_healthy_beta_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()

# # mci alpha 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average Alpha Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_mci_alpha, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('2nd_click_mci_alpha_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()


# # healthy beta 
# plt.figure(figsize=(9,12))
# plt.suptitle('Average beta Band Power Topoplot')
# img, _ = mne.viz.plot_topomap(avg_mci_beta, position_xy, show=False, cmap='viridis', sensors=False,size=2,cnorm=norm)
# plt.colorbar(img, ax=plt.gca())
# plt.savefig('2nd_click_mci_beta_topoplot.jpeg', dpi=500)  # Increase DPI for higher resolution
# plt.show()

# %%
# import os
# import numpy as np
# import matplotlib.pyplot as plt
# import mne
# from matplotlib.colors import Normalize

# folder_path = "D:\internship_ulster_university"
# os.chdir(folder_path)
# # Load your custom layout file
# layout = mne.channels.read_layout('neuromag306cmb.lay')

# folder_path = "D:\internship_ulster_university\diagrams for paper"
# os.chdir(folder_path)

# healthy_data = features_psd_2nd_click_healthy  # Shape: (16, 102, 2)
# mci_data = features_psd_2nd_click_mci  # Shape: (16, 2, 102)
# freqs = ['Alpha', 'Beta']

# avg_healthy_alpha = np.mean(healthy_data[:, :, 0], axis=0)
# avg_healthy_beta = np.mean(healthy_data[:, :, 1], axis=0)
# avg_mci_alpha = np.mean(mci_data[:, :, 0], axis=0)
# avg_mci_beta = np.mean(mci_data[:, :, 1], axis=0)

# vmax = 1e-21
# vmin = 1e-22
# norm = Normalize(vmin=overall_min, vmax=overall_max)

# def plot_topomap(data, filename):
#     fig, ax = plt.subplots(figsize=(9, 12))
#     img, _ = mne.viz.plot_topomap(data, position_xy, axes=ax, show=False,
#                                   cmap='viridis', sensors=False, size=1, cnorm=norm,sphere=(0, 0, 0,15))
#     cbar=plt.colorbar(img, ax=ax)
#     cbar.ax.tick_params(labelsize=18)
#     cbar.ax.yaxis.get_offset_text().set(size=18)
#     plt.savefig(filename, dpi=500)  # Increase DPI for higher resolution
#     plt.show()


# plot_topomap(avg_healthy_alpha, '2nd_click_healthy_alpha_topoplot.jpeg')
# plot_topomap(avg_healthy_beta, '2nd_click_healthy_beta_topoplot.jpeg')
# plot_topomap(avg_mci_alpha, '2nd_click_mci_alpha_topoplot.jpeg')
# plot_topomap(avg_mci_beta, '2nd_click_mci_beta_topoplot.jpeg')

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import mne
from matplotlib.colors import Normalize

# Ensure plots are displayed inline in the notebook
# %matplotlib inline

folder_path = "D:\internship_ulster_university\diagrams for paper"
os.chdir(folder_path)



def normalize_data(data, min_val, max_val):
    normalized_data = (data - min_val) / (max_val - min_val)
    return normalized_data


avg_healthy_alpha_normalized = normalize_data(avg_healthy_alpha_2nd_click1, overall_min,overall_max)
avg_healthy_beta_normalized = normalize_data(avg_healthy_beta_2nd_click1, overall_min, overall_max)
avg_mci_alpha_normalized = normalize_data(avg_mci_alpha_2nd_click1, overall_min, overall_max)
avg_mci_beta_normalized = normalize_data(avg_mci_beta_2nd_click1, overall_min, overall_max)

def plot_topomap(data, filename, vmin=None, vmax=None):
    fig, ax = plt.subplots(figsize=(9, 12))
    img, _ = mne.viz.plot_topomap(data, position_xy, axes=ax, show=False,
                                   cmap='inferno', sensors=False, vlim=(0,1), size=1, sphere=(0, 0, 0, 15))
    cbar = plt.colorbar(img, ax=ax)
    cbar.ax.tick_params(labelsize=18)
    cbar.ax.yaxis.get_offset_text().set(size=18)
    plt.savefig(filename, dpi=500)  # Increase DPI for higher resolution
    plt.show()

# Define color scale limits
vmin = 0
vmax = log_transform(1)  # Logarithmic transformation maximum

# List of color maps to try
color_maps = ['viridis', 'plasma', 'inferno', 'magma', 'cividis', 
              'coolwarm', 'bwr', 'Spectral', 'RdBu', 'PiYG']

# Plotting the topomaps with different color maps
#for cmap in color_maps:
plot_topomap(avg_healthy_alpha_normalized, f'2nd_click_healthy_alpha_topoplot.jpeg', vmin=vmin, vmax=vmax)
plot_topomap(avg_healthy_beta_normalized, f'2nd_click_healthy_beta_topoplot.jpeg', vmin=vmin, vmax=vmax)
plot_topomap(avg_mci_alpha_normalized, f'2nd_click_mci_alpha_topoplot.jpeg', vmin=vmin, vmax=vmax)
plot_topomap(avg_mci_beta_normalized, f'2nd_click_mci_beta_topoplot.jpeg', vmin=vmin, vmax=vmax)
